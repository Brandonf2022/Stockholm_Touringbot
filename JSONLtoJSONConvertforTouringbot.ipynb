# %%
import json
import requests
import tkinter as tk
from tkinter import filedialog

def get_url_from_api(custom_id):
    # Extract the five-digit code
    modified_custom_id = '-'.join(custom_id.split('-')[:2])
    
    # Build the API URL
    api_url = f"https://data.kb.se/lookup/?id={modified_custom_id}"
    
    try:
        response = requests.get(api_url, headers={'accept': 'application/json'})
        response.raise_for_status()  # Raise an error for bad status codes
        data = response.json()
        return data.get('uri')
    except requests.RequestException as e:
        print(f"Failed to fetch URL for custom_id {custom_id}: {e}")
        return None

def jsonl_to_json():
    root = tk.Tk()
    root.withdraw()
    file_path = filedialog.askopenfilename(title="Select JSONL file", filetypes=[("JSON Lines files", "*.jsonl")])
    if not file_path:
        print("No file selected.")
        return

    extracted_content = []
    with open(file_path, 'r') as f:
        for line in f:
            json_obj = json.loads(line)
            try:
                custom_id = json_obj.get('custom_id')
                url = get_url_from_api(custom_id) if custom_id else None
                choices = json_obj['response']['body']['choices']
                for choice in choices:
                    if choice['message']['role'] == 'assistant':
                        try:
                            assistant_content = json.loads(choice['message']['content'])
                            if isinstance(assistant_content, dict):
                                # Process as a dictionary
                                assistant_content['custom_id'] = custom_id
                                assistant_content['url'] = url
                                extracted_content.append(assistant_content)
                            elif isinstance(assistant_content, list):
                                # Process each item in the list if it's a list of dictionaries
                                for item in assistant_content:
                                    if isinstance(item, dict):
                                        item['custom_id'] = custom_id
                                        item['url'] = url
                                    extracted_content.append(item)
                        except json.JSONDecodeError:
                            print(f"Failed to decode JSON content: {choice['message']['content']}")
            except KeyError:
                continue

    output_file_path = filedialog.asksaveasfilename(title="Save JSON file", filetypes=[("JSON files", "*.json")], defaultextension=".json")
    if not output_file_path:
        print("No output file selected.")
        return

    with open(output_file_path, 'w') as f:
        json.dump(extracted_content, f, indent=4)
    print("JSON file successfully saved.")

if __name__ == "__main__":
    jsonl_to_json()
# Out:
# Failed to decode JSON content: {
#   "konsert_datum": “25.02.08",
#   "konsert_namn": "Berlioz Faust",
#   "lokal_namn": "Kungliga musikaliska akademiens stora sal",
#   "konsert_biljettpris": "3:50kr, 2:60kr",
#   "konserttyp_namn": "Orkesterkonsert",
#   "Producer": "Nya Filharmoniska Sällskapet"
# }
# Failed to decode JSON content: {
#   "konsert_datum": "22.02.08",
#   "konsert_namn": "Vis- och Sagoafton",
#   "lokal_namn": "Vetenskapsakademiens hörsal",
#   "konsert_biljettpris": "0.50kr, 0.75kr, 1kr",
#   "konserttyp_namn": "Vis- och Sagoafton",
#   "Producer": "Sjögren, Ebba"
# }
#
# {
#   "konsert_datum": "24.02.08",
#   "konsert_namn": "Aurora IV Solanders Konsert",
#   "lokal_namn": "Vetenskaps-Akademiens Hörsal",
#   "konsert_biljettpris": "2.60kr, 2kr, 1.50kr",
#   "konserttyp_namn": "Solokonsert",
#   "Producer": "Norrie, Anna"
# }
# Failed to decode JSON content: {
#   "konsert_datum": "28.01.08",
#   "konsert_namn": "Brussel-Kvartettens Beethoven-Aftnar",
#   "lokal_namn": "Kungliga musikaliska akademiens stora sal",
#   "konsert_biljettpris": "3 kr, 2:50 kr, 2 kr",
#   "konserttyp_namn": "Kvartettkonsert",
#   "Producer": "UNKNOWN"
# }
#
# {
#   "konsert_datum": "30.01.08",
#   "konsert_namn": "Brussel-Kvartettens Beethoven-Aftnar",
#   "lokal_namn": "Kungliga musikaliska akademiens stora sal",
#   "konsert_biljettpris": "3 kr, 2:50 kr, 2 kr",
#   "konserttyp_namn": "Kvartettkonsert",
#   "Producer": "UNKNOWN"
# }
#
# {
#   "konsert_datum": "01.02.08",
#   "konsert_namn": "Brussel-Kvartettens Beethoven-Aftnar",
#   "lokal_namn": "Kungliga musikaliska akademiens stora sal",
#   "konsert_biljettpris": "3 kr, 2:50 kr, 2 kr",
#   "konserttyp_namn": "Kvartettkonsert",
#   "Producer": "UNKNOWN"
# }
# Failed to decode JSON content: {
#   "konsert_datum": “24.01.08",
#   "konsert_namn": "Kapell International",
#   "lokal_namn": "Hotel Hamburger Börs",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Stop Konsert",
#   "Producer": "Roclistroli, Paul"
# }
# Failed to decode JSON content: {
#   "konsert_datum": “27.01.08",
#   "konsert_namn": "Aljoscha Schkolnicks 2:a konsert",
#   "lokal_namn": "Vetenskaps-Akademiens hörsal",
#   "konsert_biljettpris": "2kr, 2kr, 50öre",
#   "konserttyp_namn": "Solokonsert",
#   "Producer": "UNKNOWN"
# }
#
# {
#   "konsert_datum": “31.01.08",
#   "konsert_namn": "Konsert till förmån för Djursholms kapell",
#   "lokal_namn": "Djursholms kapell",
#   "konsert_biljettpris": "2kr, 1kr 50öre",
#   "konserttyp_namn": "Välgörenhetskonsert",
#   "Producer": "Ungerska Dam-Kapellet"
# }
# Failed to decode JSON content: {
#   "konsert_datum": “UNKNOWN",
#   "konsert_namn": "Stopkonsert",
#   "lokal_namn": "Sveasalen",
#   "konsert_biljettpris": "1 kr",
#   "konserttyp_namn": "Konsert",
#   "Producer": "UNKNOWN"
# }
# Failed to decode JSON content: {
#   "konsert_datum": “04.01.08",
#   "konsert_namn": "Okänd",
#   "lokal_namn": "Intima Teatern",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Populär föreställning",
#   "Producer": "Gellin, Eduard"
# }
# Failed to decode JSON content: {
#   "konsert_datum": "05.01.08",
#   "konsert_namn": "Sjögren, Sonat för violin och piano op 19",
#   "lokal_namn": "Hotel Continentals festsal",
#   "konsert_biljettpris": "1kr, 1:50kr, 2kr",
#   "konserttyp_namn": "Kammarmusik",
#   "Producer": "Hansson, Axel"
# }
#
# {
#   "konsert_datum": "05.01.08",
#   "konsert_namn": "Aurora Molander, Fantasistycke Stenhammar",
#   "lokal_namn": "Vetenskapsakademiens hörsal",
#   "konsert_biljettpris": "50öre, 75öre",
#   "konserttyp_namn": "Populär konsert",
#   "Producer": "UNKNOWN"
# }
# Failed to decode JSON content: {
#   "konsert_datum": "04.03.08",
#   "konsert_namn": "Stor Tafvel-Åuktion",
#   "lokal_namn": "Theodor Blanch's Konst-Salon",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Auktion",
#   "Producer": "Stockholms Bokauktionskammare"
# }
#
# {
#   "konsert_datum": "06.03.08",
#   "konsert_namn": "Extra sammanträde",
#   "lokal_namn": "Hotell Continental",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Möte",
#   "Producer": "Kungl Svenska Segelsällskapet"
# }
#
# {
#   "konsert_datum": "28.02.08",
#   "konsert_namn": "Publicistklubbens Sammanträde",
#   "lokal_namn": "Publicistklubben",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Möte",
#   "Producer": "Publicistklubben"
# }
#
# {
#   "konsert_datum": "02.02.08",
#   "konsert_namn": "Ars- och revisorsberättelse",
#   "lokal_namn": "Gustaf Vasa",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Möte",
#   "Producer": "Aktiebolaget Stockholms Diskontobank"
# }
#
# {
#   "konsert_datum": "28.02.08",
#   "konsert_namn": "Jubileumsfestföreställning",
#   "lokal_namn": "Kungl Teatern",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Opera",
#   "Producer": "Kungl Teatern"
# }
#
# {
#   "konsert_datum": "29.02.08",
#   "konsert_namn": "Konsert med biträde av Nya Filharmoniska Sällskapet",
#   "lokal_namn": "Kungl Teatern",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Symfonikonsert",
#   "Producer": "Kungl Teatern"
# }
#
# {
#   "konsert_datum": "29.02.08",
#   "konsert_namn": "Berlioz Faust",
#   "lokal_namn": "Kungl Teatern",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Konsert",
#   "Producer": "Kungl Teatern"
# }
#
# {
#   "konsert_datum": "28.02.08",
#   "konsert_namn": "Borgaren Adelsman, De löjliga præcioserna",
#   "lokal_namn": "K Dramatiska Teatern",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Teater",
#   "Producer": "K Dramatiska Teatern"
# }
#
# {
#   "konsert_datum": "28.02.08",
#   "konsert_namn": "Tjuven",
#   "lokal_namn": "Svenska Teatern",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Teater",
#   "Producer": "Svenska Teatern"
# }
#
# {
#   "konsert_datum": "02.03.08",
#   "konsert_namn": "Bröllopet på Ulfåsa",
#   "lokal_namn": "UNKNOWN",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Skådespel",
#   "Producer": "Hedberg, Frans"
# }
# Failed to decode JSON content: {
#   "konsert_datum": "02.09.08",
#   "konsert_namn": "Lördagskonsert",
#   "lokal_namn": "Vetenskapsakademiens hörsal",
#   "konsert_biljettpris": "0.50kr, 0.75kr",
#   "konserttyp_namn": "Diverse",
#   "Producer": "UNKNOWN"
# }
#
# {
#   "konsert_datum": "03.03.08",
#   "konsert_namn": "Henry Jackson-Norris konsert",
#   "lokal_namn": "Vetenskapsakademiens hörsal",
#   "konsert_biljettpris": "2.50kr, 2.00kr, 1.50kr",
#   "konserttyp_namn": "Diverse",
#   "Producer": "Jackson-Norris, Henry"
# }
# Failed to decode JSON content: {
#   "konsert_datum": "27.04.08",
#   "konsert_namn": "Richard Andersson Konsert-Afton",
#   "lokal_namn": "Kungliga musikaliska akademiens stora sal",
#   "konsert_biljettpris": "2:50kr, 2kr, 1:50kr",
#   "konserttyp_namn": "Konsert-Afton",
#   "Producer": "Andersson, Richard"
# }
#
# {
#   "konsert_datum": "29.04.08",
#   "konsert_namn": "Ysaye-Konserten",
#   "lokal_namn": "Kungliga musikaliska akademiens stora sal",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Solokonsert",
#   "Producer": "Ysaye, Théo"
# }
# Failed to decode JSON content: {
#   "konsert_datum": "12.04.08",
#   "konsert_namn": "Populär-Konsert",
#   "lokal_namn": "Vetenskapsakademiens hörsal",
#   "konsert_biljettpris": "50 öre, 75 öre, 76 öre",
#   "konserttyp_namn": "Varierad konsert",
#   "Producer": "Stockholms Första Blåbandsförening"
# }
#
# {
#   "konsert_datum": "12.04.08",
#   "konsert_namn": "Konsert",
#   "lokal_namn": "KFUK:s hörsal n:o 3 Brunnsgatan",
#   "konsert_biljettpris": "76 öre",
#   "konserttyp_namn": "Varierad konsert",
#   "Producer": "Lagercrantz, Jacques"
# }
# Failed to decode JSON content: {
#   "konsert_datum": "11.04.08",
#   "konsert_namn": "KFUM Gymnasternas Konsert",
#   "lokal_namn": "KFUM Musikaliska Gymnasternas lokal",
#   "konsert_biljettpris": "0.75kr, 1kr, 1.50kr",
#   "konserttyp_namn": "Välgörenhetskonsert",
#   "Producer": "OKÄNT"
# }
#
# {
#   "konsert_datum": "12.04.08",
#   "konsert_namn": "Studentkonsert",
#   "lokal_namn": "Hagalunds kyrka",
#   "konsert_biljettpris": "1kr",
#   "konserttyp_namn": "Välgörenhetskonsert",
#   "Producer": "OKÄNT"
# }
#
# {
#   "konsert_datum": "20.04.08",
#   "konsert_namn": "Konsert av Hammarby Idrottsförening",
#   "lokal_namn": "Katarina Kyrka",
#   "konsert_biljettpris": "0.50kr, 1kr",
#   "konserttyp_namn": "Välgörenhetskoncert",
#   "Producer": "OKÄNT"
# }
#
# {
#   "konsert_datum": "22.04.08",
#   "konsert_namn": "Konsert",
#   "lokal_namn": "Kungliga Musikaliska Akademiens större sal",
#   "konsert_biljettpris": "3.50kr, 3kr, 2.50kr, 0kr",
#   "konserttyp_namn": "Konsert",
#   "Producer": "OKÄNT"
# }
#
# {
#   "konsert_datum": "25.04.08",
#   "konsert_namn": "HÖGTIDSSAL",
#   "lokal_namn": "Restaurant Runans Festvåning",
#   "konsert_biljettpris": "1.50kr",
#   "konserttyp_namn": "Konsert",
#   "Producer": "Östgöta-Gillet, Folkdansklubben"
# }
# Failed to decode JSON content: {
#   "konsert_datum": “23.04.08",
#   "konsert_namn": "Kaffe-Aftonkonsert",
#   "lokal_namn": "Restaurang METROP",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Orkesterkonsert",
#   "Producer": "Halldén, Björn"
# }
# Failed to decode JSON content: {
#   "konsert_datum": "05.05.08",
#   "konsert_namn": "Maja Köhler konsert",
#   "lokal_namn": "Aeolian Hall",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Sångkonsert",
#   "Producer": "UNKNOWN"
# }
#
# {
#   "konsert_datum": "UNKNOWN",
#   "konsert_namn": "K F U M körens konsert",
#   "lokal_namn": "Östermalms kyrka",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Körkonsert",
#   "Producer": "UNKNOWN"
# }
#
# {
#   "konsert_datum": "UNKNOWN",
#   "konsert_namn": "Nya Filharmoniska sällskapets konsert",
#   "lokal_namn": "UNKNOWN",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Symfonikonsert",
#   "Producer": "UNKNOWN"
# }
#
# {
#   "konsert_datum": "21.02.08",
#   "konsert_namn": "Vivien Chartres afskedskonsert",
#   "lokal_namn": "Kungliga musikaliska akademiens lokal",
#   "konsert_biljettpris": "2:50kr, 2kr, 1kr",
#   "konserttyp_namn": "Solokonsert",
#   "Producer": "Gellin, Eduard"
# }
# Failed to decode JSON content: {
#   "konsert_datum": "25.04.08",
#   "konsert_namn": "Dramatisk-Musikalisk soaré",
#   "lokal_namn": "Dramatiska Teatern",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Förmånskonsert",
#   "Producer": "UNKNOWN"
# }{
#   "konsert_datum": "25.04.08",
#   "konsert_namn": "Imperia",
#   "lokal_namn": "Dramatiska Teatern",
#   "konsert_biljettpris": "Operans vanliga priser",
#   "konserttyp_namn": "Versdrama",
#   "Producer": "Lidman, Sven"
# }{
#   "konsert_datum": "25.04.08",
#   "konsert_namn": "MUSETTE (La petite Bohéme)",
#   "lokal_namn": "Oscars-Teatern",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Operett",
#   "Producer": "UNKNOWN"
# }{
#   "konsert_datum": "25.04.08",
#   "konsert_namn": "AMATÖRTJUFVEN",
#   "lokal_namn": "Vasa-Teatern",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Gästuppträdande",
#   "Producer": "Dinesen, Robert"
# }{
#   "konsert_datum": "25.04.08",
#   "konsert_namn": "En Rödhårig",
#   "lokal_namn": "Södra Teatern",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Mons",
#   "Producer": "UNKNOWN"
# }{
#   "konsert_datum": "25.04.08",
#   "konsert_namn": "Gästuppträdande af Herr Axel Engdahls sällskap från Göteborg",
#   "lokal_namn": "Östermalmsteatern",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Gästuppträdande",
#   "Producer": "Engdahls sällskap från Göteborg"
# }{
#   "konsert_datum": "25.04.08",
#   "konsert_namn": "PASK",
#   "lokal_namn": "Intima Teatern",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Okänt",
#   "Producer": "UNKNOWN"
# }{
#   "konsert_datum": "25.04.08",
#   "konsert_namn": "LILLA FRUN",
#   "lokal_namn": "Folk-Teatern",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Operett",
#   "Producer": "UNKNOWN"
# }{
#   "konsert_datum": "25.04.08",
#   "konsert_namn": "NYÅRSPROGRAMMET",
#   "lokal_namn": "Folkets Hus Teater",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Okänt",
#   "Producer": "UNKNOWN"
# }{
#   "konsert_datum": "25.04.08",
#   "konsert_namn": "Salig Bång",
#   "lokal_namn": "Alhambra-Teatern",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Vaudeville-operett",
#   "Producer": "UNKNOWN"
# }
# Failed to decode JSON content: {
#   "konsert_datum": "23.09.08",
#   "konsert_namn": "Hordens stjärna",
#   "lokal_namn": "Kungl. Teatern",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Opera",
#   "Producer": "UNKNOWN"
# }
#
# {
#   "konsert_datum": "23.09.08",
#   "konsert_namn": "Syndafloden",
#   "lokal_namn": "Kungl. Dramatiska Teatern",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Teater",
#   "Producer": "UNKNOWN"
# }
#
# {
#   "konsert_datum": "23.09.08",
#   "konsert_namn": "Simson",
#   "lokal_namn": "Svenska Teatern",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Teater",
#   "Producer": "UNKNOWN"
# }
#
# {
#   "konsert_datum": "23.09.08",
#   "konsert_namn": "Flickorna Jacksson",
#   "lokal_namn": "OSCARSTEATERN",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Teater",
#   "Producer": "UNKNOWN"
# }
#
# {
#   "konsert_datum": "23.09.08",
#   "konsert_namn": "Blåa Rättan",
#   "lokal_namn": "Södra Teatern",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Teater",
#   "Producer": "UNKNOWN"
# }
#
# {
#   "konsert_datum": "23.09.08",
#   "konsert_namn": "Ett köpmanshus i skärgården",
#   "lokal_namn": "Östermalms-Teatern",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Teater",
#   "Producer": "UNKNOWN"
# }
# Failed to decode JSON content: {
#   "konsert_datum": "30.09.08",
#   "konsert_namn": "Middags- och Aftonkonsert",
#   "lokal_namn": "Hamburger Börs",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Konsert",
#   "Producer": "IV ALD VA UMA \S Kapell"
# }
# Failed to decode JSON content: {
#   "konsert_datum": "15.09.08",
#   "konsert_namn": "Maria Avani-Carreras konsert",
#   "lokal_namn": "Kungliga Musikaliska Akademiens stora sal",
#   "konsert_biljettpris": "3kr, 2:50kr, 2kr, 1:50kr",
#   "konserttyp_namn": "Solokonsert",
#   "Producer": "Avani-Carreras, Maria"
# }
#
# {
#   "konsert_datum": "21.09.08",
#   "konsert_namn": "D:r Ludwig Wiillners Isa konsert",
#   "lokal_namn": "Kungliga Musikaliska Akademiens stora sal",
#   "konsert_biljettpris": "3kr, 2:50kr, 2kr, 1:50kr",
#   "konserttyp_namn": "Solokonsert",
#   "Producer": "Wiillner, Ludwig"
# }
# Failed to decode JSON content: {
#   "konsert_datum": “21.09.08",
#   "konsert_namn": "Natte Halldéns stråkkapell kaffe- & aftonkonsert",
#   "lokal_namn": "Restaurang Metropol",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Kaffe- & aftonkonsert",
#   "Producer": "Halldén, Natte"
# }
# Failed to decode JSON content: {
#   "konsert_datum": “14.10.08",
#   "konsert_namn": "Den stora tallosén",
#   "lokal_namn": "Brunkebergs-Teatern, matsalen",
#   "konsert_biljettpris": "0.25kr, 0.50kr, 0.75kr",
#   "konserttyp_namn": "Extranummer",
#   "Producer": "UNKNOWN"
# }
# Failed to decode JSON content: {
#   "konsert_datum": “11.10.08",
#   "konsert_namn": "Mångsidig populär konsert",
#   "lokal_namn": "Vetenskapsakademien",
#   "konsert_biljettpris": "50 öre",
#   "konserttyp_namn": "Mångsidig konsert",
#   "Producer": "Hansson, Axel"
# }
# Failed to decode JSON content: {
#   "konsert_datum": "12.10.08",
#   "konsert_namn": "Alexander Heinemanns 2:a konsert",
#   "lokal_namn": "Kungliga musikaliska akademiens stora sal",
#   "konsert_biljettpris": "3kr, 2:50kr, 2kr, 1:50kr",
#   "konserttyp_namn": "Solokonsert",
#   "Producer": "Heinemann, Alexander"
# }
# {
#   "konsert_datum": "14.10.08",
#   "konsert_namn": "Kathleen Parlows Solokonsert",
#   "lokal_namn": "Kungliga vetenskapsakademiens hörsal",
#   "konsert_biljettpris": "3kr, 2:50kr, 2kr, 1:50kr",
#   "konserttyp_namn": "Solokonsert",
#   "Producer": "UNKNOWN"
# }
# Failed to decode JSON content: {
#   "konsert_datum": “10.10.08",
#   "konsert_namn": "Wiarkonsertensemblens konsert",
#   "lokal_namn": "UNKNOWN",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Ensemblekonsert",
#   "Producer": "Trautmann, Karl"
# }
# Failed to decode JSON content: {
#   "konsert_datum": "08.02.08",
#   "konsert_namn": "Vivien Chartres afskedskonsert",
#   "lokal_namn": "Kungliga musikaliska akademiens storasal",
#   "konsert_biljettpris": "2:50 kr, 2 kr, 1:50 kr",
#   "konserttyp_namn": "Solokonsert",
#   "Producer": "Gellin, Eduard"
# }
# {
#   "konsert_datum": "08.03.15",
#   "konsert_namn": "Aok‡, Aino",
#   "lokal_namn": "Musikaliska akademien",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Operakonsert",
#   "Producer": "UNKNOWN"
# }
# {
#   "konsert_datum": "08.03.06",
#   "konsert_namn": "Parlow, Kathleen",
#   "lokal_namn": "Musikaliska akademien",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Violinkonsert",
#   "Producer": "UNKNOWN"
# }
# {
#   "konsert_datum": "08.03.09",
#   "konsert_namn": "Heinemann, Alexander",
#   "lokal_namn": "Musikaliska akademien",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Liedersångkonsert",
#   "Producer": "UNKNOWN"
# }
# Failed to decode JSON content: {
#   "konsert_datum": “03.10.08",
#   "konsert_namn": "Rasselbacketi",
#   "lokal_namn": "Clastäckta verandor",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Konsert",
#   "Producer": "WintiEescu, Ceorgi"
# }
# Failed to decode JSON content: {
#   "konsert_datum": "23.11.08",
#   "konsert_namn": "Teresa Correnos 2:a Konsert",
#   "lokal_namn": "UNKNOWN",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Konsert",
#   "Producer": "UNKNOWN"
# }
#
# {
#   "konsert_datum": "25.11.08",
#   "konsert_namn": "Teresa Correnos 3:e och sista Konserten",
#   "lokal_namn": "UNKNOWN",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Konsert",
#   "Producer": "UNKNOWN"
# }
# Failed to decode JSON content: {
#   "konsert_datum": "17.10.08",
#   "konsert_namn": "Sex Kammarmusik-Konserter",
#   "lokal_namn": "K. F. U. K:s nya sal",
#   "konsert_biljettpris": "10kr (abonnemang), 10kr (sittplats), 8kr (läktare)",
#   "konserttyp_namn": "Kammarmusik",
#   "Producer": "Gellin, Eduard"
# }
#
# {
#   "konsert_datum": "17.10.08",
#   "konsert_namn": "Syndafloden",
#   "lokal_namn": "Kungliga Dramatiska Teatern",
#   "konserttyp_namn": "Teaterföreställning",
#   "Producer": "UNKNOWN"
# }
#
# {
#   "konsert_datum": "17.10.08",
#   "konsert_namn": "Mrs Wärrens yrke",
#   "lokal_namn": "Svenska Teatern",
#   "konserttyp_namn": "Teaterföreställning",
#   "Producer": "UNKNOWN"
# }
#
# {
#   "konsert_datum": "17.10.08",
#   "konsert_namn": "Flickorna Jacksson",
#   "lokal_namn": "Oscars-teatern",
#   "konserttyp_namn": "Teaterföreställning",
#   "Producer": "UNKNOWN"
# }
#
# {
#   "konsert_datum": "17.10.08",
#   "konsert_namn": "Fröken Josette - min hustru",
#   "lokal_namn": "Vasateatern",
#   "konserttyp_namn": "Teaterföreställning",
#   "Producer": "UNKNOWN"
# }
#
# {
#   "konsert_datum": "17.10.08",
#   "konsert_namn": "Statsrådet Stéen - kvinnornas man",
#   "lokal_namn": "Södra Teatern",
#   "konserttyp_namn": "Teaterföreställning",
#   "Producer": "UNKNOWN"
# }
#
# {
#   "konsert_datum": "17.10.08",
#   "konsert_namn": "Daniel Hjort",
#   "lokal_namn": "Östermalms-Teatern",
#   "konserttyp_namn": "Teaterföreställning",
#   "Producer": "UNKNOWN"
# }
#
# {
#   "konsert_datum": "17.10.08",
#   "konsert_namn": "Sommarflirt",
#   "lokal_namn": "Tolk-teatern",
#   "konserttyp_namn": "Teaterföreställning",
#   "Producer": "UNKNOWN"
# }
#
# {
#   "konsert_datum": "17.10.08",
#   "konsert_namn": "Populärföreställning: Fadren",
#   "lokal_namn": "Intima teatern",
#   "konserttyp_namn": "Teaterföreställning",
#   "Producer": "UNKNOWN"
# }
# Failed to decode JSON content: {
#   "konsert_datum": "17.10.08",
#   "konsert_namn": "Eftermiddagskonsert af Rumäniska Kapellet (»Carmen Sylva»)",
#   "lokal_namn": "Berns' Salonger",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Orkesterkonsert",
#   "Producer": "UNKNOWN"
# }
#
# {
#   "konsert_datum": "17.10.08",
#   "konsert_namn": "Nederländska Dam-Orkestern »Wilhelmina»",
#   "lokal_namn": "Blanchs Café",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Orkesterkonsert",
#   "Producer": "Bekker, Sarro"
# }
# Failed to decode JSON content: {
#   "konsert_datum": “18.10.08",
#   "konsert_namn": "Folk-Konsert",
#   "lokal_namn": "Stockholms Borgarskola",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Folkkonsert",
#   "Producer": "Goria, Achille"
# }
# Failed to decode JSON content: {
#   "konsert_datum": “16.11.08",
#   "konsert_namn": "Kaffe- och Aftonkonsert Italienska Solistkapellet ROMA",
#   "lokal_namn": "Hotel Fenix",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Kaffe- och Aftonkonsert",
#   "producer": "Italienska Solistkapellet ROMA"
# }
# Failed to decode JSON content: {
#   "konsert_datum": "09.10.08",
#   "konsert_namn": "Alexander Heinemann konsert",
#   "lokal_namn": "Kungliga musikaliska akademiens stora sal",
#   "konsert_biljettpris": "3kr, 2:50kr, 2kr, 1:50kr",
#   "konserttyp_namn": "Solokonsert",
#   "Producer": "UNKNOWN"
# }
#
# {
#   "konsert_datum": "14.10.08",
#   "konsert_namn": "Kathleen Parlows konsert",
#   "lokal_namn": "Kungliga musikaliska akademiens stora sal",
#   "konsert_biljettpris": "3kr, 2:50kr, 2kr, 1:50kr",
#   "konserttyp_namn": "Solokonsert",
#   "Producer": "UNKNOWN"
# }
# Failed to decode JSON content: {
#   "konsert_datum": "17.12.08",
#   "konsert_namn": "Hus Auktion",
#   "lokal_namn": "Huset nr 4 vid Hofslagaregatan (f.d. norska ministerhotellet)",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Auktion",
#   "Producer": "UNKNOWN"
# }
#
# {
#   "konsert_datum": "09.12.08",
#   "konsert_namn": "Nordens stjärna",
#   "lokal_namn": "Kungliga Teatern",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Cästuppträdande",
#   "Producer": "UNKNOWN"
# }
#
# {
#   "konsert_datum": "16.12.08",
#   "konsert_namn": "Cästuppträdande av Fru Ragna Wettergren",
#   "lokal_namn": "Svenska Teatern",
#   "konsert_biljettpris": "UNKNOWN",
#   "konserttyp_namn": "Cästuppträdande",
#   "Producer": "UNKNOWN"
# }
# Failed to decode JSON content: {
#   "konsert_datum": “06.10.08",
#   "konsert_namn": "Middags- och Aftonkonsert",
#   "lokal_namn": "Mosebacke Restaurant",
#   "konsert_biljettpris": "1:25kr",
#   "konserttyp_namn": "Middags- och Aftonkonsert",
#   "Producer": "UNKNOWN"
# }
# JSON file successfully saved.
