# %%
import pandas as pd
from fuzzywuzzy import fuzz, process
import re
from datetime import datetime

# Load XLS file 
xls_path = 'All_Concerts_1908_filtered.xlsx'
xls_df = pd.read_excel(xls_path)

# Display the first few rows of the loaded DataFrame to verify
#print(xls_df.head(10))

# Load JSON file
json_path = 'Datasets/SD_DN_AB_1908_concerts_LLM.json'
json_df = pd.read_json(json_path)

# Verify the loaded JSON data
#print(json_df.head(3))

# Identify relevant columns
relevant_columns = ['konsert_datum', 'konsert_namn', 'lokal_namn', 'konsert_biljettpris', 'konserttyp_namn', 'Producer']

# Filter relevant columns
xls_df = xls_df[relevant_columns]
json_df = json_df[relevant_columns]

# Function to normalize text
def normalize(text):
    if pd.isna(text) or text.strip().lower() == "unknown":  # Handle NaN values and "UNKNOWN"
        return ""
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'[-,]', ' ', text)  # Replace hyphens and commas with spaces
    text = re.sub(r'\s+', ' ', text)  # Replace multiple spaces with a single space
    text = text.strip()  # Remove leading and trailing spaces
    return text

# Function to normalize dates
def normalize_date(date):
    try:
        # Try to parse the date from different formats
        if isinstance(date, str):
            if re.match(r'\d{2}\.\d{2}\.\d{2}', date):  # Format: DD.MM.YY
                date_obj = datetime.strptime(date, '%d.%m.%y')
                if date_obj.year >= 2000:
                    date_obj = date_obj.replace(year=date_obj.year - 100)
            elif re.match(r'\d{4}\.\d{2}\.\d{2}', date):  # Format: YYYY.MM.DD
                date_obj = datetime.strptime(date, '%Y.%m.%d')
            elif re.match(r'\d{2}\.\d{2}\.\d{4}', date):  # Format: DD.MM.YYYY
                date_obj = datetime.strptime(date, '%d.%m.%Y')
            else:
                return ""
        elif isinstance(date, datetime):
            date_obj = date
        else:
            return ""
        return date_obj.strftime('%Y-%m-%d')  # Convert to "YYYY-MM-DD"
    except ValueError:
        return ""

# Normalize 'UNKNOWN' values and dates in both dataframes
xls_df = xls_df.replace('UNKNOWN', '')
json_df = json_df.replace('UNKNOWN', '')
xls_df['normalized_konsert_datum'] = xls_df['konsert_datum'].apply(normalize_date)
json_df['normalized_konsert_datum'] = json_df['konsert_datum'].apply(normalize_date)

# Normalize all text columns in both dataframes
for col in xls_df.columns:
    if xls_df[col].dtype == 'object':  # Apply only to text columns
        xls_df[col] = xls_df[col].apply(normalize)

for col in json_df.columns:
    if json_df[col].dtype == 'object':  # Apply only to text columns
        json_df[col] = json_df[col].apply(normalize)

# Columns to compare (excluding date)
columns_to_compare = ['konsert_namn', 'lokal_namn', 'konsert_biljettpris', 'konserttyp_namn', 'Producer']

# Assign weights to each column based on their importance
weights = {
    'konsert_namn': 0.4,  # 40% of the total importance
    'lokal_namn': 0.4, 
    'konsert_biljettpris': 0.1,
    'konserttyp_namn': 0.1,
    'Producer': 0.2
}

def compare_rows_on_date(date, df1, df2, columns, weights):
    rows1 = df1[df1['normalized_konsert_datum'] == date]
    rows2 = df2[df2['normalized_konsert_datum'] == date]
    comparison_results = []

    for idx2, row2 in rows2.iterrows():
        overall_match_score = 0
        best_match_idx1 = None
        best_match_date = None
        overall_match_scores = {}  # Ensure this is initialized before use

        for idx1, row1 in rows1.iterrows():
            total_weighted_score = 0
            column_scores = {}  # Initialize it here within the loop before use

            for col in columns:
                score = fuzz.token_sort_ratio(row1[col], row2[col])
                weighted_score = score * weights[col]
                total_weighted_score += weighted_score
                column_scores[col] = score

            if total_weighted_score > overall_match_score:
                overall_match_score = total_weighted_score
                best_match_idx1 = idx1
                best_match_date = row1['konsert_datum']
                overall_match_scores = column_scores  # Only set this if a new best score is found

        if best_match_idx1 is not None:  # Ensure that we have a valid match before appending
            comparison_results.append({
                'original_date': best_match_date,  # Include the original date in the result
                'json_row_index': idx2,
                'xls_row_index': best_match_idx1,
                'overall_match_score': overall_match_score,
                **overall_match_scores  # Safely add scores as they are now always initialized
            })

    return comparison_results


# Group rows by normalized date and compare
all_comparison_results = []
unique_dates = pd.concat([xls_df['normalized_konsert_datum'], json_df['normalized_konsert_datum']]).unique()

for date in unique_dates:
    if date:  # Ensure date is not empty
        comparison_results = compare_rows_on_date(date, xls_df, json_df, columns_to_compare, weights)
        all_comparison_results.extend(comparison_results)

# Analyze results
for result in all_comparison_results:
    # Updated the key to 'json_row_index' which is the correct key being used in the dictionary
    print(f"Row index in LLM data: {result['json_row_index']}")
    # Key 'best_match_index' is correct as per the creation of the dictionary
    print(f"Best match row index in human data: {result['xls_row_index']}")
    # Key 'overall_match_score' is also correct
    print(f"Best match score: {result['overall_match_score']}")
    # Print detailed scores for each column
    for col, score in result.items():
        if col in ['json_row_index', 'xls_row_index', 'overall_match_score', 'original_date']:
            continue  # Skip the non-score keys
        print(f"  {col}: {score}")
    print()  # Add a newline for better readability between entries


# Convert comparison results to DataFrame for further analysis
comparison_df = pd.DataFrame(all_comparison_results)

# Generate a date-based report name
report_date = datetime.now().strftime('%Y-%m-%d')

# Save the comparison results to a CSV file
comparison_file_name = f'detailed_comparison_results_{report_date}.csv'
comparison_df.to_csv(comparison_file_name, index=False)

# Correctly reference the DataFrame keys when looking for unique concerts
def find_unique_dates(df1, df2, threshold=80):
    comparison_df = pd.DataFrame(all_comparison_results)
    unique_to_llm = comparison_df[comparison_df['overall_match_score'] < threshold]
    matched_indices = comparison_df[comparison_df['overall_match_score'] >= threshold]['xls_row_index'].unique()
    unique_to_human = df1[~df1.index.isin(matched_indices)]
    return unique_to_llm, unique_to_human

# Find unique concerts based on dates
unique_llm_dates, unique_human_dates = find_unique_dates(xls_df, json_df)

# Correcting the column names for displaying unique concerts
print(f"\nUnique concerts found by LLM but not by human (total {len(unique_llm_dates)}):")
# Ensure that 'json_row_index' is used instead of 'index'
print(unique_llm_dates[['json_row_index', 'overall_match_score']])

print(f"\nUnique concerts found by human but not by LLM (total {len(unique_human_dates)}):")
print(unique_human_dates[['konsert_datum']])



# Saving results to CSV with the correct DataFrame structure
unique_llm_file_name = f'unique_to_llm_concerts_{report_date}.csv'
unique_human_file_name = f'unique_to_human_concerts_{report_date}.csv'
unique_llm_dates.to_csv(unique_llm_file_name, index=False)
unique_human_dates.to_csv(unique_human_file_name, index=False)
# Out:
# Row index in LLM data: 666
# Best match row index in human data: 0
# Best match score: 31.6
#   konsert_namn: 23
#   lokal_namn: 17
#   konsert_biljettpris: 100
#   konserttyp_namn: 56
#   Producer: 0
#
# Row index in LLM data: 668
# Best match row index in human data: 0
# Best match score: 37.2
#   konsert_namn: 38
#   lokal_namn: 17
#   konsert_biljettpris: 100
#   konserttyp_namn: 52
#   Producer: 0
#
# Row index in LLM data: 671
# Best match row index in human data: 0
# Best match score: 52.7
#   konsert_namn: 30
#   lokal_namn: 79
#   konsert_biljettpris: 0
#   konserttyp_namn: 55
#   Producer: 18
#
# Row index in LLM data: 433
# Best match row index in human data: 1
# Best match score: 75.30000000000001
#   konsert_namn: 53
#   lokal_namn: 100
#   konsert_biljettpris: 55
#   konserttyp_namn: 22
#   Producer: 32
#
# Row index in LLM data: 434
# Best match row index in human data: 1
# Best match score: 88.30000000000001
#   konsert_namn: 66
#   lokal_namn: 100
#   konsert_biljettpris: 55
#   konserttyp_namn: 100
#   Producer: 32
#
# Row index in LLM data: 488
# Best match row index in human data: 1
# Best match score: 75.30000000000001
#   konsert_namn: 53
#   lokal_namn: 100
#   konsert_biljettpris: 55
#   konserttyp_namn: 22
#   Producer: 32
#
# Row index in LLM data: 489
# Best match row index in human data: 1
# Best match score: 88.30000000000001
#   konsert_namn: 66
#   lokal_namn: 100
#   konsert_biljettpris: 55
#   konserttyp_namn: 100
#   Producer: 32
#
# Row index in LLM data: 667
# Best match row index in human data: 1
# Best match score: 96.30000000000001
#   konsert_namn: 61
#   lokal_namn: 98
#   konsert_biljettpris: 53
#   konserttyp_namn: 74
#   Producer: 100
#
# Row index in LLM data: 1022
# Best match row index in human data: 1
# Best match score: 47.0
#   konsert_namn: 33
#   lokal_namn: 24
#   konsert_biljettpris: 0
#   konserttyp_namn: 42
#   Producer: 100
#
# Row index in LLM data: 1023
# Best match row index in human data: 1
# Best match score: 66.2
#   konsert_namn: 53
#   lokal_namn: 79
#   konsert_biljettpris: 0
#   konserttyp_namn: 70
#   Producer: 32
#
# Row index in LLM data: 1024
# Best match row index in human data: 4
# Best match score: 70.39999999999999
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 0
#   konserttyp_namn: 48
#   Producer: 24
#
# Row index in LLM data: 1027
# Best match row index in human data: 3
# Best match score: 66.30000000000001
#   konsert_namn: 54
#   lokal_namn: 20
#   konsert_biljettpris: 100
#   konserttyp_namn: 67
#   Producer: 100
#
# Row index in LLM data: 1025
# Best match row index in human data: 8
# Best match score: 82.3
#   konsert_namn: 100
#   lokal_namn: 59
#   konsert_biljettpris: 81
#   konserttyp_namn: 48
#   Producer: 29
#
# Row index in LLM data: 87
# Best match row index in human data: 9
# Best match score: 68.6
#   konsert_namn: 49
#   lokal_namn: 90
#   konsert_biljettpris: 33
#   konserttyp_namn: 97
#   Producer: 0
#
# Row index in LLM data: 435
# Best match row index in human data: 9
# Best match score: 86.9
#   konsert_namn: 49
#   lokal_namn: 100
#   konsert_biljettpris: 39
#   konserttyp_namn: 100
#   Producer: 67
#
# Row index in LLM data: 490
# Best match row index in human data: 9
# Best match score: 86.9
#   konsert_namn: 49
#   lokal_namn: 100
#   konsert_biljettpris: 39
#   konserttyp_namn: 100
#   Producer: 67
#
# Row index in LLM data: 1026
# Best match row index in human data: 9
# Best match score: 75.5
#   konsert_namn: 35
#   lokal_namn: 85
#   konsert_biljettpris: 44
#   konserttyp_namn: 97
#   Producer: 67
#
# Row index in LLM data: 1011
# Best match row index in human data: 11
# Best match score: 35.400000000000006
#   konsert_namn: 23
#   lokal_namn: 46
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 657
# Best match row index in human data: 12
# Best match score: 43.2
#   konsert_namn: 69
#   lokal_namn: 29
#   konsert_biljettpris: 0
#   konserttyp_namn: 40
#   Producer: 0
#
# Row index in LLM data: 658
# Best match row index in human data: 12
# Best match score: 40.2
#   konsert_namn: 61
#   lokal_namn: 22
#   konsert_biljettpris: 0
#   konserttyp_namn: 70
#   Producer: 0
#
# Row index in LLM data: 659
# Best match row index in human data: 12
# Best match score: 37.2
#   konsert_namn: 37
#   lokal_namn: 25
#   konsert_biljettpris: 0
#   konserttyp_namn: 56
#   Producer: 34
#
# Row index in LLM data: 961
# Best match row index in human data: 12
# Best match score: 94.2
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 963
# Best match row index in human data: 12
# Best match score: 46.2
#   konsert_namn: 71
#   lokal_namn: 25
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 964
# Best match row index in human data: 12
# Best match score: 45.7
#   konsert_namn: 60
#   lokal_namn: 39
#   konsert_biljettpris: 0
#   konserttyp_namn: 61
#   Producer: 0
#
# Row index in LLM data: 965
# Best match row index in human data: 12
# Best match score: 38.2
#   konsert_namn: 55
#   lokal_namn: 30
#   konsert_biljettpris: 0
#   konserttyp_namn: 42
#   Producer: 0
#
# Row index in LLM data: 656
# Best match row index in human data: 13
# Best match score: 63.2
#   konsert_namn: 100
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 16
#
# Row index in LLM data: 26
# Best match row index in human data: 16
# Best match score: 35.2
#   konsert_namn: 49
#   lokal_namn: 39
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 27
# Best match row index in human data: 16
# Best match score: 37.0
#   konsert_namn: 43
#   lokal_namn: 19
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 29
#
# Row index in LLM data: 28
# Best match row index in human data: 17
# Best match score: 40.6
#   konsert_namn: 43
#   lokal_namn: 27
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 13
#
# Row index in LLM data: 415
# Best match row index in human data: 16
# Best match score: 50.80000000000001
#   konsert_namn: 42
#   lokal_namn: 29
#   konsert_biljettpris: 100
#   konserttyp_namn: 52
#   Producer: 36
#
# Row index in LLM data: 416
# Best match row index in human data: 16
# Best match score: 48.60000000000001
#   konsert_namn: 52
#   lokal_namn: 39
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 29
#
# Row index in LLM data: 470
# Best match row index in human data: 16
# Best match score: 50.80000000000001
#   konsert_namn: 42
#   lokal_namn: 29
#   konsert_biljettpris: 100
#   konserttyp_namn: 52
#   Producer: 36
#
# Row index in LLM data: 471
# Best match row index in human data: 16
# Best match score: 48.60000000000001
#   konsert_namn: 52
#   lokal_namn: 39
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 29
#
# Row index in LLM data: 941
# Best match row index in human data: 16
# Best match score: 90.00000000000001
#   konsert_namn: 82
#   lokal_namn: 85
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 27
#
# Row index in LLM data: 942
# Best match row index in human data: 16
# Best match score: 17.400000000000002
#   konsert_namn: 24
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 946
# Best match row index in human data: 16
# Best match score: 38.50000000000001
#   konsert_namn: 41
#   lokal_namn: 26
#   konsert_biljettpris: 65
#   konserttyp_namn: 52
#   Producer: 0
#
# Row index in LLM data: 947
# Best match row index in human data: 16
# Best match score: 32.6
#   konsert_namn: 35
#   lokal_namn: 17
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 27
#
# Row index in LLM data: 962
# Best match row index in human data: 16
# Best match score: 62.800000000000004
#   konsert_namn: 36
#   lokal_namn: 60
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 33
#
# Row index in LLM data: 1012
# Best match row index in human data: 16
# Best match score: 51.1
#   konsert_namn: 40
#   lokal_namn: 60
#   konsert_biljettpris: 100
#   konserttyp_namn: 11
#   Producer: 0
#
# Row index in LLM data: 40
# Best match row index in human data: 18
# Best match score: 36.00000000000001
#   konsert_namn: 26
#   lokal_namn: 22
#   konsert_biljettpris: 26
#   konserttyp_namn: 76
#   Producer: 33
#
# Row index in LLM data: 44
# Best match row index in human data: 18
# Best match score: 27.8
#   konsert_namn: 14
#   lokal_namn: 36
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 414
# Best match row index in human data: 18
# Best match score: 57.199999999999996
#   konsert_namn: 35
#   lokal_namn: 67
#   konsert_biljettpris: 18
#   konserttyp_namn: 80
#   Producer: 33
#
# Row index in LLM data: 469
# Best match row index in human data: 18
# Best match score: 57.199999999999996
#   konsert_namn: 35
#   lokal_namn: 67
#   konsert_biljettpris: 18
#   konserttyp_namn: 80
#   Producer: 33
#
# Row index in LLM data: 4
# Best match row index in human data: 19
# Best match score: 61.800000000000004
#   konsert_namn: 33
#   lokal_namn: 60
#   konsert_biljettpris: 100
#   konserttyp_namn: 22
#   Producer: 62
#
# Row index in LLM data: 7
# Best match row index in human data: 19
# Best match score: 38.8
#   konsert_namn: 35
#   lokal_namn: 29
#   konsert_biljettpris: 0
#   konserttyp_namn: 74
#   Producer: 29
#
# Row index in LLM data: 23
# Best match row index in human data: 20
# Best match score: 49.699999999999996
#   konsert_namn: 62
#   lokal_namn: 20
#   konsert_biljettpris: 43
#   konserttyp_namn: 72
#   Producer: 27
#
# Row index in LLM data: 41
# Best match row index in human data: 19
# Best match score: 72.39999999999999
#   konsert_namn: 42
#   lokal_namn: 100
#   konsert_biljettpris: 100
#   konserttyp_namn: 56
#   Producer: 0
#
# Row index in LLM data: 402
# Best match row index in human data: 19
# Best match score: 56.1
#   konsert_namn: 11
#   lokal_namn: 100
#   konsert_biljettpris: 71
#   konserttyp_namn: 46
#   Producer: 0
#
# Row index in LLM data: 457
# Best match row index in human data: 19
# Best match score: 56.1
#   konsert_namn: 11
#   lokal_namn: 100
#   konsert_biljettpris: 71
#   konserttyp_namn: 46
#   Producer: 0
#
# Row index in LLM data: 660
# Best match row index in human data: 19
# Best match score: 76.00000000000001
#   konsert_namn: 48
#   lokal_namn: 100
#   konsert_biljettpris: 94
#   konserttyp_namn: 24
#   Producer: 25
#
# Row index in LLM data: 998
# Best match row index in human data: 19
# Best match score: 41.0
#   konsert_namn: 27
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 74
#   Producer: 0
#
# Row index in LLM data: 1003
# Best match row index in human data: 19
# Best match score: 40.0
#   konsert_namn: 33
#   lokal_namn: 25
#   konsert_biljettpris: 10
#   konserttyp_namn: 100
#   Producer: 29
#
# Row index in LLM data: 3
# Best match row index in human data: 21
# Best match score: 89.4
#   konsert_namn: 99
#   lokal_namn: 54
#   konsert_biljettpris: 100
#   konserttyp_namn: 58
#   Producer: 62
#
# Row index in LLM data: 43
# Best match row index in human data: 21
# Best match score: 85.60000000000001
#   konsert_namn: 95
#   lokal_namn: 71
#   konsert_biljettpris: 100
#   konserttyp_namn: 58
#   Producer: 17
#
# Row index in LLM data: 401
# Best match row index in human data: 21
# Best match score: 60.400000000000006
#   konsert_namn: 87
#   lokal_namn: 32
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 14
#
# Row index in LLM data: 456
# Best match row index in human data: 21
# Best match score: 60.400000000000006
#   konsert_namn: 87
#   lokal_namn: 32
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 14
#
# Row index in LLM data: 641
# Best match row index in human data: 21
# Best match score: 90.4
#   konsert_namn: 99
#   lokal_namn: 71
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 62
#
# Row index in LLM data: 652
# Best match row index in human data: 23
# Best match score: 75.4
#   konsert_namn: 30
#   lokal_namn: 88
#   konsert_biljettpris: 0
#   konserttyp_namn: 82
#   Producer: 100
#
# Row index in LLM data: 952
# Best match row index in human data: 23
# Best match score: 97.00000000000001
#   konsert_namn: 71
#   lokal_namn: 100
#   konsert_biljettpris: 44
#   konserttyp_namn: 42
#   Producer: 100
#
# Row index in LLM data: 959
# Best match row index in human data: 22
# Best match score: 53.599999999999994
#   konsert_namn: 81
#   lokal_namn: 16
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 24
#
# Row index in LLM data: 968
# Best match row index in human data: 22
# Best match score: 50.5
#   konsert_namn: 64
#   lokal_namn: 26
#   konsert_biljettpris: 25
#   konserttyp_namn: 56
#   Producer: 32
#
# Row index in LLM data: 5
# Best match row index in human data: 28
# Best match score: 75.60000000000001
#   konsert_namn: 42
#   lokal_namn: 89
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 16
#
# Row index in LLM data: 25
# Best match row index in human data: 28
# Best match score: 73.4
#   konsert_namn: 40
#   lokal_namn: 89
#   konsert_biljettpris: 100
#   konserttyp_namn: 86
#   Producer: 16
#
# Row index in LLM data: 78
# Best match row index in human data: 28
# Best match score: 71.0
#   konsert_namn: 42
#   lokal_namn: 89
#   konsert_biljettpris: 86
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 404
# Best match row index in human data: 28
# Best match score: 64.0
#   konsert_namn: 46
#   lokal_namn: 89
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 439
# Best match row index in human data: 28
# Best match score: 62.8
#   konsert_namn: 43
#   lokal_namn: 89
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 459
# Best match row index in human data: 28
# Best match score: 64.0
#   konsert_namn: 46
#   lokal_namn: 89
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 494
# Best match row index in human data: 28
# Best match score: 62.8
#   konsert_namn: 43
#   lokal_namn: 89
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 943
# Best match row index in human data: 28
# Best match score: 77.60000000000001
#   konsert_namn: 42
#   lokal_namn: 89
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 26
#
# Row index in LLM data: 948
# Best match row index in human data: 28
# Best match score: 42.7
#   konsert_namn: 45
#   lokal_namn: 48
#   konsert_biljettpris: 0
#   konserttyp_namn: 55
#   Producer: 0
#
# Row index in LLM data: 949
# Best match row index in human data: 28
# Best match score: 47.00000000000001
#   konsert_namn: 41
#   lokal_namn: 55
#   konsert_biljettpris: 0
#   konserttyp_namn: 56
#   Producer: 15
#
# Row index in LLM data: 950
# Best match row index in human data: 25
# Best match score: 82.4
#   konsert_namn: 65
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 951
# Best match row index in human data: 28
# Best match score: 78.0
#   konsert_namn: 51
#   lokal_namn: 94
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 955
# Best match row index in human data: 27
# Best match score: 70.6
#   konsert_namn: 39
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 36
#   Producer: 25
#
# Row index in LLM data: 960
# Best match row index in human data: 24
# Best match score: 81.19999999999999
#   konsert_namn: 100
#   lokal_namn: 44
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 18
#
# Row index in LLM data: 966
# Best match row index in human data: 27
# Best match score: 70.6
#   konsert_namn: 39
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 36
#   Producer: 25
#
# Row index in LLM data: 1002
# Best match row index in human data: 27
# Best match score: 67.0
#   konsert_namn: 44
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 30
#   Producer: 0
#
# Row index in LLM data: 1013
# Best match row index in human data: 27
# Best match score: 90.4
#   konsert_namn: 81
#   lokal_namn: 100
#   konsert_biljettpris: 0
#   konserttyp_namn: 30
#   Producer: 75
#
# Row index in LLM data: 24
# Best match row index in human data: 29
# Best match score: 65.6
#   konsert_namn: 60
#   lokal_namn: 60
#   konsert_biljettpris: 76
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 79
# Best match row index in human data: 29
# Best match score: 87.9
#   konsert_namn: 87
#   lokal_namn: 60
#   konsert_biljettpris: 76
#   konserttyp_namn: 53
#   Producer: 81
#
# Row index in LLM data: 953
# Best match row index in human data: 29
# Best match score: 57.2
#   konsert_namn: 42
#   lokal_namn: 57
#   konsert_biljettpris: 76
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 1000
# Best match row index in human data: 29
# Best match score: 61.6
#   konsert_namn: 42
#   lokal_namn: 52
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 20
#
# Row index in LLM data: 669
# Best match row index in human data: 33
# Best match score: 41.2
#   konsert_namn: 19
#   lokal_namn: 62
#   konsert_biljettpris: 0
#   konserttyp_namn: 88
#   Producer: 0
#
# Row index in LLM data: 670
# Best match row index in human data: 32
# Best match score: 26.6
#   konsert_namn: 32
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 62
#   Producer: 38
#
# Row index in LLM data: 673
# Best match row index in human data: 32
# Best match score: 31.800000000000004
#   konsert_namn: 30
#   lokal_namn: 24
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 12
#
# Row index in LLM data: 53
# Best match row index in human data: 34
# Best match score: 38.800000000000004
#   konsert_namn: 21
#   lokal_namn: 27
#   konsert_biljettpris: 100
#   konserttyp_namn: 18
#   Producer: 39
#
# Row index in LLM data: 975
# Best match row index in human data: 34
# Best match score: 30.8
#   konsert_namn: 22
#   lokal_namn: 25
#   konsert_biljettpris: 100
#   konserttyp_namn: 20
#   Producer: 0
#
# Row index in LLM data: 51
# Best match row index in human data: 39
# Best match score: 49.400000000000006
#   konsert_namn: 42
#   lokal_namn: 47
#   konsert_biljettpris: 83
#   konserttyp_namn: 55
#   Producer: 0
#
# Row index in LLM data: 642
# Best match row index in human data: 39
# Best match score: 45.6
#   konsert_namn: 40
#   lokal_namn: 47
#   konsert_biljettpris: 0
#   konserttyp_namn: 56
#   Producer: 26
#
# Row index in LLM data: 643
# Best match row index in human data: 39
# Best match score: 30.7
#   konsert_namn: 26
#   lokal_namn: 23
#   konsert_biljettpris: 0
#   konserttyp_namn: 69
#   Producer: 21
#
# Row index in LLM data: 644
# Best match row index in human data: 39
# Best match score: 50.2
#   konsert_namn: 44
#   lokal_namn: 62
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 647
# Best match row index in human data: 39
# Best match score: 42.300000000000004
#   konsert_namn: 47
#   lokal_namn: 25
#   konsert_biljettpris: 0
#   konserttyp_namn: 69
#   Producer: 33
#
# Row index in LLM data: 648
# Best match row index in human data: 38
# Best match score: 29.900000000000002
#   konsert_namn: 46
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 55
#   Producer: 30
#
# Row index in LLM data: 911
# Best match row index in human data: 39
# Best match score: 51.10000000000001
#   konsert_namn: 42
#   lokal_namn: 59
#   konsert_biljettpris: 40
#   konserttyp_namn: 67
#   Producer: 0
#
# Row index in LLM data: 913
# Best match row index in human data: 38
# Best match score: 69.4
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 22
#   Producer: 0
#
# Row index in LLM data: 916
# Best match row index in human data: 38
# Best match score: 41.900000000000006
#   konsert_namn: 44
#   lokal_namn: 32
#   konsert_biljettpris: 0
#   konserttyp_namn: 53
#   Producer: 31
#
# Row index in LLM data: 917
# Best match row index in human data: 38
# Best match score: 31.4
#   konsert_namn: 23
#   lokal_namn: 32
#   konsert_biljettpris: 0
#   konserttyp_namn: 30
#   Producer: 32
#
# Row index in LLM data: 967
# Best match row index in human data: 38
# Best match score: 74.39999999999999
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 26
#   konserttyp_namn: 62
#   Producer: 24
#
# Row index in LLM data: 83
# Best match row index in human data: 40
# Best match score: 57.9
#   konsert_namn: 58
#   lokal_namn: 31
#   konsert_biljettpris: 100
#   konserttyp_namn: 69
#   Producer: 27
#
# Row index in LLM data: 84
# Best match row index in human data: 41
# Best match score: 58.4
#   konsert_namn: 23
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 64
#   Producer: 100
#
# Row index in LLM data: 912
# Best match row index in human data: 41
# Best match score: 70.0
#   konsert_namn: 56
#   lokal_namn: 94
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 918
# Best match row index in human data: 41
# Best match score: 63.8
#   konsert_namn: 67
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 70
#   Producer: 100
#
# Row index in LLM data: 944
# Best match row index in human data: 41
# Best match score: 70.0
#   konsert_namn: 56
#   lokal_namn: 94
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 954
# Best match row index in human data: 41
# Best match score: 78.6
#   konsert_namn: 56
#   lokal_namn: 69
#   konsert_biljettpris: 0
#   konserttyp_namn: 86
#   Producer: 100
#
# Row index in LLM data: 969
# Best match row index in human data: 42
# Best match score: 111.60000000000001
#   konsert_namn: 88
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 52
# Best match row index in human data: 44
# Best match score: 60.6
#   konsert_namn: 40
#   lokal_namn: 60
#   konsert_biljettpris: 76
#   konserttyp_namn: 100
#   Producer: 15
#
# Row index in LLM data: 438
# Best match row index in human data: 44
# Best match score: 75.8
#   konsert_namn: 79
#   lokal_namn: 60
#   konsert_biljettpris: 50
#   konserttyp_namn: 100
#   Producer: 26
#
# Row index in LLM data: 493
# Best match row index in human data: 44
# Best match score: 75.8
#   konsert_namn: 79
#   lokal_namn: 60
#   konsert_biljettpris: 50
#   konserttyp_namn: 100
#   Producer: 26
#
# Row index in LLM data: 914
# Best match row index in human data: 44
# Best match score: 74.8
#   konsert_namn: 26
#   lokal_namn: 85
#   konsert_biljettpris: 76
#   konserttyp_namn: 100
#   Producer: 64
#
# Row index in LLM data: 970
# Best match row index in human data: 44
# Best match score: 64.0
#   konsert_namn: 47
#   lokal_namn: 32
#   konsert_biljettpris: 76
#   konserttyp_namn: 100
#   Producer: 74
#
# Row index in LLM data: 50
# Best match row index in human data: 47
# Best match score: 43.7
#   konsert_namn: 44
#   lokal_namn: 32
#   konsert_biljettpris: 42
#   konserttyp_namn: 61
#   Producer: 15
#
# Row index in LLM data: 80
# Best match row index in human data: 46
# Best match score: 49.30000000000001
#   konsert_namn: 79
#   lokal_namn: 0
#   konsert_biljettpris: 68
#   konserttyp_namn: 61
#   Producer: 24
#
# Row index in LLM data: 85
# Best match row index in human data: 46
# Best match score: 52.7
#   konsert_namn: 68
#   lokal_namn: 37
#   konsert_biljettpris: 26
#   konserttyp_namn: 61
#   Producer: 10
#
# Row index in LLM data: 956
# Best match row index in human data: 46
# Best match score: 31.900000000000002
#   konsert_namn: 38
#   lokal_namn: 0
#   konsert_biljettpris: 63
#   konserttyp_namn: 56
#   Producer: 24
#
# Row index in LLM data: 971
# Best match row index in human data: 46
# Best match score: 68.10000000000001
#   konsert_namn: 38
#   lokal_namn: 100
#   konsert_biljettpris: 26
#   konserttyp_namn: 55
#   Producer: 24
#
# Row index in LLM data: 957
# Best match row index in human data: 50
# Best match score: 31.900000000000002
#   konsert_namn: 38
#   lokal_namn: 0
#   konsert_biljettpris: 63
#   konserttyp_namn: 56
#   Producer: 24
#
# Row index in LLM data: 972
# Best match row index in human data: 50
# Best match score: 68.10000000000001
#   konsert_namn: 38
#   lokal_namn: 100
#   konsert_biljettpris: 26
#   konserttyp_namn: 55
#   Producer: 24
#
# Row index in LLM data: 1028
# Best match row index in human data: 52
# Best match score: 66.6
#   konsert_namn: 100
#   lokal_namn: 36
#   konsert_biljettpris: 0
#   konserttyp_namn: 82
#   Producer: 20
#
# Row index in LLM data: 1032
# Best match row index in human data: 53
# Best match score: 34.900000000000006
#   konsert_namn: 30
#   lokal_namn: 32
#   konsert_biljettpris: 0
#   konserttyp_namn: 21
#   Producer: 40
#
# Row index in LLM data: 1033
# Best match row index in human data: 52
# Best match score: 23.7
#   konsert_namn: 15
#   lokal_namn: 21
#   konsert_biljettpris: 0
#   konserttyp_namn: 33
#   Producer: 30
#
# Row index in LLM data: 55
# Best match row index in human data: 55
# Best match score: 73.4
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 0
#   konserttyp_namn: 62
#   Producer: 32
#
# Row index in LLM data: 57
# Best match row index in human data: 56
# Best match score: 38.0
#   konsert_namn: 45
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 100
#
# Row index in LLM data: 568
# Best match row index in human data: 55
# Best match score: 46.800000000000004
#   konsert_namn: 56
#   lokal_namn: 33
#   konsert_biljettpris: 0
#   konserttyp_namn: 62
#   Producer: 25
#
# Row index in LLM data: 676
# Best match row index in human data: 55
# Best match score: 44.400000000000006
#   konsert_namn: 64
#   lokal_namn: 22
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 910
# Best match row index in human data: 56
# Best match score: 40.400000000000006
#   konsert_namn: 26
#   lokal_namn: 42
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 34
#
# Row index in LLM data: 931
# Best match row index in human data: 55
# Best match score: 38.7
#   konsert_namn: 49
#   lokal_namn: 33
#   konsert_biljettpris: 0
#   konserttyp_namn: 59
#   Producer: 0
#
# Row index in LLM data: 933
# Best match row index in human data: 55
# Best match score: 73.6
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 25
#
# Row index in LLM data: 934
# Best match row index in human data: 56
# Best match score: 50.4
#   konsert_namn: 38
#   lokal_namn: 43
#   konsert_biljettpris: 54
#   konserttyp_namn: 62
#   Producer: 32
#
# Row index in LLM data: 939
# Best match row index in human data: 56
# Best match score: 46.5
#   konsert_namn: 55
#   lokal_namn: 42
#   konsert_biljettpris: 0
#   konserttyp_namn: 47
#   Producer: 15
#
# Row index in LLM data: 958
# Best match row index in human data: 56
# Best match score: 42.0
#   konsert_namn: 28
#   lokal_namn: 0
#   konsert_biljettpris: 38
#   konserttyp_namn: 70
#   Producer: 100
#
# Row index in LLM data: 973
# Best match row index in human data: 54
# Best match score: 68.10000000000001
#   konsert_namn: 38
#   lokal_namn: 100
#   konsert_biljettpris: 26
#   konserttyp_namn: 55
#   Producer: 24
#
# Row index in LLM data: 1029
# Best match row index in human data: 56
# Best match score: 66.69999999999999
#   konsert_namn: 37
#   lokal_namn: 43
#   konsert_biljettpris: 83
#   konserttyp_namn: 64
#   Producer: 100
#
# Row index in LLM data: 1031
# Best match row index in human data: 55
# Best match score: 74.5
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 70
#   konserttyp_namn: 67
#   Producer: 0
#
# Row index in LLM data: 56
# Best match row index in human data: 57
# Best match score: 67.4
#   konsert_namn: 59
#   lokal_namn: 64
#   konsert_biljettpris: 100
#   konserttyp_namn: 82
#   Producer: 0
#
# Row index in LLM data: 86
# Best match row index in human data: 60
# Best match score: 73.80000000000001
#   konsert_namn: 22
#   lokal_namn: 94
#   konsert_biljettpris: 0
#   konserttyp_namn: 74
#   Producer: 100
#
# Row index in LLM data: 431
# Best match row index in human data: 59
# Best match score: 111.60000000000001
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 52
#   Producer: 100
#
# Row index in LLM data: 432
# Best match row index in human data: 59
# Best match score: 116.4
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 486
# Best match row index in human data: 59
# Best match score: 111.60000000000001
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 52
#   Producer: 100
#
# Row index in LLM data: 487
# Best match row index in human data: 59
# Best match score: 116.4
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 584
# Best match row index in human data: 57
# Best match score: 55.400000000000006
#   konsert_namn: 41
#   lokal_namn: 53
#   konsert_biljettpris: 44
#   konserttyp_namn: 100
#   Producer: 17
#
# Row index in LLM data: 915
# Best match row index in human data: 58
# Best match score: 50.00000000000001
#   konsert_namn: 31
#   lokal_namn: 41
#   konsert_biljettpris: 100
#   konserttyp_namn: 58
#   Producer: 27
#
# Row index in LLM data: 935
# Best match row index in human data: 59
# Best match score: 96.4
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 936
# Best match row index in human data: 60
# Best match score: 97.2
#   konsert_namn: 61
#   lokal_namn: 94
#   konsert_biljettpris: 100
#   konserttyp_namn: 52
#   Producer: 100
#
# Row index in LLM data: 940
# Best match row index in human data: 58
# Best match score: 58.00000000000001
#   konsert_namn: 96
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 96
#   Producer: 0
#
# Row index in LLM data: 1030
# Best match row index in human data: 59
# Best match score: 97.0
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 70
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 938
# Best match row index in human data: 62
# Best match score: 63.900000000000006
#   konsert_namn: 24
#   lokal_namn: 79
#   konsert_biljettpris: 0
#   konserttyp_namn: 27
#   Producer: 100
#
# Row index in LLM data: 614
# Best match row index in human data: 65
# Best match score: 87.60000000000001
#   konsert_namn: 85
#   lokal_namn: 85
#   konsert_biljettpris: 52
#   konserttyp_namn: 30
#   Producer: 57
#
# Row index in LLM data: 616
# Best match row index in human data: 66
# Best match score: 42.10000000000001
#   konsert_namn: 47
#   lokal_namn: 24
#   konsert_biljettpris: 21
#   konserttyp_namn: 48
#   Producer: 34
#
# Row index in LLM data: 617
# Best match row index in human data: 66
# Best match score: 48.199999999999996
#   konsert_namn: 47
#   lokal_namn: 40
#   konsert_biljettpris: 0
#   konserttyp_namn: 74
#   Producer: 30
#
# Row index in LLM data: 650
# Best match row index in human data: 65
# Best match score: 40.900000000000006
#   konsert_namn: 32
#   lokal_namn: 38
#   konsert_biljettpris: 21
#   konserttyp_namn: 58
#   Producer: 25
#
# Row index in LLM data: 937
# Best match row index in human data: 65
# Best match score: 62.900000000000006
#   konsert_namn: 19
#   lokal_namn: 85
#   konsert_biljettpris: 76
#   konserttyp_namn: 57
#   Producer: 40
#
# Row index in LLM data: 6
# Best match row index in human data: 68
# Best match score: 69.8
#   konsert_namn: 100
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 42
# Best match row index in human data: 68
# Best match score: 67.9
#   konsert_namn: 87
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 57
#   Producer: 23
#
# Row index in LLM data: 54
# Best match row index in human data: 68
# Best match score: 64.9
#   konsert_namn: 94
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 53
#   Producer: 0
#
# Row index in LLM data: 58
# Best match row index in human data: 68
# Best match score: 68.2
#   konsert_namn: 100
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 62
#   Producer: 0
#
# Row index in LLM data: 81
# Best match row index in human data: 68
# Best match score: 39.0
#   konsert_namn: 27
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 62
#   Producer: 0
#
# Row index in LLM data: 405
# Best match row index in human data: 68
# Best match score: 89.8
#   konsert_namn: 100
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 427
# Best match row index in human data: 68
# Best match score: 88.60000000000001
#   konsert_namn: 97
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 460
# Best match row index in human data: 68
# Best match score: 89.8
#   konsert_namn: 100
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 482
# Best match row index in human data: 68
# Best match score: 88.60000000000001
#   konsert_namn: 97
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 945
# Best match row index in human data: 68
# Best match score: 69.8
#   konsert_namn: 100
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 1001
# Best match row index in human data: 68
# Best match score: 61.7
#   konsert_namn: 100
#   lokal_namn: 30
#   konsert_biljettpris: 57
#   konserttyp_namn: 40
#   Producer: 0
#
# Row index in LLM data: 71
# Best match row index in human data: 70
# Best match score: 55.4
#   konsert_namn: 50
#   lokal_namn: 42
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 43
#
# Row index in LLM data: 428
# Best match row index in human data: 71
# Best match score: 37.60000000000001
#   konsert_namn: 22
#   lokal_namn: 26
#   konsert_biljettpris: 100
#   konserttyp_namn: 52
#   Producer: 16
#
# Row index in LLM data: 483
# Best match row index in human data: 71
# Best match score: 37.60000000000001
#   konsert_namn: 22
#   lokal_namn: 26
#   konsert_biljettpris: 100
#   konserttyp_namn: 52
#   Producer: 16
#
# Row index in LLM data: 590
# Best match row index in human data: 70
# Best match score: 82.19999999999999
#   konsert_namn: 67
#   lokal_namn: 100
#   konsert_biljettpris: 16
#   konserttyp_namn: 100
#   Producer: 19
#
# Row index in LLM data: 926
# Best match row index in human data: 71
# Best match score: 28.0
#   konsert_namn: 70
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 927
# Best match row index in human data: 70
# Best match score: 78.8
#   konsert_namn: 47
#   lokal_namn: 100
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 930
# Best match row index in human data: 70
# Best match score: 55.6
#   konsert_namn: 100
#   lokal_namn: 39
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 702
# Best match row index in human data: 73
# Best match score: 40.5
#   konsert_namn: 52
#   lokal_namn: 22
#   konsert_biljettpris: 0
#   konserttyp_namn: 69
#   Producer: 20
#
# Row index in LLM data: 902
# Best match row index in human data: 73
# Best match score: 68.6
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 26
#   konserttyp_namn: 52
#   Producer: 0
#
# Row index in LLM data: 909
# Best match row index in human data: 73
# Best match score: 47.80000000000001
#   konsert_namn: 44
#   lokal_namn: 29
#   konsert_biljettpris: 46
#   konserttyp_namn: 78
#   Producer: 31
#
# Row index in LLM data: 928
# Best match row index in human data: 73
# Best match score: 72.9
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 30
#   konserttyp_namn: 27
#   Producer: 32
#
# Row index in LLM data: 59
# Best match row index in human data: 75
# Best match score: 10.0
#   konsert_namn: 0
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 62
# Best match row index in human data: 75
# Best match score: 55.0
#   konsert_namn: 61
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 63
# Best match row index in human data: 75
# Best match score: 56.099999999999994
#   konsert_namn: 62
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 69
#   Producer: 12
#
# Row index in LLM data: 64
# Best match row index in human data: 75
# Best match score: 39.400000000000006
#   konsert_namn: 32
#   lokal_namn: 26
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 42
#
# Row index in LLM data: 562
# Best match row index in human data: 74
# Best match score: 73.8
#   konsert_namn: 67
#   lokal_namn: 64
#   konsert_biljettpris: 29
#   konserttyp_namn: 33
#   Producer: 76
#
# Row index in LLM data: 700
# Best match row index in human data: 75
# Best match score: 58.400000000000006
#   konsert_namn: 96
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 903
# Best match row index in human data: 74
# Best match score: 62.39999999999999
#   konsert_namn: 31
#   lokal_namn: 79
#   konsert_biljettpris: 78
#   konserttyp_namn: 78
#   Producer: 14
#
# Row index in LLM data: 904
# Best match row index in human data: 76
# Best match score: 73.60000000000001
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 64
#   Producer: 0
#
# Row index in LLM data: 908
# Best match row index in human data: 75
# Best match score: 69.2
#   konsert_namn: 96
#   lokal_namn: 52
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 929
# Best match row index in human data: 76
# Best match score: 96.4
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 976
# Best match row index in human data: 74
# Best match score: 49.3
#   konsert_namn: 21
#   lokal_namn: 59
#   konsert_biljettpris: 67
#   konserttyp_namn: 78
#   Producer: 14
#
# Row index in LLM data: 980
# Best match row index in human data: 75
# Best match score: 10.0
#   konsert_namn: 0
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 981
# Best match row index in human data: 75
# Best match score: 55.0
#   konsert_namn: 61
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 982
# Best match row index in human data: 75
# Best match score: 58.80000000000001
#   konsert_namn: 46
#   lokal_namn: 48
#   konsert_biljettpris: 100
#   konserttyp_namn: 52
#   Producer: 30
#
# Row index in LLM data: 983
# Best match row index in human data: 75
# Best match score: 60.599999999999994
#   konsert_namn: 26
#   lokal_namn: 81
#   konsert_biljettpris: 100
#   konserttyp_namn: 30
#   Producer: 24
#
# Row index in LLM data: 74
# Best match row index in human data: 77
# Best match score: 42.400000000000006
#   konsert_namn: 24
#   lokal_namn: 39
#   konsert_biljettpris: 100
#   konserttyp_namn: 36
#   Producer: 18
#
# Row index in LLM data: 76
# Best match row index in human data: 77
# Best match score: 26.8
#   konsert_namn: 29
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 32
#   Producer: 10
#
# Row index in LLM data: 77
# Best match row index in human data: 77
# Best match score: 27.200000000000003
#   konsert_namn: 25
#   lokal_namn: 34
#   konsert_biljettpris: 0
#   konserttyp_namn: 36
#   Producer: 0
#
# Row index in LLM data: 581
# Best match row index in human data: 77
# Best match score: 50.8
#   konsert_namn: 29
#   lokal_namn: 45
#   konsert_biljettpris: 100
#   konserttyp_namn: 38
#   Producer: 37
#
# Row index in LLM data: 661
# Best match row index in human data: 77
# Best match score: 36.400000000000006
#   konsert_namn: 18
#   lokal_namn: 40
#   konsert_biljettpris: 100
#   konserttyp_namn: 32
#   Producer: 0
#
# Row index in LLM data: 662
# Best match row index in human data: 77
# Best match score: 38.800000000000004
#   konsert_namn: 23
#   lokal_namn: 41
#   konsert_biljettpris: 100
#   konserttyp_namn: 32
#   Producer: 0
#
# Row index in LLM data: 663
# Best match row index in human data: 77
# Best match score: 10.0
#   konsert_namn: 0
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 38
# Best match row index in human data: 78
# Best match score: 31.800000000000004
#   konsert_namn: 53
#   lokal_namn: 9
#   konsert_biljettpris: 0
#   konserttyp_namn: 70
#   Producer: 0
#
# Row index in LLM data: 39
# Best match row index in human data: 78
# Best match score: 38.6
#   konsert_namn: 44
#   lokal_namn: 28
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 17
#
# Row index in LLM data: 72
# Best match row index in human data: 78
# Best match score: 53.0
#   konsert_namn: 55
#   lokal_namn: 10
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 96
#
# Row index in LLM data: 429
# Best match row index in human data: 78
# Best match score: 84.2
#   konsert_namn: 57
#   lokal_namn: 84
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 484
# Best match row index in human data: 78
# Best match score: 84.2
#   konsert_namn: 57
#   lokal_namn: 84
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 582
# Best match row index in human data: 78
# Best match score: 32.0
#   konsert_namn: 30
#   lokal_namn: 14
#   konsert_biljettpris: 0
#   konserttyp_namn: 70
#   Producer: 37
#
# Row index in LLM data: 664
# Best match row index in human data: 78
# Best match score: 41.0
#   konsert_namn: 17
#   lokal_namn: 32
#   konsert_biljettpris: 74
#   konserttyp_namn: 78
#   Producer: 31
#
# Row index in LLM data: 704
# Best match row index in human data: 78
# Best match score: 61.199999999999996
#   konsert_namn: 43
#   lokal_namn: 79
#   konsert_biljettpris: 0
#   konserttyp_namn: 48
#   Producer: 38
#
# Row index in LLM data: 905
# Best match row index in human data: 78
# Best match score: 82.0
#   konsert_namn: 100
#   lokal_namn: 79
#   konsert_biljettpris: 0
#   konserttyp_namn: 42
#   Producer: 31
#
# Row index in LLM data: 924
# Best match row index in human data: 78
# Best match score: 36.6
#   konsert_namn: 30
#   lokal_namn: 43
#   konsert_biljettpris: 0
#   konserttyp_namn: 12
#   Producer: 31
#
# Row index in LLM data: 45
# Best match row index in human data: 79
# Best match score: 72.4
#   konsert_namn: 49
#   lokal_namn: 79
#   konsert_biljettpris: 72
#   konserttyp_namn: 78
#   Producer: 31
#
# Row index in LLM data: 436
# Best match row index in human data: 79
# Best match score: 67.30000000000001
#   konsert_namn: 47
#   lokal_namn: 79
#   konsert_biljettpris: 91
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 491
# Best match row index in human data: 79
# Best match score: 67.30000000000001
#   konsert_namn: 47
#   lokal_namn: 79
#   konsert_biljettpris: 91
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 684
# Best match row index in human data: 79
# Best match score: 35.6
#   konsert_namn: 47
#   lokal_namn: 17
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 919
# Best match row index in human data: 79
# Best match score: 41.6
#   konsert_namn: 78
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 58
#   Producer: 23
#
# Row index in LLM data: 977
# Best match row index in human data: 79
# Best match score: 68.8
#   konsert_namn: 56
#   lokal_namn: 79
#   konsert_biljettpris: 70
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 1
# Best match row index in human data: 81
# Best match score: 39.199999999999996
#   konsert_namn: 13
#   lokal_namn: 44
#   konsert_biljettpris: 100
#   konserttyp_namn: 64
#   Producer: 0
#
# Row index in LLM data: 2
# Best match row index in human data: 81
# Best match score: 49.2
#   konsert_namn: 25
#   lokal_namn: 48
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 35
# Best match row index in human data: 80
# Best match score: 58.00000000000001
#   konsert_namn: 58
#   lokal_namn: 41
#   konsert_biljettpris: 89
#   konserttyp_namn: 55
#   Producer: 20
#
# Row index in LLM data: 510
# Best match row index in human data: 81
# Best match score: 43.800000000000004
#   konsert_namn: 13
#   lokal_namn: 48
#   konsert_biljettpris: 100
#   konserttyp_namn: 64
#   Producer: 15
#
# Row index in LLM data: 543
# Best match row index in human data: 80
# Best match score: 67.7
#   konsert_namn: 67
#   lokal_namn: 64
#   konsert_biljettpris: 35
#   konserttyp_namn: 78
#   Producer: 20
#
# Row index in LLM data: 557
# Best match row index in human data: 80
# Best match score: 60.400000000000006
#   konsert_namn: 87
#   lokal_namn: 64
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 558
# Best match row index in human data: 80
# Best match score: 69.7
#   konsert_namn: 87
#   lokal_namn: 64
#   konsert_biljettpris: 0
#   konserttyp_namn: 55
#   Producer: 19
#
# Row index in LLM data: 563
# Best match row index in human data: 80
# Best match score: 62.0
#   konsert_namn: 59
#   lokal_namn: 64
#   konsert_biljettpris: 50
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 591
# Best match row index in human data: 81
# Best match score: 41.2
#   konsert_namn: 11
#   lokal_namn: 92
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 592
# Best match row index in human data: 81
# Best match score: 57.60000000000001
#   konsert_namn: 19
#   lokal_namn: 92
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 16
#
# Row index in LLM data: 612
# Best match row index in human data: 80
# Best match score: 64.8
#   konsert_namn: 54
#   lokal_namn: 64
#   konsert_biljettpris: 50
#   konserttyp_namn: 78
#   Producer: 24
#
# Row index in LLM data: 686
# Best match row index in human data: 80
# Best match score: 48.5
#   konsert_namn: 44
#   lokal_namn: 32
#   konsert_biljettpris: 81
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 687
# Best match row index in human data: 81
# Best match score: 46.20000000000001
#   konsert_namn: 29
#   lokal_namn: 33
#   konsert_biljettpris: 100
#   konserttyp_namn: 48
#   Producer: 33
#
# Row index in LLM data: 703
# Best match row index in human data: 80
# Best match score: 45.7
#   konsert_namn: 26
#   lokal_namn: 41
#   konsert_biljettpris: 89
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 906
# Best match row index in human data: 80
# Best match score: 52.4
#   konsert_namn: 57
#   lokal_namn: 37
#   konsert_biljettpris: 100
#   konserttyp_namn: 18
#   Producer: 15
#
# Row index in LLM data: 920
# Best match row index in human data: 80
# Best match score: 40.3
#   konsert_namn: 51
#   lokal_namn: 0
#   konsert_biljettpris: 81
#   konserttyp_namn: 78
#   Producer: 20
#
# Row index in LLM data: 978
# Best match row index in human data: 80
# Best match score: 40.1
#   konsert_namn: 45
#   lokal_namn: 0
#   konsert_biljettpris: 81
#   konserttyp_namn: 100
#   Producer: 20
#
# Row index in LLM data: 0
# Best match row index in human data: 82
# Best match score: 91.1
#   konsert_namn: 56
#   lokal_namn: 79
#   konsert_biljettpris: 71
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 36
# Best match row index in human data: 82
# Best match score: 75.6
#   konsert_namn: 60
#   lokal_namn: 79
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 48
# Best match row index in human data: 83
# Best match score: 35.800000000000004
#   konsert_namn: 29
#   lokal_namn: 40
#   konsert_biljettpris: 0
#   konserttyp_namn: 48
#   Producer: 17
#
# Row index in LLM data: 60
# Best match row index in human data: 82
# Best match score: 48.5
#   konsert_namn: 30
#   lokal_namn: 0
#   konsert_biljettpris: 65
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 61
# Best match row index in human data: 82
# Best match score: 65.0
#   konsert_namn: 43
#   lokal_namn: 79
#   konsert_biljettpris: 100
#   konserttyp_namn: 62
#   Producer: 0
#
# Row index in LLM data: 70
# Best match row index in human data: 82
# Best match score: 49.2
#   konsert_namn: 34
#   lokal_namn: 64
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 75
# Best match row index in human data: 82
# Best match score: 72.0
#   konsert_namn: 56
#   lokal_namn: 79
#   konsert_biljettpris: 80
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 395
# Best match row index in human data: 83
# Best match score: 63.9
#   konsert_namn: 65
#   lokal_namn: 20
#   konsert_biljettpris: 38
#   konserttyp_namn: 61
#   Producer: 100
#
# Row index in LLM data: 412
# Best match row index in human data: 82
# Best match score: 82.80000000000001
#   konsert_namn: 28
#   lokal_namn: 79
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 413
# Best match row index in human data: 83
# Best match score: 65.9
#   konsert_namn: 65
#   lokal_namn: 24
#   konsert_biljettpris: 42
#   konserttyp_namn: 61
#   Producer: 100
#
# Row index in LLM data: 417
# Best match row index in human data: 82
# Best match score: 85.2
#   konsert_namn: 34
#   lokal_namn: 79
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 418
# Best match row index in human data: 82
# Best match score: 98.2
#   konsert_namn: 51
#   lokal_namn: 100
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 421
# Best match row index in human data: 82
# Best match score: 53.0
#   konsert_namn: 31
#   lokal_namn: 21
#   konsert_biljettpris: 100
#   konserttyp_namn: 22
#   Producer: 100
#
# Row index in LLM data: 450
# Best match row index in human data: 83
# Best match score: 63.9
#   konsert_namn: 65
#   lokal_namn: 20
#   konsert_biljettpris: 38
#   konserttyp_namn: 61
#   Producer: 100
#
# Row index in LLM data: 467
# Best match row index in human data: 82
# Best match score: 82.80000000000001
#   konsert_namn: 28
#   lokal_namn: 79
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 468
# Best match row index in human data: 83
# Best match score: 65.9
#   konsert_namn: 65
#   lokal_namn: 24
#   konsert_biljettpris: 42
#   konserttyp_namn: 61
#   Producer: 100
#
# Row index in LLM data: 472
# Best match row index in human data: 82
# Best match score: 85.2
#   konsert_namn: 34
#   lokal_namn: 79
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 473
# Best match row index in human data: 82
# Best match score: 98.2
#   konsert_namn: 51
#   lokal_namn: 100
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 476
# Best match row index in human data: 82
# Best match score: 53.0
#   konsert_namn: 31
#   lokal_namn: 21
#   konsert_biljettpris: 100
#   konserttyp_namn: 22
#   Producer: 100
#
# Row index in LLM data: 508
# Best match row index in human data: 82
# ...
#   lokal_namn: 21
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 15
#
# Row index in LLM data: 1345
# Best match row index in human data: 448
# Best match score: 35.0
#   konsert_namn: 43
#   lokal_namn: 27
#   konsert_biljettpris: 0
#   konserttyp_namn: 70
#   Producer: 0
#
# Row index in LLM data: 1347
# Best match row index in human data: 448
# Best match score: 40.4
#   konsert_namn: 39
#   lokal_namn: 21
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 50
#
# Row index in LLM data: 356
# Best match row index in human data: 450
# Best match score: 32.4
#   konsert_namn: 28
#   lokal_namn: 35
#   konsert_biljettpris: 29
#   konserttyp_namn: 43
#   Producer: 0
#
# Row index in LLM data: 1346
# Best match row index in human data: 450
# Best match score: 32.4
#   konsert_namn: 28
#   lokal_namn: 35
#   konsert_biljettpris: 29
#   konserttyp_namn: 43
#   Producer: 0
#
# Row index in LLM data: 353
# Best match row index in human data: 452
# Best match score: 52.0
#   konsert_namn: 55
#   lokal_namn: 17
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 16
#
# Row index in LLM data: 879
# Best match row index in human data: 452
# Best match score: 30.400000000000002
#   konsert_namn: 17
#   lokal_namn: 37
#   konsert_biljettpris: 0
#   konserttyp_namn: 88
#   Producer: 0
#
# Row index in LLM data: 882
# Best match row index in human data: 453
# Best match score: 69.0
#   konsert_namn: 48
#   lokal_namn: 81
#   konsert_biljettpris: 100
#   konserttyp_namn: 74
#   Producer: 0
#
# Row index in LLM data: 1343
# Best match row index in human data: 452
# Best match score: 52.0
#   konsert_namn: 55
#   lokal_namn: 17
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 16
#
# Row index in LLM data: 336
# Best match row index in human data: 455
# Best match score: 50.10000000000001
#   konsert_namn: 49
#   lokal_namn: 32
#   konsert_biljettpris: 70
#   konserttyp_namn: 67
#   Producer: 20
#
# Row index in LLM data: 352
# Best match row index in human data: 455
# Best match score: 24.0
#   konsert_namn: 47
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 26
#
# Row index in LLM data: 856
# Best match row index in human data: 455
# Best match score: 62.2
#   konsert_namn: 45
#   lokal_namn: 79
#   konsert_biljettpris: 74
#   konserttyp_namn: 22
#   Producer: 15
#
# Row index in LLM data: 1326
# Best match row index in human data: 455
# Best match score: 50.10000000000001
#   konsert_namn: 49
#   lokal_namn: 32
#   konsert_biljettpris: 70
#   konserttyp_namn: 67
#   Producer: 20
#
# Row index in LLM data: 1342
# Best match row index in human data: 455
# Best match score: 24.0
#   konsert_namn: 47
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 26
#
# Row index in LLM data: 317
# Best match row index in human data: 459
# Best match score: 78.3
#   konsert_namn: 60
#   lokal_namn: 94
#   konsert_biljettpris: 100
#   konserttyp_namn: 67
#   Producer: 0
#
# Row index in LLM data: 323
# Best match row index in human data: 459
# Best match score: 59.2
#   konsert_namn: 75
#   lokal_namn: 43
#   konsert_biljettpris: 50
#   konserttyp_namn: 70
#   Producer: 0
#
# Row index in LLM data: 324
# Best match row index in human data: 458
# Best match score: 69.9
#   konsert_namn: 43
#   lokal_namn: 100
#   konsert_biljettpris: 60
#   konserttyp_namn: 67
#   Producer: 0
#
# Row index in LLM data: 325
# Best match row index in human data: 459
# Best match score: 90.3
#   konsert_namn: 56
#   lokal_namn: 94
#   konsert_biljettpris: 46
#   konserttyp_namn: 67
#   Producer: 95
#
# Row index in LLM data: 327
# Best match row index in human data: 460
# Best match score: 39.2
#   konsert_namn: 37
#   lokal_namn: 25
#   konsert_biljettpris: 22
#   konserttyp_namn: 64
#   Producer: 29
#
# Row index in LLM data: 328
# Best match row index in human data: 457
# Best match score: 46.400000000000006
#   konsert_namn: 33
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 62
#   Producer: 21
#
# Row index in LLM data: 1307
# Best match row index in human data: 459
# Best match score: 78.3
#   konsert_namn: 60
#   lokal_namn: 94
#   konsert_biljettpris: 100
#   konserttyp_namn: 67
#   Producer: 0
#
# Row index in LLM data: 1313
# Best match row index in human data: 459
# Best match score: 59.2
#   konsert_namn: 75
#   lokal_namn: 43
#   konsert_biljettpris: 50
#   konserttyp_namn: 70
#   Producer: 0
#
# Row index in LLM data: 1314
# Best match row index in human data: 458
# Best match score: 69.9
#   konsert_namn: 43
#   lokal_namn: 100
#   konsert_biljettpris: 60
#   konserttyp_namn: 67
#   Producer: 0
#
# Row index in LLM data: 1315
# Best match row index in human data: 459
# Best match score: 90.3
#   konsert_namn: 56
#   lokal_namn: 94
#   konsert_biljettpris: 46
#   konserttyp_namn: 67
#   Producer: 95
#
# Row index in LLM data: 1317
# Best match row index in human data: 460
# Best match score: 39.2
#   konsert_namn: 37
#   lokal_namn: 25
#   konsert_biljettpris: 22
#   konserttyp_namn: 64
#   Producer: 29
#
# Row index in LLM data: 1318
# Best match row index in human data: 457
# Best match score: 46.400000000000006
#   konsert_namn: 33
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 62
#   Producer: 21
#
# Row index in LLM data: 315
# Best match row index in human data: 462
# Best match score: 55.0
#   konsert_namn: 44
#   lokal_namn: 39
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 20
#
# Row index in LLM data: 876
# Best match row index in human data: 462
# Best match score: 56.0
#   konsert_namn: 26
#   lokal_namn: 64
#   konsert_biljettpris: 84
#   konserttyp_namn: 78
#   Producer: 19
#
# Row index in LLM data: 1305
# Best match row index in human data: 462
# Best match score: 55.0
#   konsert_namn: 44
#   lokal_namn: 39
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 20
#
# Row index in LLM data: 316
# Best match row index in human data: 467
# Best match score: 41.300000000000004
#   konsert_namn: 30
#   lokal_namn: 48
#   konsert_biljettpris: 49
#   konserttyp_namn: 52
#   Producer: 0
#
# Row index in LLM data: 326
# Best match row index in human data: 467
# Best match score: 50.3
#   konsert_namn: 50
#   lokal_namn: 48
#   konsert_biljettpris: 23
#   konserttyp_namn: 88
#   Producer: 0
#
# Row index in LLM data: 1306
# Best match row index in human data: 467
# Best match score: 41.300000000000004
#   konsert_namn: 30
#   lokal_namn: 48
#   konsert_biljettpris: 49
#   konserttyp_namn: 52
#   Producer: 0
#
# Row index in LLM data: 1316
# Best match row index in human data: 467
# Best match score: 50.3
#   konsert_namn: 50
#   lokal_namn: 48
#   konsert_biljettpris: 23
#   konserttyp_namn: 88
#   Producer: 0
#
# Row index in LLM data: 385
# Best match row index in human data: 470
# Best match score: 51.60000000000001
#   konsert_namn: 56
#   lokal_namn: 25
#   konsert_biljettpris: 100
#   konserttyp_namn: 56
#   Producer: 18
#
# Row index in LLM data: 386
# Best match row index in human data: 471
# Best match score: 62.800000000000004
#   konsert_namn: 44
#   lokal_namn: 24
#   konsert_biljettpris: 100
#   konserttyp_namn: 56
#   Producer: 100
#
# Row index in LLM data: 387
# Best match row index in human data: 470
# Best match score: 48.60000000000001
#   konsert_namn: 41
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 54
#   Producer: 24
#
# Row index in LLM data: 388
# Best match row index in human data: 471
# Best match score: 44.60000000000001
#   konsert_namn: 39
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 62
#   Producer: 0
#
# Row index in LLM data: 389
# Best match row index in human data: 471
# Best match score: 67.60000000000001
#   konsert_namn: 51
#   lokal_namn: 83
#   konsert_biljettpris: 100
#   konserttyp_namn: 40
#   Producer: 0
#
# Row index in LLM data: 1375
# Best match row index in human data: 470
# Best match score: 51.60000000000001
#   konsert_namn: 56
#   lokal_namn: 25
#   konsert_biljettpris: 100
#   konserttyp_namn: 56
#   Producer: 18
#
# Row index in LLM data: 1376
# Best match row index in human data: 471
# Best match score: 62.800000000000004
#   konsert_namn: 44
#   lokal_namn: 24
#   konsert_biljettpris: 100
#   konserttyp_namn: 56
#   Producer: 100
#
# Row index in LLM data: 1377
# Best match row index in human data: 470
# Best match score: 48.60000000000001
#   konsert_namn: 41
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 54
#   Producer: 24
#
# Row index in LLM data: 1378
# Best match row index in human data: 471
# Best match score: 44.60000000000001
#   konsert_namn: 39
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 62
#   Producer: 0
#
# Row index in LLM data: 1379
# Best match row index in human data: 471
# Best match score: 67.60000000000001
#   konsert_namn: 51
#   lokal_namn: 83
#   konsert_biljettpris: 100
#   konserttyp_namn: 40
#   Producer: 0
#
# Row index in LLM data: 372
# Best match row index in human data: 475
# Best match score: 49.3
#   konsert_namn: 27
#   lokal_namn: 52
#   konsert_biljettpris: 89
#   konserttyp_namn: 64
#   Producer: 12
#
# Row index in LLM data: 374
# Best match row index in human data: 477
# Best match score: 34.599999999999994
#   konsert_namn: 31
#   lokal_namn: 25
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 29
#
# Row index in LLM data: 375
# Best match row index in human data: 477
# Best match score: 50.800000000000004
#   konsert_namn: 49
#   lokal_namn: 39
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 46
#
# Row index in LLM data: 376
# Best match row index in human data: 477
# Best match score: 47.6
#   konsert_namn: 50
#   lokal_namn: 27
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 52
#
# Row index in LLM data: 377
# Best match row index in human data: 475
# Best match score: 26.700000000000003
#   konsert_namn: 15
#   lokal_namn: 19
#   konsert_biljettpris: 67
#   konserttyp_namn: 28
#   Producer: 18
#
# Row index in LLM data: 390
# Best match row index in human data: 475
# Best match score: 36.6
#   konsert_namn: 74
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 70
#   Producer: 0
#
# Row index in LLM data: 1362
# Best match row index in human data: 475
# Best match score: 49.3
#   konsert_namn: 27
#   lokal_namn: 52
#   konsert_biljettpris: 89
#   konserttyp_namn: 64
#   Producer: 12
#
# Row index in LLM data: 1364
# Best match row index in human data: 477
# Best match score: 34.599999999999994
#   konsert_namn: 31
#   lokal_namn: 25
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 29
#
# Row index in LLM data: 1365
# Best match row index in human data: 477
# Best match score: 50.800000000000004
#   konsert_namn: 49
#   lokal_namn: 39
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 46
#
# Row index in LLM data: 1366
# Best match row index in human data: 477
# Best match score: 47.6
#   konsert_namn: 50
#   lokal_namn: 27
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 52
#
# Row index in LLM data: 1367
# Best match row index in human data: 475
# Best match score: 26.700000000000003
#   konsert_namn: 15
#   lokal_namn: 19
#   konsert_biljettpris: 67
#   konserttyp_namn: 28
#   Producer: 18
#
# Row index in LLM data: 1380
# Best match row index in human data: 475
# Best match score: 36.6
#   konsert_namn: 74
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 70
#   Producer: 0
#
# Row index in LLM data: 383
# Best match row index in human data: 478
# Best match score: 74.8
#   konsert_namn: 21
#   lokal_namn: 91
#   konsert_biljettpris: 100
#   konserttyp_namn: 64
#   Producer: 68
#
# Row index in LLM data: 1373
# Best match row index in human data: 478
# Best match score: 74.8
#   konsert_namn: 21
#   lokal_namn: 91
#   konsert_biljettpris: 100
#   konserttyp_namn: 64
#   Producer: 68
#
# Row index in LLM data: 373
# Best match row index in human data: 483
# Best match score: 54.400000000000006
#   konsert_namn: 34
#   lokal_namn: 33
#   konsert_biljettpris: 0
#   konserttyp_namn: 76
#   Producer: 100
#
# Row index in LLM data: 384
# Best match row index in human data: 483
# Best match score: 55.2
#   konsert_namn: 34
#   lokal_namn: 29
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 1363
# Best match row index in human data: 483
# Best match score: 54.400000000000006
#   konsert_namn: 34
#   lokal_namn: 33
#   konsert_biljettpris: 0
#   konserttyp_namn: 76
#   Producer: 100
#
# Row index in LLM data: 1374
# Best match row index in human data: 483
# Best match score: 55.2
#   konsert_namn: 34
#   lokal_namn: 29
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 367
# Best match row index in human data: 505
# Best match score: 18.7
#   konsert_namn: 25
#   lokal_namn: 17
#   konsert_biljettpris: 0
#   konserttyp_namn: 19
#   Producer: 0
#
# Row index in LLM data: 368
# Best match row index in human data: 505
# Best match score: 18.0
#   konsert_namn: 17
#   lokal_namn: 25
#   konsert_biljettpris: 0
#   konserttyp_namn: 12
#   Producer: 0
#
# Row index in LLM data: 369
# Best match row index in human data: 505
# Best match score: 21.3
#   konsert_namn: 21
#   lokal_namn: 26
#   konsert_biljettpris: 0
#   konserttyp_namn: 25
#   Producer: 0
#
# Row index in LLM data: 370
# Best match row index in human data: 505
# Best match score: 17.8
#   konsert_namn: 25
#   lokal_namn: 14
#   konsert_biljettpris: 0
#   konserttyp_namn: 22
#   Producer: 0
#
# Row index in LLM data: 371
# Best match row index in human data: 505
# Best match score: 39.8
#   konsert_namn: 26
#   lokal_namn: 18
#   konsert_biljettpris: 0
#   konserttyp_namn: 22
#   Producer: 100
#
# Row index in LLM data: 1357
# Best match row index in human data: 505
# Best match score: 18.7
#   konsert_namn: 25
#   lokal_namn: 17
#   konsert_biljettpris: 0
#   konserttyp_namn: 19
#   Producer: 0
#
# Row index in LLM data: 1358
# Best match row index in human data: 505
# Best match score: 18.0
#   konsert_namn: 17
#   lokal_namn: 25
#   konsert_biljettpris: 0
#   konserttyp_namn: 12
#   Producer: 0
#
# Row index in LLM data: 1359
# Best match row index in human data: 505
# Best match score: 21.3
#   konsert_namn: 21
#   lokal_namn: 26
#   konsert_biljettpris: 0
#   konserttyp_namn: 25
#   Producer: 0
#
# Row index in LLM data: 1360
# Best match row index in human data: 505
# Best match score: 17.8
#   konsert_namn: 25
#   lokal_namn: 14
#   konsert_biljettpris: 0
#   konserttyp_namn: 22
#   Producer: 0
#
# Row index in LLM data: 1361
# Best match row index in human data: 505
# Best match score: 39.8
#   konsert_namn: 26
#   lokal_namn: 18
#   konsert_biljettpris: 0
#   konserttyp_namn: 22
#   Producer: 100
#
# Row index in LLM data: 835
# Best match row index in human data: 506
# Best match score: 46.8
#   konsert_namn: 43
#   lokal_namn: 24
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 836
# Best match row index in human data: 506
# Best match score: 46.800000000000004
#   konsert_namn: 45
#   lokal_namn: 29
#   konsert_biljettpris: 100
#   konserttyp_namn: 22
#   Producer: 25
#
# Row index in LLM data: 850
# Best match row index in human data: 508
# Best match score: 33.4
#   konsert_namn: 20
#   lokal_namn: 25
#   konsert_biljettpris: 85
#   konserttyp_namn: 69
#   Producer: 0
#
# Row index in LLM data: 849
# Best match row index in human data: 511
# Best match score: 27.500000000000004
#   konsert_namn: 12
#   lokal_namn: 32
#   konsert_biljettpris: 0
#   konserttyp_namn: 33
#   Producer: 33
#
# Row index in LLM data: 828
# Best match row index in human data: 513
# Best match score: 27.000000000000004
#   konsert_namn: 33
#   lokal_namn: 29
#   konsert_biljettpris: 0
#   konserttyp_namn: 22
#   Producer: 0
#
# Row index in LLM data: 829
# Best match row index in human data: 513
# Best match score: 23.2
#   konsert_namn: 25
#   lokal_namn: 31
#   konsert_biljettpris: 0
#   konserttyp_namn: 8
#   Producer: 0
#
# Row index in LLM data: 832
# Best match row index in human data: 512
# Best match score: 79.6
#   konsert_namn: 24
#   lokal_namn: 100
#   konsert_biljettpris: 100
#   konserttyp_namn: 0
#   Producer: 100
#
#
# Unique concerts found by LLM but not by human (total 924):
#       json_row_index  overall_match_score
# 0                666                 31.6
# 1                668                 37.2
# 2                671                 52.7
# 3                433                 75.3
# 5                488                 75.3
# ...              ...                  ...
# 1031             850                 33.4
# 1032             849                 27.5
# 1033             828                 27.0
# 1034             829                 23.2
# 1035             832                 79.6
#
# [924 rows x 2 columns]
#
# Unique concerts found by human but not by LLM (total 460):
#     konsert_datum
# 0      1908-01-02
# 2      1908-01-05
# 3      1908-01-05
# 4      1908-01-05
# 5      1908-01-06
# ..            ...
# 509    1908-12-26
# 510    1908-12-26
# 511    1908-12-27
# 512    1908-12-31
# 513    1908-12-31
#
# [460 rows x 1 columns]

# %%
import pandas as pd
from fuzzywuzzy import fuzz, process
import re
from datetime import datetime

# Load XLS file 
xls_path = 'All_Concerts_1908_filtered.xlsx'
xls_df = pd.read_excel(xls_path)

# Display the first few rows of the loaded DataFrame to verify
#print(xls_df.head(10))

# Load JSON file
json_path = 'Datasets/SD_DN_AB_1908_concerts_LLM.json'
json_df = pd.read_json(json_path)

# Verify the loaded JSON data
#print(json_df.head(3))

# Identify relevant columns
relevant_columns = ['konsert_datum', 'konsert_namn', 'lokal_namn', 'konsert_biljettpris', 'konserttyp_namn', 'Producer']

# Filter relevant columns
xls_df = xls_df[relevant_columns]
json_df = json_df[relevant_columns]

# Function to normalize text
def normalize(text):
    if pd.isna(text) or text.strip().lower() == "unknown":  # Handle NaN values and "UNKNOWN"
        return ""
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'[-,]', ' ', text)  # Replace hyphens and commas with spaces
    text = re.sub(r'\s+', ' ', text)  # Replace multiple spaces with a single space
    text = text.strip()  # Remove leading and trailing spaces
    return text

# Function to normalize dates
def normalize_date(date):
    try:
        # Try to parse the date from different formats
        if isinstance(date, str):
            if re.match(r'\d{2}\.\d{2}\.\d{2}', date):  # Format: DD.MM.YY
                date_obj = datetime.strptime(date, '%d.%m.%y')
                if date_obj.year >= 2000:
                    date_obj = date_obj.replace(year=date_obj.year - 100)
            elif re.match(r'\d{4}\.\d{2}\.\d{2}', date):  # Format: YYYY.MM.DD
                date_obj = datetime.strptime(date, '%Y.%m.%d')
            elif re.match(r'\d{2}\.\d{2}\.\d{4}', date):  # Format: DD.MM.YYYY
                date_obj = datetime.strptime(date, '%d.%m.%Y')
            else:
                return ""
        elif isinstance(date, datetime):
            date_obj = date
        else:
            return ""
        return date_obj.strftime('%Y-%m-%d')  # Convert to "YYYY-MM-DD"
    except ValueError:
        return ""

# Normalize 'UNKNOWN' values and dates in both dataframes
xls_df = xls_df.replace('UNKNOWN', '')
json_df = json_df.replace('UNKNOWN', '')
xls_df['normalized_konsert_datum'] = xls_df['konsert_datum'].apply(normalize_date)
json_df['normalized_konsert_datum'] = json_df['konsert_datum'].apply(normalize_date)

# Normalize all text columns in both dataframes
for col in xls_df.columns:
    if xls_df[col].dtype == 'object':  # Apply only to text columns
        xls_df[col] = xls_df[col].apply(normalize)

for col in json_df.columns:
    if json_df[col].dtype == 'object':  # Apply only to text columns
        json_df[col] = json_df[col].apply(normalize)

# Columns to compare (excluding date)
columns_to_compare = ['konsert_namn', 'lokal_namn', 'konsert_biljettpris', 'konserttyp_namn', 'Producer']

# Assign weights to each column based on their importance
weights = {
    'konsert_namn': 0.4,  # 40% of the total importance
    'lokal_namn': 0.4, 
    'konsert_biljettpris': 0.1,
    'konserttyp_namn': 0.1,
    'Producer': 0.2
}

def compare_rows_on_date(date, df1, df2, columns, weights):
    rows1 = df1[df1['normalized_konsert_datum'] == date]
    rows2 = df2[df2['normalized_konsert_datum'] == date]
    comparison_results = []

    for idx2, row2 in rows2.iterrows():
        overall_match_score = 0
        best_match_idx1 = None
        best_match_date = None
        overall_match_scores = {}  # Ensure this is initialized before use

        for idx1, row1 in rows1.iterrows():
            total_weighted_score = 0
            column_scores = {}  # Initialize it here within the loop before use

            for col in columns:
                score = fuzz.token_sort_ratio(row1[col], row2[col])
                weighted_score = score * weights[col]
                total_weighted_score += weighted_score
                column_scores[col] = score

            if total_weighted_score > overall_match_score:
                overall_match_score = total_weighted_score
                best_match_idx1 = idx1
                best_match_date = row1['konsert_datum']
                overall_match_scores = column_scores  # Only set this if a new best score is found

        if best_match_idx1 is not None:  # Ensure that we have a valid match before appending
            comparison_results.append({
                'original_date': best_match_date,  # Include the original date in the result
                'json_row_index': idx2,
                'xls_row_index': best_match_idx1,
                'overall_match_score': overall_match_score,
                **overall_match_scores  # Safely add scores as they are now always initialized
            })

    return comparison_results


# Group rows by normalized date and compare
all_comparison_results = []
unique_dates = pd.concat([xls_df['normalized_konsert_datum'], json_df['normalized_konsert_datum']]).unique()

for date in unique_dates:
    if date:  # Ensure date is not empty
        comparison_results = compare_rows_on_date(date, xls_df, json_df, columns_to_compare, weights)
        all_comparison_results.extend(comparison_results)

# Analyze results
for result in all_comparison_results:
    # Updated the key to 'json_row_index' which is the correct key being used in the dictionary
    print(f"Row index in LLM data: {result['json_row_index']}")
    # Key 'best_match_index' is correct as per the creation of the dictionary
    print(f"Best match row index in human data: {result['xls_row_index']}")
    # Key 'overall_match_score' is also correct
    print(f"Best match score: {result['overall_match_score']}")
    # Print detailed scores for each column
    for col, score in result.items():
        if col in ['json_row_index', 'xls_row_index', 'overall_match_score', 'original_date']:
            continue  # Skip the non-score keys
        print(f"  {col}: {score}")
    print()  # Add a newline for better readability between entries


# Convert comparison results to DataFrame for further analysis
comparison_df = pd.DataFrame(all_comparison_results)

# Generate a date-based report name
report_date = datetime.now().strftime('%Y-%m-%d')

# Save the comparison results to a CSV file
comparison_file_name = f'detailed_comparison_results_{report_date}.csv'
comparison_df.to_csv(comparison_file_name, index=False)

# Correctly reference the DataFrame keys when looking for unique concerts
def find_unique_dates(df1, df2, threshold=80):
    comparison_df = pd.DataFrame(all_comparison_results)
    unique_to_llm = comparison_df[comparison_df['overall_match_score'] < threshold]
    matched_indices = comparison_df[comparison_df['overall_match_score'] >= threshold]['xls_row_index'].unique()
    unique_to_human = df1[~df1.index.isin(matched_indices)]
    return unique_to_llm, unique_to_human

# Find unique concerts based on dates
unique_llm_dates, unique_human_dates = find_unique_dates(xls_df, json_df)


print(f"\nUnique concerts found by LLM but not by human (total {len(unique_llm_dates)}):")
print(unique_llm_dates[['json_row_index', 'overall_match_score']])

print(f"\nUnique concerts found by human but not by LLM (total {len(unique_human_dates)}):")
print(unique_human_dates[['konsert_datum']])


# Saving results to CSV with the correct DataFrame structure
unique_llm_file_name = f'unique_to_llm_concerts_{report_date}.csv'
unique_human_file_name = f'unique_to_human_concerts_{report_date}.csv'
unique_llm_dates.to_csv(unique_llm_file_name, index=False)
unique_human_dates.to_csv(unique_human_file_name, index=False)
# Out:
# Row index in LLM data: 666
# Best match row index in human data: 0
# Best match score: 31.6
#   konsert_namn: 23
#   lokal_namn: 17
#   konsert_biljettpris: 100
#   konserttyp_namn: 56
#   Producer: 0
#
# Row index in LLM data: 668
# Best match row index in human data: 0
# Best match score: 37.2
#   konsert_namn: 38
#   lokal_namn: 17
#   konsert_biljettpris: 100
#   konserttyp_namn: 52
#   Producer: 0
#
# Row index in LLM data: 671
# Best match row index in human data: 0
# Best match score: 52.7
#   konsert_namn: 30
#   lokal_namn: 79
#   konsert_biljettpris: 0
#   konserttyp_namn: 55
#   Producer: 18
#
# Row index in LLM data: 433
# Best match row index in human data: 1
# Best match score: 75.30000000000001
#   konsert_namn: 53
#   lokal_namn: 100
#   konsert_biljettpris: 55
#   konserttyp_namn: 22
#   Producer: 32
#
# Row index in LLM data: 434
# Best match row index in human data: 1
# Best match score: 88.30000000000001
#   konsert_namn: 66
#   lokal_namn: 100
#   konsert_biljettpris: 55
#   konserttyp_namn: 100
#   Producer: 32
#
# Row index in LLM data: 488
# Best match row index in human data: 1
# Best match score: 75.30000000000001
#   konsert_namn: 53
#   lokal_namn: 100
#   konsert_biljettpris: 55
#   konserttyp_namn: 22
#   Producer: 32
#
# Row index in LLM data: 489
# Best match row index in human data: 1
# Best match score: 88.30000000000001
#   konsert_namn: 66
#   lokal_namn: 100
#   konsert_biljettpris: 55
#   konserttyp_namn: 100
#   Producer: 32
#
# Row index in LLM data: 667
# Best match row index in human data: 1
# Best match score: 96.30000000000001
#   konsert_namn: 61
#   lokal_namn: 98
#   konsert_biljettpris: 53
#   konserttyp_namn: 74
#   Producer: 100
#
# Row index in LLM data: 1022
# Best match row index in human data: 1
# Best match score: 47.0
#   konsert_namn: 33
#   lokal_namn: 24
#   konsert_biljettpris: 0
#   konserttyp_namn: 42
#   Producer: 100
#
# Row index in LLM data: 1023
# Best match row index in human data: 1
# Best match score: 66.2
#   konsert_namn: 53
#   lokal_namn: 79
#   konsert_biljettpris: 0
#   konserttyp_namn: 70
#   Producer: 32
#
# Row index in LLM data: 1024
# Best match row index in human data: 4
# Best match score: 70.39999999999999
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 0
#   konserttyp_namn: 48
#   Producer: 24
#
# Row index in LLM data: 1027
# Best match row index in human data: 3
# Best match score: 66.30000000000001
#   konsert_namn: 54
#   lokal_namn: 20
#   konsert_biljettpris: 100
#   konserttyp_namn: 67
#   Producer: 100
#
# Row index in LLM data: 1025
# Best match row index in human data: 8
# Best match score: 82.3
#   konsert_namn: 100
#   lokal_namn: 59
#   konsert_biljettpris: 81
#   konserttyp_namn: 48
#   Producer: 29
#
# Row index in LLM data: 87
# Best match row index in human data: 9
# Best match score: 68.6
#   konsert_namn: 49
#   lokal_namn: 90
#   konsert_biljettpris: 33
#   konserttyp_namn: 97
#   Producer: 0
#
# Row index in LLM data: 435
# Best match row index in human data: 9
# Best match score: 86.9
#   konsert_namn: 49
#   lokal_namn: 100
#   konsert_biljettpris: 39
#   konserttyp_namn: 100
#   Producer: 67
#
# Row index in LLM data: 490
# Best match row index in human data: 9
# Best match score: 86.9
#   konsert_namn: 49
#   lokal_namn: 100
#   konsert_biljettpris: 39
#   konserttyp_namn: 100
#   Producer: 67
#
# Row index in LLM data: 1026
# Best match row index in human data: 9
# Best match score: 75.5
#   konsert_namn: 35
#   lokal_namn: 85
#   konsert_biljettpris: 44
#   konserttyp_namn: 97
#   Producer: 67
#
# Row index in LLM data: 1011
# Best match row index in human data: 11
# Best match score: 35.400000000000006
#   konsert_namn: 23
#   lokal_namn: 46
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 657
# Best match row index in human data: 12
# Best match score: 43.2
#   konsert_namn: 69
#   lokal_namn: 29
#   konsert_biljettpris: 0
#   konserttyp_namn: 40
#   Producer: 0
#
# Row index in LLM data: 658
# Best match row index in human data: 12
# Best match score: 40.2
#   konsert_namn: 61
#   lokal_namn: 22
#   konsert_biljettpris: 0
#   konserttyp_namn: 70
#   Producer: 0
#
# Row index in LLM data: 659
# Best match row index in human data: 12
# Best match score: 37.2
#   konsert_namn: 37
#   lokal_namn: 25
#   konsert_biljettpris: 0
#   konserttyp_namn: 56
#   Producer: 34
#
# Row index in LLM data: 961
# Best match row index in human data: 12
# Best match score: 94.2
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 963
# Best match row index in human data: 12
# Best match score: 46.2
#   konsert_namn: 71
#   lokal_namn: 25
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 964
# Best match row index in human data: 12
# Best match score: 45.7
#   konsert_namn: 60
#   lokal_namn: 39
#   konsert_biljettpris: 0
#   konserttyp_namn: 61
#   Producer: 0
#
# Row index in LLM data: 965
# Best match row index in human data: 12
# Best match score: 38.2
#   konsert_namn: 55
#   lokal_namn: 30
#   konsert_biljettpris: 0
#   konserttyp_namn: 42
#   Producer: 0
#
# Row index in LLM data: 656
# Best match row index in human data: 13
# Best match score: 63.2
#   konsert_namn: 100
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 16
#
# Row index in LLM data: 26
# Best match row index in human data: 16
# Best match score: 35.2
#   konsert_namn: 49
#   lokal_namn: 39
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 27
# Best match row index in human data: 16
# Best match score: 37.0
#   konsert_namn: 43
#   lokal_namn: 19
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 29
#
# Row index in LLM data: 28
# Best match row index in human data: 17
# Best match score: 40.6
#   konsert_namn: 43
#   lokal_namn: 27
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 13
#
# Row index in LLM data: 415
# Best match row index in human data: 16
# Best match score: 50.80000000000001
#   konsert_namn: 42
#   lokal_namn: 29
#   konsert_biljettpris: 100
#   konserttyp_namn: 52
#   Producer: 36
#
# Row index in LLM data: 416
# Best match row index in human data: 16
# Best match score: 48.60000000000001
#   konsert_namn: 52
#   lokal_namn: 39
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 29
#
# Row index in LLM data: 470
# Best match row index in human data: 16
# Best match score: 50.80000000000001
#   konsert_namn: 42
#   lokal_namn: 29
#   konsert_biljettpris: 100
#   konserttyp_namn: 52
#   Producer: 36
#
# Row index in LLM data: 471
# Best match row index in human data: 16
# Best match score: 48.60000000000001
#   konsert_namn: 52
#   lokal_namn: 39
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 29
#
# Row index in LLM data: 941
# Best match row index in human data: 16
# Best match score: 90.00000000000001
#   konsert_namn: 82
#   lokal_namn: 85
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 27
#
# Row index in LLM data: 942
# Best match row index in human data: 16
# Best match score: 17.400000000000002
#   konsert_namn: 24
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 946
# Best match row index in human data: 16
# Best match score: 38.50000000000001
#   konsert_namn: 41
#   lokal_namn: 26
#   konsert_biljettpris: 65
#   konserttyp_namn: 52
#   Producer: 0
#
# Row index in LLM data: 947
# Best match row index in human data: 16
# Best match score: 32.6
#   konsert_namn: 35
#   lokal_namn: 17
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 27
#
# Row index in LLM data: 962
# Best match row index in human data: 16
# Best match score: 62.800000000000004
#   konsert_namn: 36
#   lokal_namn: 60
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 33
#
# Row index in LLM data: 1012
# Best match row index in human data: 16
# Best match score: 51.1
#   konsert_namn: 40
#   lokal_namn: 60
#   konsert_biljettpris: 100
#   konserttyp_namn: 11
#   Producer: 0
#
# Row index in LLM data: 40
# Best match row index in human data: 18
# Best match score: 36.00000000000001
#   konsert_namn: 26
#   lokal_namn: 22
#   konsert_biljettpris: 26
#   konserttyp_namn: 76
#   Producer: 33
#
# Row index in LLM data: 44
# Best match row index in human data: 18
# Best match score: 27.8
#   konsert_namn: 14
#   lokal_namn: 36
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 414
# Best match row index in human data: 18
# Best match score: 57.199999999999996
#   konsert_namn: 35
#   lokal_namn: 67
#   konsert_biljettpris: 18
#   konserttyp_namn: 80
#   Producer: 33
#
# Row index in LLM data: 469
# Best match row index in human data: 18
# Best match score: 57.199999999999996
#   konsert_namn: 35
#   lokal_namn: 67
#   konsert_biljettpris: 18
#   konserttyp_namn: 80
#   Producer: 33
#
# Row index in LLM data: 4
# Best match row index in human data: 19
# Best match score: 61.800000000000004
#   konsert_namn: 33
#   lokal_namn: 60
#   konsert_biljettpris: 100
#   konserttyp_namn: 22
#   Producer: 62
#
# Row index in LLM data: 7
# Best match row index in human data: 19
# Best match score: 38.8
#   konsert_namn: 35
#   lokal_namn: 29
#   konsert_biljettpris: 0
#   konserttyp_namn: 74
#   Producer: 29
#
# Row index in LLM data: 23
# Best match row index in human data: 20
# Best match score: 49.699999999999996
#   konsert_namn: 62
#   lokal_namn: 20
#   konsert_biljettpris: 43
#   konserttyp_namn: 72
#   Producer: 27
#
# Row index in LLM data: 41
# Best match row index in human data: 19
# Best match score: 72.39999999999999
#   konsert_namn: 42
#   lokal_namn: 100
#   konsert_biljettpris: 100
#   konserttyp_namn: 56
#   Producer: 0
#
# Row index in LLM data: 402
# Best match row index in human data: 19
# Best match score: 56.1
#   konsert_namn: 11
#   lokal_namn: 100
#   konsert_biljettpris: 71
#   konserttyp_namn: 46
#   Producer: 0
#
# Row index in LLM data: 457
# Best match row index in human data: 19
# Best match score: 56.1
#   konsert_namn: 11
#   lokal_namn: 100
#   konsert_biljettpris: 71
#   konserttyp_namn: 46
#   Producer: 0
#
# Row index in LLM data: 660
# Best match row index in human data: 19
# Best match score: 76.00000000000001
#   konsert_namn: 48
#   lokal_namn: 100
#   konsert_biljettpris: 94
#   konserttyp_namn: 24
#   Producer: 25
#
# Row index in LLM data: 998
# Best match row index in human data: 19
# Best match score: 41.0
#   konsert_namn: 27
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 74
#   Producer: 0
#
# Row index in LLM data: 1003
# Best match row index in human data: 19
# Best match score: 40.0
#   konsert_namn: 33
#   lokal_namn: 25
#   konsert_biljettpris: 10
#   konserttyp_namn: 100
#   Producer: 29
#
# Row index in LLM data: 3
# Best match row index in human data: 21
# Best match score: 89.4
#   konsert_namn: 99
#   lokal_namn: 54
#   konsert_biljettpris: 100
#   konserttyp_namn: 58
#   Producer: 62
#
# Row index in LLM data: 43
# Best match row index in human data: 21
# Best match score: 85.60000000000001
#   konsert_namn: 95
#   lokal_namn: 71
#   konsert_biljettpris: 100
#   konserttyp_namn: 58
#   Producer: 17
#
# Row index in LLM data: 401
# Best match row index in human data: 21
# Best match score: 60.400000000000006
#   konsert_namn: 87
#   lokal_namn: 32
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 14
#
# Row index in LLM data: 456
# Best match row index in human data: 21
# Best match score: 60.400000000000006
#   konsert_namn: 87
#   lokal_namn: 32
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 14
#
# Row index in LLM data: 641
# Best match row index in human data: 21
# Best match score: 90.4
#   konsert_namn: 99
#   lokal_namn: 71
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 62
#
# Row index in LLM data: 652
# Best match row index in human data: 23
# Best match score: 75.4
#   konsert_namn: 30
#   lokal_namn: 88
#   konsert_biljettpris: 0
#   konserttyp_namn: 82
#   Producer: 100
#
# Row index in LLM data: 952
# Best match row index in human data: 23
# Best match score: 97.00000000000001
#   konsert_namn: 71
#   lokal_namn: 100
#   konsert_biljettpris: 44
#   konserttyp_namn: 42
#   Producer: 100
#
# Row index in LLM data: 959
# Best match row index in human data: 22
# Best match score: 53.599999999999994
#   konsert_namn: 81
#   lokal_namn: 16
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 24
#
# Row index in LLM data: 968
# Best match row index in human data: 22
# Best match score: 50.5
#   konsert_namn: 64
#   lokal_namn: 26
#   konsert_biljettpris: 25
#   konserttyp_namn: 56
#   Producer: 32
#
# Row index in LLM data: 5
# Best match row index in human data: 28
# Best match score: 75.60000000000001
#   konsert_namn: 42
#   lokal_namn: 89
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 16
#
# Row index in LLM data: 25
# Best match row index in human data: 28
# Best match score: 73.4
#   konsert_namn: 40
#   lokal_namn: 89
#   konsert_biljettpris: 100
#   konserttyp_namn: 86
#   Producer: 16
#
# Row index in LLM data: 78
# Best match row index in human data: 28
# Best match score: 71.0
#   konsert_namn: 42
#   lokal_namn: 89
#   konsert_biljettpris: 86
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 404
# Best match row index in human data: 28
# Best match score: 64.0
#   konsert_namn: 46
#   lokal_namn: 89
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 439
# Best match row index in human data: 28
# Best match score: 62.8
#   konsert_namn: 43
#   lokal_namn: 89
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 459
# Best match row index in human data: 28
# Best match score: 64.0
#   konsert_namn: 46
#   lokal_namn: 89
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 494
# Best match row index in human data: 28
# Best match score: 62.8
#   konsert_namn: 43
#   lokal_namn: 89
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 943
# Best match row index in human data: 28
# Best match score: 77.60000000000001
#   konsert_namn: 42
#   lokal_namn: 89
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 26
#
# Row index in LLM data: 948
# Best match row index in human data: 28
# Best match score: 42.7
#   konsert_namn: 45
#   lokal_namn: 48
#   konsert_biljettpris: 0
#   konserttyp_namn: 55
#   Producer: 0
#
# Row index in LLM data: 949
# Best match row index in human data: 28
# Best match score: 47.00000000000001
#   konsert_namn: 41
#   lokal_namn: 55
#   konsert_biljettpris: 0
#   konserttyp_namn: 56
#   Producer: 15
#
# Row index in LLM data: 950
# Best match row index in human data: 25
# Best match score: 82.4
#   konsert_namn: 65
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 951
# Best match row index in human data: 28
# Best match score: 78.0
#   konsert_namn: 51
#   lokal_namn: 94
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 955
# Best match row index in human data: 27
# Best match score: 70.6
#   konsert_namn: 39
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 36
#   Producer: 25
#
# Row index in LLM data: 960
# Best match row index in human data: 24
# Best match score: 81.19999999999999
#   konsert_namn: 100
#   lokal_namn: 44
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 18
#
# Row index in LLM data: 966
# Best match row index in human data: 27
# Best match score: 70.6
#   konsert_namn: 39
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 36
#   Producer: 25
#
# Row index in LLM data: 1002
# Best match row index in human data: 27
# Best match score: 67.0
#   konsert_namn: 44
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 30
#   Producer: 0
#
# Row index in LLM data: 1013
# Best match row index in human data: 27
# Best match score: 90.4
#   konsert_namn: 81
#   lokal_namn: 100
#   konsert_biljettpris: 0
#   konserttyp_namn: 30
#   Producer: 75
#
# Row index in LLM data: 24
# Best match row index in human data: 29
# Best match score: 65.6
#   konsert_namn: 60
#   lokal_namn: 60
#   konsert_biljettpris: 76
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 79
# Best match row index in human data: 29
# Best match score: 87.9
#   konsert_namn: 87
#   lokal_namn: 60
#   konsert_biljettpris: 76
#   konserttyp_namn: 53
#   Producer: 81
#
# Row index in LLM data: 953
# Best match row index in human data: 29
# Best match score: 57.2
#   konsert_namn: 42
#   lokal_namn: 57
#   konsert_biljettpris: 76
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 1000
# Best match row index in human data: 29
# Best match score: 61.6
#   konsert_namn: 42
#   lokal_namn: 52
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 20
#
# Row index in LLM data: 669
# Best match row index in human data: 33
# Best match score: 41.2
#   konsert_namn: 19
#   lokal_namn: 62
#   konsert_biljettpris: 0
#   konserttyp_namn: 88
#   Producer: 0
#
# Row index in LLM data: 670
# Best match row index in human data: 32
# Best match score: 26.6
#   konsert_namn: 32
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 62
#   Producer: 38
#
# Row index in LLM data: 673
# Best match row index in human data: 32
# Best match score: 31.800000000000004
#   konsert_namn: 30
#   lokal_namn: 24
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 12
#
# Row index in LLM data: 53
# Best match row index in human data: 34
# Best match score: 38.800000000000004
#   konsert_namn: 21
#   lokal_namn: 27
#   konsert_biljettpris: 100
#   konserttyp_namn: 18
#   Producer: 39
#
# Row index in LLM data: 975
# Best match row index in human data: 34
# Best match score: 30.8
#   konsert_namn: 22
#   lokal_namn: 25
#   konsert_biljettpris: 100
#   konserttyp_namn: 20
#   Producer: 0
#
# Row index in LLM data: 51
# Best match row index in human data: 39
# Best match score: 49.400000000000006
#   konsert_namn: 42
#   lokal_namn: 47
#   konsert_biljettpris: 83
#   konserttyp_namn: 55
#   Producer: 0
#
# Row index in LLM data: 642
# Best match row index in human data: 39
# Best match score: 45.6
#   konsert_namn: 40
#   lokal_namn: 47
#   konsert_biljettpris: 0
#   konserttyp_namn: 56
#   Producer: 26
#
# Row index in LLM data: 643
# Best match row index in human data: 39
# Best match score: 30.7
#   konsert_namn: 26
#   lokal_namn: 23
#   konsert_biljettpris: 0
#   konserttyp_namn: 69
#   Producer: 21
#
# Row index in LLM data: 644
# Best match row index in human data: 39
# Best match score: 50.2
#   konsert_namn: 44
#   lokal_namn: 62
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 647
# Best match row index in human data: 39
# Best match score: 42.300000000000004
#   konsert_namn: 47
#   lokal_namn: 25
#   konsert_biljettpris: 0
#   konserttyp_namn: 69
#   Producer: 33
#
# Row index in LLM data: 648
# Best match row index in human data: 38
# Best match score: 29.900000000000002
#   konsert_namn: 46
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 55
#   Producer: 30
#
# Row index in LLM data: 911
# Best match row index in human data: 39
# Best match score: 51.10000000000001
#   konsert_namn: 42
#   lokal_namn: 59
#   konsert_biljettpris: 40
#   konserttyp_namn: 67
#   Producer: 0
#
# Row index in LLM data: 913
# Best match row index in human data: 38
# Best match score: 69.4
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 22
#   Producer: 0
#
# Row index in LLM data: 916
# Best match row index in human data: 38
# Best match score: 41.900000000000006
#   konsert_namn: 44
#   lokal_namn: 32
#   konsert_biljettpris: 0
#   konserttyp_namn: 53
#   Producer: 31
#
# Row index in LLM data: 917
# Best match row index in human data: 38
# Best match score: 31.4
#   konsert_namn: 23
#   lokal_namn: 32
#   konsert_biljettpris: 0
#   konserttyp_namn: 30
#   Producer: 32
#
# Row index in LLM data: 967
# Best match row index in human data: 38
# Best match score: 74.39999999999999
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 26
#   konserttyp_namn: 62
#   Producer: 24
#
# Row index in LLM data: 83
# Best match row index in human data: 40
# Best match score: 57.9
#   konsert_namn: 58
#   lokal_namn: 31
#   konsert_biljettpris: 100
#   konserttyp_namn: 69
#   Producer: 27
#
# Row index in LLM data: 84
# Best match row index in human data: 41
# Best match score: 58.4
#   konsert_namn: 23
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 64
#   Producer: 100
#
# Row index in LLM data: 912
# Best match row index in human data: 41
# Best match score: 70.0
#   konsert_namn: 56
#   lokal_namn: 94
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 918
# Best match row index in human data: 41
# Best match score: 63.8
#   konsert_namn: 67
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 70
#   Producer: 100
#
# Row index in LLM data: 944
# Best match row index in human data: 41
# Best match score: 70.0
#   konsert_namn: 56
#   lokal_namn: 94
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 954
# Best match row index in human data: 41
# Best match score: 78.6
#   konsert_namn: 56
#   lokal_namn: 69
#   konsert_biljettpris: 0
#   konserttyp_namn: 86
#   Producer: 100
#
# Row index in LLM data: 969
# Best match row index in human data: 42
# Best match score: 111.60000000000001
#   konsert_namn: 88
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 52
# Best match row index in human data: 44
# Best match score: 60.6
#   konsert_namn: 40
#   lokal_namn: 60
#   konsert_biljettpris: 76
#   konserttyp_namn: 100
#   Producer: 15
#
# Row index in LLM data: 438
# Best match row index in human data: 44
# Best match score: 75.8
#   konsert_namn: 79
#   lokal_namn: 60
#   konsert_biljettpris: 50
#   konserttyp_namn: 100
#   Producer: 26
#
# Row index in LLM data: 493
# Best match row index in human data: 44
# Best match score: 75.8
#   konsert_namn: 79
#   lokal_namn: 60
#   konsert_biljettpris: 50
#   konserttyp_namn: 100
#   Producer: 26
#
# Row index in LLM data: 914
# Best match row index in human data: 44
# Best match score: 74.8
#   konsert_namn: 26
#   lokal_namn: 85
#   konsert_biljettpris: 76
#   konserttyp_namn: 100
#   Producer: 64
#
# Row index in LLM data: 970
# Best match row index in human data: 44
# Best match score: 64.0
#   konsert_namn: 47
#   lokal_namn: 32
#   konsert_biljettpris: 76
#   konserttyp_namn: 100
#   Producer: 74
#
# Row index in LLM data: 50
# Best match row index in human data: 47
# Best match score: 43.7
#   konsert_namn: 44
#   lokal_namn: 32
#   konsert_biljettpris: 42
#   konserttyp_namn: 61
#   Producer: 15
#
# Row index in LLM data: 80
# Best match row index in human data: 46
# Best match score: 49.30000000000001
#   konsert_namn: 79
#   lokal_namn: 0
#   konsert_biljettpris: 68
#   konserttyp_namn: 61
#   Producer: 24
#
# Row index in LLM data: 85
# Best match row index in human data: 46
# Best match score: 52.7
#   konsert_namn: 68
#   lokal_namn: 37
#   konsert_biljettpris: 26
#   konserttyp_namn: 61
#   Producer: 10
#
# Row index in LLM data: 956
# Best match row index in human data: 46
# Best match score: 31.900000000000002
#   konsert_namn: 38
#   lokal_namn: 0
#   konsert_biljettpris: 63
#   konserttyp_namn: 56
#   Producer: 24
#
# Row index in LLM data: 971
# Best match row index in human data: 46
# Best match score: 68.10000000000001
#   konsert_namn: 38
#   lokal_namn: 100
#   konsert_biljettpris: 26
#   konserttyp_namn: 55
#   Producer: 24
#
# Row index in LLM data: 957
# Best match row index in human data: 50
# Best match score: 31.900000000000002
#   konsert_namn: 38
#   lokal_namn: 0
#   konsert_biljettpris: 63
#   konserttyp_namn: 56
#   Producer: 24
#
# Row index in LLM data: 972
# Best match row index in human data: 50
# Best match score: 68.10000000000001
#   konsert_namn: 38
#   lokal_namn: 100
#   konsert_biljettpris: 26
#   konserttyp_namn: 55
#   Producer: 24
#
# Row index in LLM data: 1028
# Best match row index in human data: 52
# Best match score: 66.6
#   konsert_namn: 100
#   lokal_namn: 36
#   konsert_biljettpris: 0
#   konserttyp_namn: 82
#   Producer: 20
#
# Row index in LLM data: 1032
# Best match row index in human data: 53
# Best match score: 34.900000000000006
#   konsert_namn: 30
#   lokal_namn: 32
#   konsert_biljettpris: 0
#   konserttyp_namn: 21
#   Producer: 40
#
# Row index in LLM data: 1033
# Best match row index in human data: 52
# Best match score: 23.7
#   konsert_namn: 15
#   lokal_namn: 21
#   konsert_biljettpris: 0
#   konserttyp_namn: 33
#   Producer: 30
#
# Row index in LLM data: 55
# Best match row index in human data: 55
# Best match score: 73.4
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 0
#   konserttyp_namn: 62
#   Producer: 32
#
# Row index in LLM data: 57
# Best match row index in human data: 56
# Best match score: 38.0
#   konsert_namn: 45
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 100
#
# Row index in LLM data: 568
# Best match row index in human data: 55
# Best match score: 46.800000000000004
#   konsert_namn: 56
#   lokal_namn: 33
#   konsert_biljettpris: 0
#   konserttyp_namn: 62
#   Producer: 25
#
# Row index in LLM data: 676
# Best match row index in human data: 55
# Best match score: 44.400000000000006
#   konsert_namn: 64
#   lokal_namn: 22
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 910
# Best match row index in human data: 56
# Best match score: 40.400000000000006
#   konsert_namn: 26
#   lokal_namn: 42
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 34
#
# Row index in LLM data: 931
# Best match row index in human data: 55
# Best match score: 38.7
#   konsert_namn: 49
#   lokal_namn: 33
#   konsert_biljettpris: 0
#   konserttyp_namn: 59
#   Producer: 0
#
# Row index in LLM data: 933
# Best match row index in human data: 55
# Best match score: 73.6
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 25
#
# Row index in LLM data: 934
# Best match row index in human data: 56
# Best match score: 50.4
#   konsert_namn: 38
#   lokal_namn: 43
#   konsert_biljettpris: 54
#   konserttyp_namn: 62
#   Producer: 32
#
# Row index in LLM data: 939
# Best match row index in human data: 56
# Best match score: 46.5
#   konsert_namn: 55
#   lokal_namn: 42
#   konsert_biljettpris: 0
#   konserttyp_namn: 47
#   Producer: 15
#
# Row index in LLM data: 958
# Best match row index in human data: 56
# Best match score: 42.0
#   konsert_namn: 28
#   lokal_namn: 0
#   konsert_biljettpris: 38
#   konserttyp_namn: 70
#   Producer: 100
#
# Row index in LLM data: 973
# Best match row index in human data: 54
# Best match score: 68.10000000000001
#   konsert_namn: 38
#   lokal_namn: 100
#   konsert_biljettpris: 26
#   konserttyp_namn: 55
#   Producer: 24
#
# Row index in LLM data: 1029
# Best match row index in human data: 56
# Best match score: 66.69999999999999
#   konsert_namn: 37
#   lokal_namn: 43
#   konsert_biljettpris: 83
#   konserttyp_namn: 64
#   Producer: 100
#
# Row index in LLM data: 1031
# Best match row index in human data: 55
# Best match score: 74.5
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 70
#   konserttyp_namn: 67
#   Producer: 0
#
# Row index in LLM data: 56
# Best match row index in human data: 57
# Best match score: 67.4
#   konsert_namn: 59
#   lokal_namn: 64
#   konsert_biljettpris: 100
#   konserttyp_namn: 82
#   Producer: 0
#
# Row index in LLM data: 86
# Best match row index in human data: 60
# Best match score: 73.80000000000001
#   konsert_namn: 22
#   lokal_namn: 94
#   konsert_biljettpris: 0
#   konserttyp_namn: 74
#   Producer: 100
#
# Row index in LLM data: 431
# Best match row index in human data: 59
# Best match score: 111.60000000000001
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 52
#   Producer: 100
#
# Row index in LLM data: 432
# Best match row index in human data: 59
# Best match score: 116.4
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 486
# Best match row index in human data: 59
# Best match score: 111.60000000000001
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 52
#   Producer: 100
#
# Row index in LLM data: 487
# Best match row index in human data: 59
# Best match score: 116.4
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 584
# Best match row index in human data: 57
# Best match score: 55.400000000000006
#   konsert_namn: 41
#   lokal_namn: 53
#   konsert_biljettpris: 44
#   konserttyp_namn: 100
#   Producer: 17
#
# Row index in LLM data: 915
# Best match row index in human data: 58
# Best match score: 50.00000000000001
#   konsert_namn: 31
#   lokal_namn: 41
#   konsert_biljettpris: 100
#   konserttyp_namn: 58
#   Producer: 27
#
# Row index in LLM data: 935
# Best match row index in human data: 59
# Best match score: 96.4
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 936
# Best match row index in human data: 60
# Best match score: 97.2
#   konsert_namn: 61
#   lokal_namn: 94
#   konsert_biljettpris: 100
#   konserttyp_namn: 52
#   Producer: 100
#
# Row index in LLM data: 940
# Best match row index in human data: 58
# Best match score: 58.00000000000001
#   konsert_namn: 96
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 96
#   Producer: 0
#
# Row index in LLM data: 1030
# Best match row index in human data: 59
# Best match score: 97.0
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 70
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 938
# Best match row index in human data: 62
# Best match score: 63.900000000000006
#   konsert_namn: 24
#   lokal_namn: 79
#   konsert_biljettpris: 0
#   konserttyp_namn: 27
#   Producer: 100
#
# Row index in LLM data: 614
# Best match row index in human data: 65
# Best match score: 87.60000000000001
#   konsert_namn: 85
#   lokal_namn: 85
#   konsert_biljettpris: 52
#   konserttyp_namn: 30
#   Producer: 57
#
# Row index in LLM data: 616
# Best match row index in human data: 66
# Best match score: 42.10000000000001
#   konsert_namn: 47
#   lokal_namn: 24
#   konsert_biljettpris: 21
#   konserttyp_namn: 48
#   Producer: 34
#
# Row index in LLM data: 617
# Best match row index in human data: 66
# Best match score: 48.199999999999996
#   konsert_namn: 47
#   lokal_namn: 40
#   konsert_biljettpris: 0
#   konserttyp_namn: 74
#   Producer: 30
#
# Row index in LLM data: 650
# Best match row index in human data: 65
# Best match score: 40.900000000000006
#   konsert_namn: 32
#   lokal_namn: 38
#   konsert_biljettpris: 21
#   konserttyp_namn: 58
#   Producer: 25
#
# Row index in LLM data: 937
# Best match row index in human data: 65
# Best match score: 62.900000000000006
#   konsert_namn: 19
#   lokal_namn: 85
#   konsert_biljettpris: 76
#   konserttyp_namn: 57
#   Producer: 40
#
# Row index in LLM data: 6
# Best match row index in human data: 68
# Best match score: 69.8
#   konsert_namn: 100
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 42
# Best match row index in human data: 68
# Best match score: 67.9
#   konsert_namn: 87
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 57
#   Producer: 23
#
# Row index in LLM data: 54
# Best match row index in human data: 68
# Best match score: 64.9
#   konsert_namn: 94
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 53
#   Producer: 0
#
# Row index in LLM data: 58
# Best match row index in human data: 68
# Best match score: 68.2
#   konsert_namn: 100
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 62
#   Producer: 0
#
# Row index in LLM data: 81
# Best match row index in human data: 68
# Best match score: 39.0
#   konsert_namn: 27
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 62
#   Producer: 0
#
# Row index in LLM data: 405
# Best match row index in human data: 68
# Best match score: 89.8
#   konsert_namn: 100
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 427
# Best match row index in human data: 68
# Best match score: 88.60000000000001
#   konsert_namn: 97
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 460
# Best match row index in human data: 68
# Best match score: 89.8
#   konsert_namn: 100
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 482
# Best match row index in human data: 68
# Best match score: 88.60000000000001
#   konsert_namn: 97
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 945
# Best match row index in human data: 68
# Best match score: 69.8
#   konsert_namn: 100
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 1001
# Best match row index in human data: 68
# Best match score: 61.7
#   konsert_namn: 100
#   lokal_namn: 30
#   konsert_biljettpris: 57
#   konserttyp_namn: 40
#   Producer: 0
#
# Row index in LLM data: 71
# Best match row index in human data: 70
# Best match score: 55.4
#   konsert_namn: 50
#   lokal_namn: 42
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 43
#
# Row index in LLM data: 428
# Best match row index in human data: 71
# Best match score: 37.60000000000001
#   konsert_namn: 22
#   lokal_namn: 26
#   konsert_biljettpris: 100
#   konserttyp_namn: 52
#   Producer: 16
#
# Row index in LLM data: 483
# Best match row index in human data: 71
# Best match score: 37.60000000000001
#   konsert_namn: 22
#   lokal_namn: 26
#   konsert_biljettpris: 100
#   konserttyp_namn: 52
#   Producer: 16
#
# Row index in LLM data: 590
# Best match row index in human data: 70
# Best match score: 82.19999999999999
#   konsert_namn: 67
#   lokal_namn: 100
#   konsert_biljettpris: 16
#   konserttyp_namn: 100
#   Producer: 19
#
# Row index in LLM data: 926
# Best match row index in human data: 71
# Best match score: 28.0
#   konsert_namn: 70
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 927
# Best match row index in human data: 70
# Best match score: 78.8
#   konsert_namn: 47
#   lokal_namn: 100
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 930
# Best match row index in human data: 70
# Best match score: 55.6
#   konsert_namn: 100
#   lokal_namn: 39
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 702
# Best match row index in human data: 73
# Best match score: 40.5
#   konsert_namn: 52
#   lokal_namn: 22
#   konsert_biljettpris: 0
#   konserttyp_namn: 69
#   Producer: 20
#
# Row index in LLM data: 902
# Best match row index in human data: 73
# Best match score: 68.6
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 26
#   konserttyp_namn: 52
#   Producer: 0
#
# Row index in LLM data: 909
# Best match row index in human data: 73
# Best match score: 47.80000000000001
#   konsert_namn: 44
#   lokal_namn: 29
#   konsert_biljettpris: 46
#   konserttyp_namn: 78
#   Producer: 31
#
# Row index in LLM data: 928
# Best match row index in human data: 73
# Best match score: 72.9
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 30
#   konserttyp_namn: 27
#   Producer: 32
#
# Row index in LLM data: 59
# Best match row index in human data: 75
# Best match score: 10.0
#   konsert_namn: 0
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 62
# Best match row index in human data: 75
# Best match score: 55.0
#   konsert_namn: 61
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 63
# Best match row index in human data: 75
# Best match score: 56.099999999999994
#   konsert_namn: 62
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 69
#   Producer: 12
#
# Row index in LLM data: 64
# Best match row index in human data: 75
# Best match score: 39.400000000000006
#   konsert_namn: 32
#   lokal_namn: 26
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 42
#
# Row index in LLM data: 562
# Best match row index in human data: 74
# Best match score: 73.8
#   konsert_namn: 67
#   lokal_namn: 64
#   konsert_biljettpris: 29
#   konserttyp_namn: 33
#   Producer: 76
#
# Row index in LLM data: 700
# Best match row index in human data: 75
# Best match score: 58.400000000000006
#   konsert_namn: 96
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 903
# Best match row index in human data: 74
# Best match score: 62.39999999999999
#   konsert_namn: 31
#   lokal_namn: 79
#   konsert_biljettpris: 78
#   konserttyp_namn: 78
#   Producer: 14
#
# Row index in LLM data: 904
# Best match row index in human data: 76
# Best match score: 73.60000000000001
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 64
#   Producer: 0
#
# Row index in LLM data: 908
# Best match row index in human data: 75
# Best match score: 69.2
#   konsert_namn: 96
#   lokal_namn: 52
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 929
# Best match row index in human data: 76
# Best match score: 96.4
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 976
# Best match row index in human data: 74
# Best match score: 49.3
#   konsert_namn: 21
#   lokal_namn: 59
#   konsert_biljettpris: 67
#   konserttyp_namn: 78
#   Producer: 14
#
# Row index in LLM data: 980
# Best match row index in human data: 75
# Best match score: 10.0
#   konsert_namn: 0
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 981
# Best match row index in human data: 75
# Best match score: 55.0
#   konsert_namn: 61
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 982
# Best match row index in human data: 75
# Best match score: 58.80000000000001
#   konsert_namn: 46
#   lokal_namn: 48
#   konsert_biljettpris: 100
#   konserttyp_namn: 52
#   Producer: 30
#
# Row index in LLM data: 983
# Best match row index in human data: 75
# Best match score: 60.599999999999994
#   konsert_namn: 26
#   lokal_namn: 81
#   konsert_biljettpris: 100
#   konserttyp_namn: 30
#   Producer: 24
#
# Row index in LLM data: 74
# Best match row index in human data: 77
# Best match score: 42.400000000000006
#   konsert_namn: 24
#   lokal_namn: 39
#   konsert_biljettpris: 100
#   konserttyp_namn: 36
#   Producer: 18
#
# Row index in LLM data: 76
# Best match row index in human data: 77
# Best match score: 26.8
#   konsert_namn: 29
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 32
#   Producer: 10
#
# Row index in LLM data: 77
# Best match row index in human data: 77
# Best match score: 27.200000000000003
#   konsert_namn: 25
#   lokal_namn: 34
#   konsert_biljettpris: 0
#   konserttyp_namn: 36
#   Producer: 0
#
# Row index in LLM data: 581
# Best match row index in human data: 77
# Best match score: 50.8
#   konsert_namn: 29
#   lokal_namn: 45
#   konsert_biljettpris: 100
#   konserttyp_namn: 38
#   Producer: 37
#
# Row index in LLM data: 661
# Best match row index in human data: 77
# Best match score: 36.400000000000006
#   konsert_namn: 18
#   lokal_namn: 40
#   konsert_biljettpris: 100
#   konserttyp_namn: 32
#   Producer: 0
#
# Row index in LLM data: 662
# Best match row index in human data: 77
# Best match score: 38.800000000000004
#   konsert_namn: 23
#   lokal_namn: 41
#   konsert_biljettpris: 100
#   konserttyp_namn: 32
#   Producer: 0
#
# Row index in LLM data: 663
# Best match row index in human data: 77
# Best match score: 10.0
#   konsert_namn: 0
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 38
# Best match row index in human data: 78
# Best match score: 31.800000000000004
#   konsert_namn: 53
#   lokal_namn: 9
#   konsert_biljettpris: 0
#   konserttyp_namn: 70
#   Producer: 0
#
# Row index in LLM data: 39
# Best match row index in human data: 78
# Best match score: 38.6
#   konsert_namn: 44
#   lokal_namn: 28
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 17
#
# Row index in LLM data: 72
# Best match row index in human data: 78
# Best match score: 53.0
#   konsert_namn: 55
#   lokal_namn: 10
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 96
#
# Row index in LLM data: 429
# Best match row index in human data: 78
# Best match score: 84.2
#   konsert_namn: 57
#   lokal_namn: 84
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 484
# Best match row index in human data: 78
# Best match score: 84.2
#   konsert_namn: 57
#   lokal_namn: 84
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 582
# Best match row index in human data: 78
# Best match score: 32.0
#   konsert_namn: 30
#   lokal_namn: 14
#   konsert_biljettpris: 0
#   konserttyp_namn: 70
#   Producer: 37
#
# Row index in LLM data: 664
# Best match row index in human data: 78
# Best match score: 41.0
#   konsert_namn: 17
#   lokal_namn: 32
#   konsert_biljettpris: 74
#   konserttyp_namn: 78
#   Producer: 31
#
# Row index in LLM data: 704
# Best match row index in human data: 78
# Best match score: 61.199999999999996
#   konsert_namn: 43
#   lokal_namn: 79
#   konsert_biljettpris: 0
#   konserttyp_namn: 48
#   Producer: 38
#
# Row index in LLM data: 905
# Best match row index in human data: 78
# Best match score: 82.0
#   konsert_namn: 100
#   lokal_namn: 79
#   konsert_biljettpris: 0
#   konserttyp_namn: 42
#   Producer: 31
#
# Row index in LLM data: 924
# Best match row index in human data: 78
# Best match score: 36.6
#   konsert_namn: 30
#   lokal_namn: 43
#   konsert_biljettpris: 0
#   konserttyp_namn: 12
#   Producer: 31
#
# Row index in LLM data: 45
# Best match row index in human data: 79
# Best match score: 72.4
#   konsert_namn: 49
#   lokal_namn: 79
#   konsert_biljettpris: 72
#   konserttyp_namn: 78
#   Producer: 31
#
# Row index in LLM data: 436
# Best match row index in human data: 79
# Best match score: 67.30000000000001
#   konsert_namn: 47
#   lokal_namn: 79
#   konsert_biljettpris: 91
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 491
# Best match row index in human data: 79
# Best match score: 67.30000000000001
#   konsert_namn: 47
#   lokal_namn: 79
#   konsert_biljettpris: 91
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 684
# Best match row index in human data: 79
# Best match score: 35.6
#   konsert_namn: 47
#   lokal_namn: 17
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 919
# Best match row index in human data: 79
# Best match score: 41.6
#   konsert_namn: 78
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 58
#   Producer: 23
#
# Row index in LLM data: 977
# Best match row index in human data: 79
# Best match score: 68.8
#   konsert_namn: 56
#   lokal_namn: 79
#   konsert_biljettpris: 70
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 1
# Best match row index in human data: 81
# Best match score: 39.199999999999996
#   konsert_namn: 13
#   lokal_namn: 44
#   konsert_biljettpris: 100
#   konserttyp_namn: 64
#   Producer: 0
#
# Row index in LLM data: 2
# Best match row index in human data: 81
# Best match score: 49.2
#   konsert_namn: 25
#   lokal_namn: 48
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 35
# Best match row index in human data: 80
# Best match score: 58.00000000000001
#   konsert_namn: 58
#   lokal_namn: 41
#   konsert_biljettpris: 89
#   konserttyp_namn: 55
#   Producer: 20
#
# Row index in LLM data: 510
# Best match row index in human data: 81
# Best match score: 43.800000000000004
#   konsert_namn: 13
#   lokal_namn: 48
#   konsert_biljettpris: 100
#   konserttyp_namn: 64
#   Producer: 15
#
# Row index in LLM data: 543
# Best match row index in human data: 80
# Best match score: 67.7
#   konsert_namn: 67
#   lokal_namn: 64
#   konsert_biljettpris: 35
#   konserttyp_namn: 78
#   Producer: 20
#
# Row index in LLM data: 557
# Best match row index in human data: 80
# Best match score: 60.400000000000006
#   konsert_namn: 87
#   lokal_namn: 64
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 558
# Best match row index in human data: 80
# Best match score: 69.7
#   konsert_namn: 87
#   lokal_namn: 64
#   konsert_biljettpris: 0
#   konserttyp_namn: 55
#   Producer: 19
#
# Row index in LLM data: 563
# Best match row index in human data: 80
# Best match score: 62.0
#   konsert_namn: 59
#   lokal_namn: 64
#   konsert_biljettpris: 50
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 591
# Best match row index in human data: 81
# Best match score: 41.2
#   konsert_namn: 11
#   lokal_namn: 92
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 592
# Best match row index in human data: 81
# Best match score: 57.60000000000001
#   konsert_namn: 19
#   lokal_namn: 92
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 16
#
# Row index in LLM data: 612
# Best match row index in human data: 80
# Best match score: 64.8
#   konsert_namn: 54
#   lokal_namn: 64
#   konsert_biljettpris: 50
#   konserttyp_namn: 78
#   Producer: 24
#
# Row index in LLM data: 686
# Best match row index in human data: 80
# Best match score: 48.5
#   konsert_namn: 44
#   lokal_namn: 32
#   konsert_biljettpris: 81
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 687
# Best match row index in human data: 81
# Best match score: 46.20000000000001
#   konsert_namn: 29
#   lokal_namn: 33
#   konsert_biljettpris: 100
#   konserttyp_namn: 48
#   Producer: 33
#
# Row index in LLM data: 703
# Best match row index in human data: 80
# Best match score: 45.7
#   konsert_namn: 26
#   lokal_namn: 41
#   konsert_biljettpris: 89
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 906
# Best match row index in human data: 80
# Best match score: 52.4
#   konsert_namn: 57
#   lokal_namn: 37
#   konsert_biljettpris: 100
#   konserttyp_namn: 18
#   Producer: 15
#
# Row index in LLM data: 920
# Best match row index in human data: 80
# Best match score: 40.3
#   konsert_namn: 51
#   lokal_namn: 0
#   konsert_biljettpris: 81
#   konserttyp_namn: 78
#   Producer: 20
#
# Row index in LLM data: 978
# Best match row index in human data: 80
# Best match score: 40.1
#   konsert_namn: 45
#   lokal_namn: 0
#   konsert_biljettpris: 81
#   konserttyp_namn: 100
#   Producer: 20
#
# Row index in LLM data: 0
# Best match row index in human data: 82
# Best match score: 91.1
#   konsert_namn: 56
#   lokal_namn: 79
#   konsert_biljettpris: 71
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 36
# Best match row index in human data: 82
# Best match score: 75.6
#   konsert_namn: 60
#   lokal_namn: 79
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 48
# Best match row index in human data: 83
# Best match score: 35.800000000000004
#   konsert_namn: 29
#   lokal_namn: 40
#   konsert_biljettpris: 0
#   konserttyp_namn: 48
#   Producer: 17
#
# Row index in LLM data: 60
# Best match row index in human data: 82
# Best match score: 48.5
#   konsert_namn: 30
#   lokal_namn: 0
#   konsert_biljettpris: 65
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 61
# Best match row index in human data: 82
# Best match score: 65.0
#   konsert_namn: 43
#   lokal_namn: 79
#   konsert_biljettpris: 100
#   konserttyp_namn: 62
#   Producer: 0
#
# Row index in LLM data: 70
# Best match row index in human data: 82
# Best match score: 49.2
#   konsert_namn: 34
#   lokal_namn: 64
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 75
# Best match row index in human data: 82
# Best match score: 72.0
#   konsert_namn: 56
#   lokal_namn: 79
#   konsert_biljettpris: 80
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 395
# Best match row index in human data: 83
# Best match score: 63.9
#   konsert_namn: 65
#   lokal_namn: 20
#   konsert_biljettpris: 38
#   konserttyp_namn: 61
#   Producer: 100
#
# Row index in LLM data: 412
# Best match row index in human data: 82
# Best match score: 82.80000000000001
#   konsert_namn: 28
#   lokal_namn: 79
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 413
# Best match row index in human data: 83
# Best match score: 65.9
#   konsert_namn: 65
#   lokal_namn: 24
#   konsert_biljettpris: 42
#   konserttyp_namn: 61
#   Producer: 100
#
# Row index in LLM data: 417
# Best match row index in human data: 82
# Best match score: 85.2
#   konsert_namn: 34
#   lokal_namn: 79
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 418
# Best match row index in human data: 82
# Best match score: 98.2
#   konsert_namn: 51
#   lokal_namn: 100
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 421
# Best match row index in human data: 82
# Best match score: 53.0
#   konsert_namn: 31
#   lokal_namn: 21
#   konsert_biljettpris: 100
#   konserttyp_namn: 22
#   Producer: 100
#
# Row index in LLM data: 450
# Best match row index in human data: 83
# Best match score: 63.9
#   konsert_namn: 65
#   lokal_namn: 20
#   konsert_biljettpris: 38
#   konserttyp_namn: 61
#   Producer: 100
#
# Row index in LLM data: 467
# Best match row index in human data: 82
# Best match score: 82.80000000000001
#   konsert_namn: 28
#   lokal_namn: 79
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 468
# Best match row index in human data: 83
# Best match score: 65.9
#   konsert_namn: 65
#   lokal_namn: 24
#   konsert_biljettpris: 42
#   konserttyp_namn: 61
#   Producer: 100
#
# Row index in LLM data: 472
# Best match row index in human data: 82
# Best match score: 85.2
#   konsert_namn: 34
#   lokal_namn: 79
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 473
# Best match row index in human data: 82
# Best match score: 98.2
#   konsert_namn: 51
#   lokal_namn: 100
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 476
# Best match row index in human data: 82
# Best match score: 53.0
#   konsert_namn: 31
#   lokal_namn: 21
#   konsert_biljettpris: 100
#   konserttyp_namn: 22
#   Producer: 100
#
# Row index in LLM data: 508
# Best match row index in human data: 82
# ...
#   lokal_namn: 21
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 15
#
# Row index in LLM data: 1345
# Best match row index in human data: 448
# Best match score: 35.0
#   konsert_namn: 43
#   lokal_namn: 27
#   konsert_biljettpris: 0
#   konserttyp_namn: 70
#   Producer: 0
#
# Row index in LLM data: 1347
# Best match row index in human data: 448
# Best match score: 40.4
#   konsert_namn: 39
#   lokal_namn: 21
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 50
#
# Row index in LLM data: 356
# Best match row index in human data: 450
# Best match score: 32.4
#   konsert_namn: 28
#   lokal_namn: 35
#   konsert_biljettpris: 29
#   konserttyp_namn: 43
#   Producer: 0
#
# Row index in LLM data: 1346
# Best match row index in human data: 450
# Best match score: 32.4
#   konsert_namn: 28
#   lokal_namn: 35
#   konsert_biljettpris: 29
#   konserttyp_namn: 43
#   Producer: 0
#
# Row index in LLM data: 353
# Best match row index in human data: 452
# Best match score: 52.0
#   konsert_namn: 55
#   lokal_namn: 17
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 16
#
# Row index in LLM data: 879
# Best match row index in human data: 452
# Best match score: 30.400000000000002
#   konsert_namn: 17
#   lokal_namn: 37
#   konsert_biljettpris: 0
#   konserttyp_namn: 88
#   Producer: 0
#
# Row index in LLM data: 882
# Best match row index in human data: 453
# Best match score: 69.0
#   konsert_namn: 48
#   lokal_namn: 81
#   konsert_biljettpris: 100
#   konserttyp_namn: 74
#   Producer: 0
#
# Row index in LLM data: 1343
# Best match row index in human data: 452
# Best match score: 52.0
#   konsert_namn: 55
#   lokal_namn: 17
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 16
#
# Row index in LLM data: 336
# Best match row index in human data: 455
# Best match score: 50.10000000000001
#   konsert_namn: 49
#   lokal_namn: 32
#   konsert_biljettpris: 70
#   konserttyp_namn: 67
#   Producer: 20
#
# Row index in LLM data: 352
# Best match row index in human data: 455
# Best match score: 24.0
#   konsert_namn: 47
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 26
#
# Row index in LLM data: 856
# Best match row index in human data: 455
# Best match score: 62.2
#   konsert_namn: 45
#   lokal_namn: 79
#   konsert_biljettpris: 74
#   konserttyp_namn: 22
#   Producer: 15
#
# Row index in LLM data: 1326
# Best match row index in human data: 455
# Best match score: 50.10000000000001
#   konsert_namn: 49
#   lokal_namn: 32
#   konsert_biljettpris: 70
#   konserttyp_namn: 67
#   Producer: 20
#
# Row index in LLM data: 1342
# Best match row index in human data: 455
# Best match score: 24.0
#   konsert_namn: 47
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 26
#
# Row index in LLM data: 317
# Best match row index in human data: 459
# Best match score: 78.3
#   konsert_namn: 60
#   lokal_namn: 94
#   konsert_biljettpris: 100
#   konserttyp_namn: 67
#   Producer: 0
#
# Row index in LLM data: 323
# Best match row index in human data: 459
# Best match score: 59.2
#   konsert_namn: 75
#   lokal_namn: 43
#   konsert_biljettpris: 50
#   konserttyp_namn: 70
#   Producer: 0
#
# Row index in LLM data: 324
# Best match row index in human data: 458
# Best match score: 69.9
#   konsert_namn: 43
#   lokal_namn: 100
#   konsert_biljettpris: 60
#   konserttyp_namn: 67
#   Producer: 0
#
# Row index in LLM data: 325
# Best match row index in human data: 459
# Best match score: 90.3
#   konsert_namn: 56
#   lokal_namn: 94
#   konsert_biljettpris: 46
#   konserttyp_namn: 67
#   Producer: 95
#
# Row index in LLM data: 327
# Best match row index in human data: 460
# Best match score: 39.2
#   konsert_namn: 37
#   lokal_namn: 25
#   konsert_biljettpris: 22
#   konserttyp_namn: 64
#   Producer: 29
#
# Row index in LLM data: 328
# Best match row index in human data: 457
# Best match score: 46.400000000000006
#   konsert_namn: 33
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 62
#   Producer: 21
#
# Row index in LLM data: 1307
# Best match row index in human data: 459
# Best match score: 78.3
#   konsert_namn: 60
#   lokal_namn: 94
#   konsert_biljettpris: 100
#   konserttyp_namn: 67
#   Producer: 0
#
# Row index in LLM data: 1313
# Best match row index in human data: 459
# Best match score: 59.2
#   konsert_namn: 75
#   lokal_namn: 43
#   konsert_biljettpris: 50
#   konserttyp_namn: 70
#   Producer: 0
#
# Row index in LLM data: 1314
# Best match row index in human data: 458
# Best match score: 69.9
#   konsert_namn: 43
#   lokal_namn: 100
#   konsert_biljettpris: 60
#   konserttyp_namn: 67
#   Producer: 0
#
# Row index in LLM data: 1315
# Best match row index in human data: 459
# Best match score: 90.3
#   konsert_namn: 56
#   lokal_namn: 94
#   konsert_biljettpris: 46
#   konserttyp_namn: 67
#   Producer: 95
#
# Row index in LLM data: 1317
# Best match row index in human data: 460
# Best match score: 39.2
#   konsert_namn: 37
#   lokal_namn: 25
#   konsert_biljettpris: 22
#   konserttyp_namn: 64
#   Producer: 29
#
# Row index in LLM data: 1318
# Best match row index in human data: 457
# Best match score: 46.400000000000006
#   konsert_namn: 33
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 62
#   Producer: 21
#
# Row index in LLM data: 315
# Best match row index in human data: 462
# Best match score: 55.0
#   konsert_namn: 44
#   lokal_namn: 39
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 20
#
# Row index in LLM data: 876
# Best match row index in human data: 462
# Best match score: 56.0
#   konsert_namn: 26
#   lokal_namn: 64
#   konsert_biljettpris: 84
#   konserttyp_namn: 78
#   Producer: 19
#
# Row index in LLM data: 1305
# Best match row index in human data: 462
# Best match score: 55.0
#   konsert_namn: 44
#   lokal_namn: 39
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 20
#
# Row index in LLM data: 316
# Best match row index in human data: 467
# Best match score: 41.300000000000004
#   konsert_namn: 30
#   lokal_namn: 48
#   konsert_biljettpris: 49
#   konserttyp_namn: 52
#   Producer: 0
#
# Row index in LLM data: 326
# Best match row index in human data: 467
# Best match score: 50.3
#   konsert_namn: 50
#   lokal_namn: 48
#   konsert_biljettpris: 23
#   konserttyp_namn: 88
#   Producer: 0
#
# Row index in LLM data: 1306
# Best match row index in human data: 467
# Best match score: 41.300000000000004
#   konsert_namn: 30
#   lokal_namn: 48
#   konsert_biljettpris: 49
#   konserttyp_namn: 52
#   Producer: 0
#
# Row index in LLM data: 1316
# Best match row index in human data: 467
# Best match score: 50.3
#   konsert_namn: 50
#   lokal_namn: 48
#   konsert_biljettpris: 23
#   konserttyp_namn: 88
#   Producer: 0
#
# Row index in LLM data: 385
# Best match row index in human data: 470
# Best match score: 51.60000000000001
#   konsert_namn: 56
#   lokal_namn: 25
#   konsert_biljettpris: 100
#   konserttyp_namn: 56
#   Producer: 18
#
# Row index in LLM data: 386
# Best match row index in human data: 471
# Best match score: 62.800000000000004
#   konsert_namn: 44
#   lokal_namn: 24
#   konsert_biljettpris: 100
#   konserttyp_namn: 56
#   Producer: 100
#
# Row index in LLM data: 387
# Best match row index in human data: 470
# Best match score: 48.60000000000001
#   konsert_namn: 41
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 54
#   Producer: 24
#
# Row index in LLM data: 388
# Best match row index in human data: 471
# Best match score: 44.60000000000001
#   konsert_namn: 39
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 62
#   Producer: 0
#
# Row index in LLM data: 389
# Best match row index in human data: 471
# Best match score: 67.60000000000001
#   konsert_namn: 51
#   lokal_namn: 83
#   konsert_biljettpris: 100
#   konserttyp_namn: 40
#   Producer: 0
#
# Row index in LLM data: 1375
# Best match row index in human data: 470
# Best match score: 51.60000000000001
#   konsert_namn: 56
#   lokal_namn: 25
#   konsert_biljettpris: 100
#   konserttyp_namn: 56
#   Producer: 18
#
# Row index in LLM data: 1376
# Best match row index in human data: 471
# Best match score: 62.800000000000004
#   konsert_namn: 44
#   lokal_namn: 24
#   konsert_biljettpris: 100
#   konserttyp_namn: 56
#   Producer: 100
#
# Row index in LLM data: 1377
# Best match row index in human data: 470
# Best match score: 48.60000000000001
#   konsert_namn: 41
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 54
#   Producer: 24
#
# Row index in LLM data: 1378
# Best match row index in human data: 471
# Best match score: 44.60000000000001
#   konsert_namn: 39
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 62
#   Producer: 0
#
# Row index in LLM data: 1379
# Best match row index in human data: 471
# Best match score: 67.60000000000001
#   konsert_namn: 51
#   lokal_namn: 83
#   konsert_biljettpris: 100
#   konserttyp_namn: 40
#   Producer: 0
#
# Row index in LLM data: 372
# Best match row index in human data: 475
# Best match score: 49.3
#   konsert_namn: 27
#   lokal_namn: 52
#   konsert_biljettpris: 89
#   konserttyp_namn: 64
#   Producer: 12
#
# Row index in LLM data: 374
# Best match row index in human data: 477
# Best match score: 34.599999999999994
#   konsert_namn: 31
#   lokal_namn: 25
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 29
#
# Row index in LLM data: 375
# Best match row index in human data: 477
# Best match score: 50.800000000000004
#   konsert_namn: 49
#   lokal_namn: 39
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 46
#
# Row index in LLM data: 376
# Best match row index in human data: 477
# Best match score: 47.6
#   konsert_namn: 50
#   lokal_namn: 27
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 52
#
# Row index in LLM data: 377
# Best match row index in human data: 475
# Best match score: 26.700000000000003
#   konsert_namn: 15
#   lokal_namn: 19
#   konsert_biljettpris: 67
#   konserttyp_namn: 28
#   Producer: 18
#
# Row index in LLM data: 390
# Best match row index in human data: 475
# Best match score: 36.6
#   konsert_namn: 74
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 70
#   Producer: 0
#
# Row index in LLM data: 1362
# Best match row index in human data: 475
# Best match score: 49.3
#   konsert_namn: 27
#   lokal_namn: 52
#   konsert_biljettpris: 89
#   konserttyp_namn: 64
#   Producer: 12
#
# Row index in LLM data: 1364
# Best match row index in human data: 477
# Best match score: 34.599999999999994
#   konsert_namn: 31
#   lokal_namn: 25
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 29
#
# Row index in LLM data: 1365
# Best match row index in human data: 477
# Best match score: 50.800000000000004
#   konsert_namn: 49
#   lokal_namn: 39
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 46
#
# Row index in LLM data: 1366
# Best match row index in human data: 477
# Best match score: 47.6
#   konsert_namn: 50
#   lokal_namn: 27
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 52
#
# Row index in LLM data: 1367
# Best match row index in human data: 475
# Best match score: 26.700000000000003
#   konsert_namn: 15
#   lokal_namn: 19
#   konsert_biljettpris: 67
#   konserttyp_namn: 28
#   Producer: 18
#
# Row index in LLM data: 1380
# Best match row index in human data: 475
# Best match score: 36.6
#   konsert_namn: 74
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 70
#   Producer: 0
#
# Row index in LLM data: 383
# Best match row index in human data: 478
# Best match score: 74.8
#   konsert_namn: 21
#   lokal_namn: 91
#   konsert_biljettpris: 100
#   konserttyp_namn: 64
#   Producer: 68
#
# Row index in LLM data: 1373
# Best match row index in human data: 478
# Best match score: 74.8
#   konsert_namn: 21
#   lokal_namn: 91
#   konsert_biljettpris: 100
#   konserttyp_namn: 64
#   Producer: 68
#
# Row index in LLM data: 373
# Best match row index in human data: 483
# Best match score: 54.400000000000006
#   konsert_namn: 34
#   lokal_namn: 33
#   konsert_biljettpris: 0
#   konserttyp_namn: 76
#   Producer: 100
#
# Row index in LLM data: 384
# Best match row index in human data: 483
# Best match score: 55.2
#   konsert_namn: 34
#   lokal_namn: 29
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 1363
# Best match row index in human data: 483
# Best match score: 54.400000000000006
#   konsert_namn: 34
#   lokal_namn: 33
#   konsert_biljettpris: 0
#   konserttyp_namn: 76
#   Producer: 100
#
# Row index in LLM data: 1374
# Best match row index in human data: 483
# Best match score: 55.2
#   konsert_namn: 34
#   lokal_namn: 29
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 367
# Best match row index in human data: 505
# Best match score: 18.7
#   konsert_namn: 25
#   lokal_namn: 17
#   konsert_biljettpris: 0
#   konserttyp_namn: 19
#   Producer: 0
#
# Row index in LLM data: 368
# Best match row index in human data: 505
# Best match score: 18.0
#   konsert_namn: 17
#   lokal_namn: 25
#   konsert_biljettpris: 0
#   konserttyp_namn: 12
#   Producer: 0
#
# Row index in LLM data: 369
# Best match row index in human data: 505
# Best match score: 21.3
#   konsert_namn: 21
#   lokal_namn: 26
#   konsert_biljettpris: 0
#   konserttyp_namn: 25
#   Producer: 0
#
# Row index in LLM data: 370
# Best match row index in human data: 505
# Best match score: 17.8
#   konsert_namn: 25
#   lokal_namn: 14
#   konsert_biljettpris: 0
#   konserttyp_namn: 22
#   Producer: 0
#
# Row index in LLM data: 371
# Best match row index in human data: 505
# Best match score: 39.8
#   konsert_namn: 26
#   lokal_namn: 18
#   konsert_biljettpris: 0
#   konserttyp_namn: 22
#   Producer: 100
#
# Row index in LLM data: 1357
# Best match row index in human data: 505
# Best match score: 18.7
#   konsert_namn: 25
#   lokal_namn: 17
#   konsert_biljettpris: 0
#   konserttyp_namn: 19
#   Producer: 0
#
# Row index in LLM data: 1358
# Best match row index in human data: 505
# Best match score: 18.0
#   konsert_namn: 17
#   lokal_namn: 25
#   konsert_biljettpris: 0
#   konserttyp_namn: 12
#   Producer: 0
#
# Row index in LLM data: 1359
# Best match row index in human data: 505
# Best match score: 21.3
#   konsert_namn: 21
#   lokal_namn: 26
#   konsert_biljettpris: 0
#   konserttyp_namn: 25
#   Producer: 0
#
# Row index in LLM data: 1360
# Best match row index in human data: 505
# Best match score: 17.8
#   konsert_namn: 25
#   lokal_namn: 14
#   konsert_biljettpris: 0
#   konserttyp_namn: 22
#   Producer: 0
#
# Row index in LLM data: 1361
# Best match row index in human data: 505
# Best match score: 39.8
#   konsert_namn: 26
#   lokal_namn: 18
#   konsert_biljettpris: 0
#   konserttyp_namn: 22
#   Producer: 100
#
# Row index in LLM data: 835
# Best match row index in human data: 506
# Best match score: 46.8
#   konsert_namn: 43
#   lokal_namn: 24
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 836
# Best match row index in human data: 506
# Best match score: 46.800000000000004
#   konsert_namn: 45
#   lokal_namn: 29
#   konsert_biljettpris: 100
#   konserttyp_namn: 22
#   Producer: 25
#
# Row index in LLM data: 850
# Best match row index in human data: 508
# Best match score: 33.4
#   konsert_namn: 20
#   lokal_namn: 25
#   konsert_biljettpris: 85
#   konserttyp_namn: 69
#   Producer: 0
#
# Row index in LLM data: 849
# Best match row index in human data: 511
# Best match score: 27.500000000000004
#   konsert_namn: 12
#   lokal_namn: 32
#   konsert_biljettpris: 0
#   konserttyp_namn: 33
#   Producer: 33
#
# Row index in LLM data: 828
# Best match row index in human data: 513
# Best match score: 27.000000000000004
#   konsert_namn: 33
#   lokal_namn: 29
#   konsert_biljettpris: 0
#   konserttyp_namn: 22
#   Producer: 0
#
# Row index in LLM data: 829
# Best match row index in human data: 513
# Best match score: 23.2
#   konsert_namn: 25
#   lokal_namn: 31
#   konsert_biljettpris: 0
#   konserttyp_namn: 8
#   Producer: 0
#
# Row index in LLM data: 832
# Best match row index in human data: 512
# Best match score: 79.6
#   konsert_namn: 24
#   lokal_namn: 100
#   konsert_biljettpris: 100
#   konserttyp_namn: 0
#   Producer: 100
#
#
# Unique concerts found by LLM but not by human (total 924):
#       json_row_index  overall_match_score
# 0                666                 31.6
# 1                668                 37.2
# 2                671                 52.7
# 3                433                 75.3
# 5                488                 75.3
# ...              ...                  ...
# 1031             850                 33.4
# 1032             849                 27.5
# 1033             828                 27.0
# 1034             829                 23.2
# 1035             832                 79.6
#
# [924 rows x 2 columns]
#
# Unique concerts found by human but not by LLM (total 460):
#     konsert_datum
# 0      1908-01-02
# 2      1908-01-05
# 3      1908-01-05
# 4      1908-01-05
# 5      1908-01-06
# ..            ...
# 509    1908-12-26
# 510    1908-12-26
# 511    1908-12-27
# 512    1908-12-31
# 513    1908-12-31
#
# [460 rows x 1 columns]

# %%
# Extract JSON matching info from the report and turn it into a table

# Create a DataFrame to store detailed matching information
detailed_matching_info = []

# Iterate over all comparison results to gather detailed matching information
for result in all_comparison_results:
    print(f"Row index in LLM data: {result['json_row_index']}")
    print(f"Best match row index in human data: {result['xls_row_index']}")
    print(f"Best match score: {result['overall_match_score']}")
    
    # Prepare a dictionary to hold details for this particular match
    match_details = {
        'json_row_index': result['json_row_index'],
        'xls_row_index': result['xls_row_index'],
        'overall_match_score': result['overall_match_score']
    }

    # Collect scores for each column that was compared
    for col, score in result.items():
        if col in ['json_row_index', 'xls_row_index', 'overall_match_score', 'original_date']:
            continue
        print(f"  {col}: {score}")
        match_details[col] = score  # Add each score to the match details
    
    # Append the collected match details to the list
    detailed_matching_info.append(match_details)
    print()

# Convert the list to a DataFrame
detailed_matching_df = pd.DataFrame(detailed_matching_info)

# Display the first few rows of the detailed matching DataFrame
print(detailed_matching_df.head())

## Find the best match by identifying the max 'overall_match_score'
best_match = detailed_matching_df[detailed_matching_df['overall_match_score'] == detailed_matching_df['overall_match_score'].max()]

# Display the best match details
if not best_match.empty:
    print("Best Match Details:")
    display(best_match)  # Using 'display' for better formatting in Jupyter Notebook
else:
    print("No matches found or no scores available.")

# Optionally, highlight this in the CSV output
detailed_matching_file_name = f'detailed_matching_info_{report_date}.csv'
detailed_matching_df.to_csv(detailed_matching_file_name, index=False)

# Show this best match separately in a highlighted form if required
highlighted_best_match_file_name = f'best_match_details_{report_date}.csv'
best_match.to_csv(highlighted_best_match_file_name, index=False)
# Out:
# Row index in LLM data: 666
# Best match row index in human data: 0
# Best match score: 31.6
#   konsert_namn: 23
#   lokal_namn: 17
#   konsert_biljettpris: 100
#   konserttyp_namn: 56
#   Producer: 0
#
# Row index in LLM data: 668
# Best match row index in human data: 0
# Best match score: 37.2
#   konsert_namn: 38
#   lokal_namn: 17
#   konsert_biljettpris: 100
#   konserttyp_namn: 52
#   Producer: 0
#
# Row index in LLM data: 671
# Best match row index in human data: 0
# Best match score: 52.7
#   konsert_namn: 30
#   lokal_namn: 79
#   konsert_biljettpris: 0
#   konserttyp_namn: 55
#   Producer: 18
#
# Row index in LLM data: 433
# Best match row index in human data: 1
# Best match score: 75.30000000000001
#   konsert_namn: 53
#   lokal_namn: 100
#   konsert_biljettpris: 55
#   konserttyp_namn: 22
#   Producer: 32
#
# Row index in LLM data: 434
# Best match row index in human data: 1
# Best match score: 88.30000000000001
#   konsert_namn: 66
#   lokal_namn: 100
#   konsert_biljettpris: 55
#   konserttyp_namn: 100
#   Producer: 32
#
# Row index in LLM data: 488
# Best match row index in human data: 1
# Best match score: 75.30000000000001
#   konsert_namn: 53
#   lokal_namn: 100
#   konsert_biljettpris: 55
#   konserttyp_namn: 22
#   Producer: 32
#
# Row index in LLM data: 489
# Best match row index in human data: 1
# Best match score: 88.30000000000001
#   konsert_namn: 66
#   lokal_namn: 100
#   konsert_biljettpris: 55
#   konserttyp_namn: 100
#   Producer: 32
#
# Row index in LLM data: 667
# Best match row index in human data: 1
# Best match score: 96.30000000000001
#   konsert_namn: 61
#   lokal_namn: 98
#   konsert_biljettpris: 53
#   konserttyp_namn: 74
#   Producer: 100
#
# Row index in LLM data: 1022
# Best match row index in human data: 1
# Best match score: 47.0
#   konsert_namn: 33
#   lokal_namn: 24
#   konsert_biljettpris: 0
#   konserttyp_namn: 42
#   Producer: 100
#
# Row index in LLM data: 1023
# Best match row index in human data: 1
# Best match score: 66.2
#   konsert_namn: 53
#   lokal_namn: 79
#   konsert_biljettpris: 0
#   konserttyp_namn: 70
#   Producer: 32
#
# Row index in LLM data: 1024
# Best match row index in human data: 4
# Best match score: 70.39999999999999
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 0
#   konserttyp_namn: 48
#   Producer: 24
#
# Row index in LLM data: 1027
# Best match row index in human data: 3
# Best match score: 66.30000000000001
#   konsert_namn: 54
#   lokal_namn: 20
#   konsert_biljettpris: 100
#   konserttyp_namn: 67
#   Producer: 100
#
# Row index in LLM data: 1025
# Best match row index in human data: 8
# Best match score: 82.3
#   konsert_namn: 100
#   lokal_namn: 59
#   konsert_biljettpris: 81
#   konserttyp_namn: 48
#   Producer: 29
#
# Row index in LLM data: 87
# Best match row index in human data: 9
# Best match score: 68.6
#   konsert_namn: 49
#   lokal_namn: 90
#   konsert_biljettpris: 33
#   konserttyp_namn: 97
#   Producer: 0
#
# Row index in LLM data: 435
# Best match row index in human data: 9
# Best match score: 86.9
#   konsert_namn: 49
#   lokal_namn: 100
#   konsert_biljettpris: 39
#   konserttyp_namn: 100
#   Producer: 67
#
# Row index in LLM data: 490
# Best match row index in human data: 9
# Best match score: 86.9
#   konsert_namn: 49
#   lokal_namn: 100
#   konsert_biljettpris: 39
#   konserttyp_namn: 100
#   Producer: 67
#
# Row index in LLM data: 1026
# Best match row index in human data: 9
# Best match score: 75.5
#   konsert_namn: 35
#   lokal_namn: 85
#   konsert_biljettpris: 44
#   konserttyp_namn: 97
#   Producer: 67
#
# Row index in LLM data: 1011
# Best match row index in human data: 11
# Best match score: 35.400000000000006
#   konsert_namn: 23
#   lokal_namn: 46
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 657
# Best match row index in human data: 12
# Best match score: 43.2
#   konsert_namn: 69
#   lokal_namn: 29
#   konsert_biljettpris: 0
#   konserttyp_namn: 40
#   Producer: 0
#
# Row index in LLM data: 658
# Best match row index in human data: 12
# Best match score: 40.2
#   konsert_namn: 61
#   lokal_namn: 22
#   konsert_biljettpris: 0
#   konserttyp_namn: 70
#   Producer: 0
#
# Row index in LLM data: 659
# Best match row index in human data: 12
# Best match score: 37.2
#   konsert_namn: 37
#   lokal_namn: 25
#   konsert_biljettpris: 0
#   konserttyp_namn: 56
#   Producer: 34
#
# Row index in LLM data: 961
# Best match row index in human data: 12
# Best match score: 94.2
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 963
# Best match row index in human data: 12
# Best match score: 46.2
#   konsert_namn: 71
#   lokal_namn: 25
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 964
# Best match row index in human data: 12
# Best match score: 45.7
#   konsert_namn: 60
#   lokal_namn: 39
#   konsert_biljettpris: 0
#   konserttyp_namn: 61
#   Producer: 0
#
# Row index in LLM data: 965
# Best match row index in human data: 12
# Best match score: 38.2
#   konsert_namn: 55
#   lokal_namn: 30
#   konsert_biljettpris: 0
#   konserttyp_namn: 42
#   Producer: 0
#
# Row index in LLM data: 656
# Best match row index in human data: 13
# Best match score: 63.2
#   konsert_namn: 100
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 16
#
# Row index in LLM data: 26
# Best match row index in human data: 16
# Best match score: 35.2
#   konsert_namn: 49
#   lokal_namn: 39
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 27
# Best match row index in human data: 16
# Best match score: 37.0
#   konsert_namn: 43
#   lokal_namn: 19
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 29
#
# Row index in LLM data: 28
# Best match row index in human data: 17
# Best match score: 40.6
#   konsert_namn: 43
#   lokal_namn: 27
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 13
#
# Row index in LLM data: 415
# Best match row index in human data: 16
# Best match score: 50.80000000000001
#   konsert_namn: 42
#   lokal_namn: 29
#   konsert_biljettpris: 100
#   konserttyp_namn: 52
#   Producer: 36
#
# Row index in LLM data: 416
# Best match row index in human data: 16
# Best match score: 48.60000000000001
#   konsert_namn: 52
#   lokal_namn: 39
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 29
#
# Row index in LLM data: 470
# Best match row index in human data: 16
# Best match score: 50.80000000000001
#   konsert_namn: 42
#   lokal_namn: 29
#   konsert_biljettpris: 100
#   konserttyp_namn: 52
#   Producer: 36
#
# Row index in LLM data: 471
# Best match row index in human data: 16
# Best match score: 48.60000000000001
#   konsert_namn: 52
#   lokal_namn: 39
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 29
#
# Row index in LLM data: 941
# Best match row index in human data: 16
# Best match score: 90.00000000000001
#   konsert_namn: 82
#   lokal_namn: 85
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 27
#
# Row index in LLM data: 942
# Best match row index in human data: 16
# Best match score: 17.400000000000002
#   konsert_namn: 24
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 946
# Best match row index in human data: 16
# Best match score: 38.50000000000001
#   konsert_namn: 41
#   lokal_namn: 26
#   konsert_biljettpris: 65
#   konserttyp_namn: 52
#   Producer: 0
#
# Row index in LLM data: 947
# Best match row index in human data: 16
# Best match score: 32.6
#   konsert_namn: 35
#   lokal_namn: 17
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 27
#
# Row index in LLM data: 962
# Best match row index in human data: 16
# Best match score: 62.800000000000004
#   konsert_namn: 36
#   lokal_namn: 60
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 33
#
# Row index in LLM data: 1012
# Best match row index in human data: 16
# Best match score: 51.1
#   konsert_namn: 40
#   lokal_namn: 60
#   konsert_biljettpris: 100
#   konserttyp_namn: 11
#   Producer: 0
#
# Row index in LLM data: 40
# Best match row index in human data: 18
# Best match score: 36.00000000000001
#   konsert_namn: 26
#   lokal_namn: 22
#   konsert_biljettpris: 26
#   konserttyp_namn: 76
#   Producer: 33
#
# Row index in LLM data: 44
# Best match row index in human data: 18
# Best match score: 27.8
#   konsert_namn: 14
#   lokal_namn: 36
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 414
# Best match row index in human data: 18
# Best match score: 57.199999999999996
#   konsert_namn: 35
#   lokal_namn: 67
#   konsert_biljettpris: 18
#   konserttyp_namn: 80
#   Producer: 33
#
# Row index in LLM data: 469
# Best match row index in human data: 18
# Best match score: 57.199999999999996
#   konsert_namn: 35
#   lokal_namn: 67
#   konsert_biljettpris: 18
#   konserttyp_namn: 80
#   Producer: 33
#
# Row index in LLM data: 4
# Best match row index in human data: 19
# Best match score: 61.800000000000004
#   konsert_namn: 33
#   lokal_namn: 60
#   konsert_biljettpris: 100
#   konserttyp_namn: 22
#   Producer: 62
#
# Row index in LLM data: 7
# Best match row index in human data: 19
# Best match score: 38.8
#   konsert_namn: 35
#   lokal_namn: 29
#   konsert_biljettpris: 0
#   konserttyp_namn: 74
#   Producer: 29
#
# Row index in LLM data: 23
# Best match row index in human data: 20
# Best match score: 49.699999999999996
#   konsert_namn: 62
#   lokal_namn: 20
#   konsert_biljettpris: 43
#   konserttyp_namn: 72
#   Producer: 27
#
# Row index in LLM data: 41
# Best match row index in human data: 19
# Best match score: 72.39999999999999
#   konsert_namn: 42
#   lokal_namn: 100
#   konsert_biljettpris: 100
#   konserttyp_namn: 56
#   Producer: 0
#
# Row index in LLM data: 402
# Best match row index in human data: 19
# Best match score: 56.1
#   konsert_namn: 11
#   lokal_namn: 100
#   konsert_biljettpris: 71
#   konserttyp_namn: 46
#   Producer: 0
#
# Row index in LLM data: 457
# Best match row index in human data: 19
# Best match score: 56.1
#   konsert_namn: 11
#   lokal_namn: 100
#   konsert_biljettpris: 71
#   konserttyp_namn: 46
#   Producer: 0
#
# Row index in LLM data: 660
# Best match row index in human data: 19
# Best match score: 76.00000000000001
#   konsert_namn: 48
#   lokal_namn: 100
#   konsert_biljettpris: 94
#   konserttyp_namn: 24
#   Producer: 25
#
# Row index in LLM data: 998
# Best match row index in human data: 19
# Best match score: 41.0
#   konsert_namn: 27
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 74
#   Producer: 0
#
# Row index in LLM data: 1003
# Best match row index in human data: 19
# Best match score: 40.0
#   konsert_namn: 33
#   lokal_namn: 25
#   konsert_biljettpris: 10
#   konserttyp_namn: 100
#   Producer: 29
#
# Row index in LLM data: 3
# Best match row index in human data: 21
# Best match score: 89.4
#   konsert_namn: 99
#   lokal_namn: 54
#   konsert_biljettpris: 100
#   konserttyp_namn: 58
#   Producer: 62
#
# Row index in LLM data: 43
# Best match row index in human data: 21
# Best match score: 85.60000000000001
#   konsert_namn: 95
#   lokal_namn: 71
#   konsert_biljettpris: 100
#   konserttyp_namn: 58
#   Producer: 17
#
# Row index in LLM data: 401
# Best match row index in human data: 21
# Best match score: 60.400000000000006
#   konsert_namn: 87
#   lokal_namn: 32
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 14
#
# Row index in LLM data: 456
# Best match row index in human data: 21
# Best match score: 60.400000000000006
#   konsert_namn: 87
#   lokal_namn: 32
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 14
#
# Row index in LLM data: 641
# Best match row index in human data: 21
# Best match score: 90.4
#   konsert_namn: 99
#   lokal_namn: 71
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 62
#
# Row index in LLM data: 652
# Best match row index in human data: 23
# Best match score: 75.4
#   konsert_namn: 30
#   lokal_namn: 88
#   konsert_biljettpris: 0
#   konserttyp_namn: 82
#   Producer: 100
#
# Row index in LLM data: 952
# Best match row index in human data: 23
# Best match score: 97.00000000000001
#   konsert_namn: 71
#   lokal_namn: 100
#   konsert_biljettpris: 44
#   konserttyp_namn: 42
#   Producer: 100
#
# Row index in LLM data: 959
# Best match row index in human data: 22
# Best match score: 53.599999999999994
#   konsert_namn: 81
#   lokal_namn: 16
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 24
#
# Row index in LLM data: 968
# Best match row index in human data: 22
# Best match score: 50.5
#   konsert_namn: 64
#   lokal_namn: 26
#   konsert_biljettpris: 25
#   konserttyp_namn: 56
#   Producer: 32
#
# Row index in LLM data: 5
# Best match row index in human data: 28
# Best match score: 75.60000000000001
#   konsert_namn: 42
#   lokal_namn: 89
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 16
#
# Row index in LLM data: 25
# Best match row index in human data: 28
# Best match score: 73.4
#   konsert_namn: 40
#   lokal_namn: 89
#   konsert_biljettpris: 100
#   konserttyp_namn: 86
#   Producer: 16
#
# Row index in LLM data: 78
# Best match row index in human data: 28
# Best match score: 71.0
#   konsert_namn: 42
#   lokal_namn: 89
#   konsert_biljettpris: 86
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 404
# Best match row index in human data: 28
# Best match score: 64.0
#   konsert_namn: 46
#   lokal_namn: 89
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 439
# Best match row index in human data: 28
# Best match score: 62.8
#   konsert_namn: 43
#   lokal_namn: 89
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 459
# Best match row index in human data: 28
# Best match score: 64.0
#   konsert_namn: 46
#   lokal_namn: 89
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 494
# Best match row index in human data: 28
# Best match score: 62.8
#   konsert_namn: 43
#   lokal_namn: 89
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 943
# Best match row index in human data: 28
# Best match score: 77.60000000000001
#   konsert_namn: 42
#   lokal_namn: 89
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 26
#
# Row index in LLM data: 948
# Best match row index in human data: 28
# Best match score: 42.7
#   konsert_namn: 45
#   lokal_namn: 48
#   konsert_biljettpris: 0
#   konserttyp_namn: 55
#   Producer: 0
#
# Row index in LLM data: 949
# Best match row index in human data: 28
# Best match score: 47.00000000000001
#   konsert_namn: 41
#   lokal_namn: 55
#   konsert_biljettpris: 0
#   konserttyp_namn: 56
#   Producer: 15
#
# Row index in LLM data: 950
# Best match row index in human data: 25
# Best match score: 82.4
#   konsert_namn: 65
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 951
# Best match row index in human data: 28
# Best match score: 78.0
#   konsert_namn: 51
#   lokal_namn: 94
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 955
# Best match row index in human data: 27
# Best match score: 70.6
#   konsert_namn: 39
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 36
#   Producer: 25
#
# Row index in LLM data: 960
# Best match row index in human data: 24
# Best match score: 81.19999999999999
#   konsert_namn: 100
#   lokal_namn: 44
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 18
#
# Row index in LLM data: 966
# Best match row index in human data: 27
# Best match score: 70.6
#   konsert_namn: 39
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 36
#   Producer: 25
#
# Row index in LLM data: 1002
# Best match row index in human data: 27
# Best match score: 67.0
#   konsert_namn: 44
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 30
#   Producer: 0
#
# Row index in LLM data: 1013
# Best match row index in human data: 27
# Best match score: 90.4
#   konsert_namn: 81
#   lokal_namn: 100
#   konsert_biljettpris: 0
#   konserttyp_namn: 30
#   Producer: 75
#
# Row index in LLM data: 24
# Best match row index in human data: 29
# Best match score: 65.6
#   konsert_namn: 60
#   lokal_namn: 60
#   konsert_biljettpris: 76
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 79
# Best match row index in human data: 29
# Best match score: 87.9
#   konsert_namn: 87
#   lokal_namn: 60
#   konsert_biljettpris: 76
#   konserttyp_namn: 53
#   Producer: 81
#
# Row index in LLM data: 953
# Best match row index in human data: 29
# Best match score: 57.2
#   konsert_namn: 42
#   lokal_namn: 57
#   konsert_biljettpris: 76
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 1000
# Best match row index in human data: 29
# Best match score: 61.6
#   konsert_namn: 42
#   lokal_namn: 52
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 20
#
# Row index in LLM data: 669
# Best match row index in human data: 33
# Best match score: 41.2
#   konsert_namn: 19
#   lokal_namn: 62
#   konsert_biljettpris: 0
#   konserttyp_namn: 88
#   Producer: 0
#
# Row index in LLM data: 670
# Best match row index in human data: 32
# Best match score: 26.6
#   konsert_namn: 32
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 62
#   Producer: 38
#
# Row index in LLM data: 673
# Best match row index in human data: 32
# Best match score: 31.800000000000004
#   konsert_namn: 30
#   lokal_namn: 24
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 12
#
# Row index in LLM data: 53
# Best match row index in human data: 34
# Best match score: 38.800000000000004
#   konsert_namn: 21
#   lokal_namn: 27
#   konsert_biljettpris: 100
#   konserttyp_namn: 18
#   Producer: 39
#
# Row index in LLM data: 975
# Best match row index in human data: 34
# Best match score: 30.8
#   konsert_namn: 22
#   lokal_namn: 25
#   konsert_biljettpris: 100
#   konserttyp_namn: 20
#   Producer: 0
#
# Row index in LLM data: 51
# Best match row index in human data: 39
# Best match score: 49.400000000000006
#   konsert_namn: 42
#   lokal_namn: 47
#   konsert_biljettpris: 83
#   konserttyp_namn: 55
#   Producer: 0
#
# Row index in LLM data: 642
# Best match row index in human data: 39
# Best match score: 45.6
#   konsert_namn: 40
#   lokal_namn: 47
#   konsert_biljettpris: 0
#   konserttyp_namn: 56
#   Producer: 26
#
# Row index in LLM data: 643
# Best match row index in human data: 39
# Best match score: 30.7
#   konsert_namn: 26
#   lokal_namn: 23
#   konsert_biljettpris: 0
#   konserttyp_namn: 69
#   Producer: 21
#
# Row index in LLM data: 644
# Best match row index in human data: 39
# Best match score: 50.2
#   konsert_namn: 44
#   lokal_namn: 62
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 647
# Best match row index in human data: 39
# Best match score: 42.300000000000004
#   konsert_namn: 47
#   lokal_namn: 25
#   konsert_biljettpris: 0
#   konserttyp_namn: 69
#   Producer: 33
#
# Row index in LLM data: 648
# Best match row index in human data: 38
# Best match score: 29.900000000000002
#   konsert_namn: 46
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 55
#   Producer: 30
#
# Row index in LLM data: 911
# Best match row index in human data: 39
# Best match score: 51.10000000000001
#   konsert_namn: 42
#   lokal_namn: 59
#   konsert_biljettpris: 40
#   konserttyp_namn: 67
#   Producer: 0
#
# Row index in LLM data: 913
# Best match row index in human data: 38
# Best match score: 69.4
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 22
#   Producer: 0
#
# Row index in LLM data: 916
# Best match row index in human data: 38
# Best match score: 41.900000000000006
#   konsert_namn: 44
#   lokal_namn: 32
#   konsert_biljettpris: 0
#   konserttyp_namn: 53
#   Producer: 31
#
# Row index in LLM data: 917
# Best match row index in human data: 38
# Best match score: 31.4
#   konsert_namn: 23
#   lokal_namn: 32
#   konsert_biljettpris: 0
#   konserttyp_namn: 30
#   Producer: 32
#
# Row index in LLM data: 967
# Best match row index in human data: 38
# Best match score: 74.39999999999999
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 26
#   konserttyp_namn: 62
#   Producer: 24
#
# Row index in LLM data: 83
# Best match row index in human data: 40
# Best match score: 57.9
#   konsert_namn: 58
#   lokal_namn: 31
#   konsert_biljettpris: 100
#   konserttyp_namn: 69
#   Producer: 27
#
# Row index in LLM data: 84
# Best match row index in human data: 41
# Best match score: 58.4
#   konsert_namn: 23
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 64
#   Producer: 100
#
# Row index in LLM data: 912
# Best match row index in human data: 41
# Best match score: 70.0
#   konsert_namn: 56
#   lokal_namn: 94
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 918
# Best match row index in human data: 41
# Best match score: 63.8
#   konsert_namn: 67
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 70
#   Producer: 100
#
# Row index in LLM data: 944
# Best match row index in human data: 41
# Best match score: 70.0
#   konsert_namn: 56
#   lokal_namn: 94
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 954
# Best match row index in human data: 41
# Best match score: 78.6
#   konsert_namn: 56
#   lokal_namn: 69
#   konsert_biljettpris: 0
#   konserttyp_namn: 86
#   Producer: 100
#
# Row index in LLM data: 969
# Best match row index in human data: 42
# Best match score: 111.60000000000001
#   konsert_namn: 88
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 52
# Best match row index in human data: 44
# Best match score: 60.6
#   konsert_namn: 40
#   lokal_namn: 60
#   konsert_biljettpris: 76
#   konserttyp_namn: 100
#   Producer: 15
#
# Row index in LLM data: 438
# Best match row index in human data: 44
# Best match score: 75.8
#   konsert_namn: 79
#   lokal_namn: 60
#   konsert_biljettpris: 50
#   konserttyp_namn: 100
#   Producer: 26
#
# Row index in LLM data: 493
# Best match row index in human data: 44
# Best match score: 75.8
#   konsert_namn: 79
#   lokal_namn: 60
#   konsert_biljettpris: 50
#   konserttyp_namn: 100
#   Producer: 26
#
# Row index in LLM data: 914
# Best match row index in human data: 44
# Best match score: 74.8
#   konsert_namn: 26
#   lokal_namn: 85
#   konsert_biljettpris: 76
#   konserttyp_namn: 100
#   Producer: 64
#
# Row index in LLM data: 970
# Best match row index in human data: 44
# Best match score: 64.0
#   konsert_namn: 47
#   lokal_namn: 32
#   konsert_biljettpris: 76
#   konserttyp_namn: 100
#   Producer: 74
#
# Row index in LLM data: 50
# Best match row index in human data: 47
# Best match score: 43.7
#   konsert_namn: 44
#   lokal_namn: 32
#   konsert_biljettpris: 42
#   konserttyp_namn: 61
#   Producer: 15
#
# Row index in LLM data: 80
# Best match row index in human data: 46
# Best match score: 49.30000000000001
#   konsert_namn: 79
#   lokal_namn: 0
#   konsert_biljettpris: 68
#   konserttyp_namn: 61
#   Producer: 24
#
# Row index in LLM data: 85
# Best match row index in human data: 46
# Best match score: 52.7
#   konsert_namn: 68
#   lokal_namn: 37
#   konsert_biljettpris: 26
#   konserttyp_namn: 61
#   Producer: 10
#
# Row index in LLM data: 956
# Best match row index in human data: 46
# Best match score: 31.900000000000002
#   konsert_namn: 38
#   lokal_namn: 0
#   konsert_biljettpris: 63
#   konserttyp_namn: 56
#   Producer: 24
#
# Row index in LLM data: 971
# Best match row index in human data: 46
# Best match score: 68.10000000000001
#   konsert_namn: 38
#   lokal_namn: 100
#   konsert_biljettpris: 26
#   konserttyp_namn: 55
#   Producer: 24
#
# Row index in LLM data: 957
# Best match row index in human data: 50
# Best match score: 31.900000000000002
#   konsert_namn: 38
#   lokal_namn: 0
#   konsert_biljettpris: 63
#   konserttyp_namn: 56
#   Producer: 24
#
# Row index in LLM data: 972
# Best match row index in human data: 50
# Best match score: 68.10000000000001
#   konsert_namn: 38
#   lokal_namn: 100
#   konsert_biljettpris: 26
#   konserttyp_namn: 55
#   Producer: 24
#
# Row index in LLM data: 1028
# Best match row index in human data: 52
# Best match score: 66.6
#   konsert_namn: 100
#   lokal_namn: 36
#   konsert_biljettpris: 0
#   konserttyp_namn: 82
#   Producer: 20
#
# Row index in LLM data: 1032
# Best match row index in human data: 53
# Best match score: 34.900000000000006
#   konsert_namn: 30
#   lokal_namn: 32
#   konsert_biljettpris: 0
#   konserttyp_namn: 21
#   Producer: 40
#
# Row index in LLM data: 1033
# Best match row index in human data: 52
# Best match score: 23.7
#   konsert_namn: 15
#   lokal_namn: 21
#   konsert_biljettpris: 0
#   konserttyp_namn: 33
#   Producer: 30
#
# Row index in LLM data: 55
# Best match row index in human data: 55
# Best match score: 73.4
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 0
#   konserttyp_namn: 62
#   Producer: 32
#
# Row index in LLM data: 57
# Best match row index in human data: 56
# Best match score: 38.0
#   konsert_namn: 45
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 100
#
# Row index in LLM data: 568
# Best match row index in human data: 55
# Best match score: 46.800000000000004
#   konsert_namn: 56
#   lokal_namn: 33
#   konsert_biljettpris: 0
#   konserttyp_namn: 62
#   Producer: 25
#
# Row index in LLM data: 676
# Best match row index in human data: 55
# Best match score: 44.400000000000006
#   konsert_namn: 64
#   lokal_namn: 22
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 910
# Best match row index in human data: 56
# Best match score: 40.400000000000006
#   konsert_namn: 26
#   lokal_namn: 42
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 34
#
# Row index in LLM data: 931
# Best match row index in human data: 55
# Best match score: 38.7
#   konsert_namn: 49
#   lokal_namn: 33
#   konsert_biljettpris: 0
#   konserttyp_namn: 59
#   Producer: 0
#
# Row index in LLM data: 933
# Best match row index in human data: 55
# Best match score: 73.6
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 25
#
# Row index in LLM data: 934
# Best match row index in human data: 56
# Best match score: 50.4
#   konsert_namn: 38
#   lokal_namn: 43
#   konsert_biljettpris: 54
#   konserttyp_namn: 62
#   Producer: 32
#
# Row index in LLM data: 939
# Best match row index in human data: 56
# Best match score: 46.5
#   konsert_namn: 55
#   lokal_namn: 42
#   konsert_biljettpris: 0
#   konserttyp_namn: 47
#   Producer: 15
#
# Row index in LLM data: 958
# Best match row index in human data: 56
# Best match score: 42.0
#   konsert_namn: 28
#   lokal_namn: 0
#   konsert_biljettpris: 38
#   konserttyp_namn: 70
#   Producer: 100
#
# Row index in LLM data: 973
# Best match row index in human data: 54
# Best match score: 68.10000000000001
#   konsert_namn: 38
#   lokal_namn: 100
#   konsert_biljettpris: 26
#   konserttyp_namn: 55
#   Producer: 24
#
# Row index in LLM data: 1029
# Best match row index in human data: 56
# Best match score: 66.69999999999999
#   konsert_namn: 37
#   lokal_namn: 43
#   konsert_biljettpris: 83
#   konserttyp_namn: 64
#   Producer: 100
#
# Row index in LLM data: 1031
# Best match row index in human data: 55
# Best match score: 74.5
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 70
#   konserttyp_namn: 67
#   Producer: 0
#
# Row index in LLM data: 56
# Best match row index in human data: 57
# Best match score: 67.4
#   konsert_namn: 59
#   lokal_namn: 64
#   konsert_biljettpris: 100
#   konserttyp_namn: 82
#   Producer: 0
#
# Row index in LLM data: 86
# Best match row index in human data: 60
# Best match score: 73.80000000000001
#   konsert_namn: 22
#   lokal_namn: 94
#   konsert_biljettpris: 0
#   konserttyp_namn: 74
#   Producer: 100
#
# Row index in LLM data: 431
# Best match row index in human data: 59
# Best match score: 111.60000000000001
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 52
#   Producer: 100
#
# Row index in LLM data: 432
# Best match row index in human data: 59
# Best match score: 116.4
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 486
# Best match row index in human data: 59
# Best match score: 111.60000000000001
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 52
#   Producer: 100
#
# Row index in LLM data: 487
# Best match row index in human data: 59
# Best match score: 116.4
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 584
# Best match row index in human data: 57
# Best match score: 55.400000000000006
#   konsert_namn: 41
#   lokal_namn: 53
#   konsert_biljettpris: 44
#   konserttyp_namn: 100
#   Producer: 17
#
# Row index in LLM data: 915
# Best match row index in human data: 58
# Best match score: 50.00000000000001
#   konsert_namn: 31
#   lokal_namn: 41
#   konsert_biljettpris: 100
#   konserttyp_namn: 58
#   Producer: 27
#
# Row index in LLM data: 935
# Best match row index in human data: 59
# Best match score: 96.4
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 936
# Best match row index in human data: 60
# Best match score: 97.2
#   konsert_namn: 61
#   lokal_namn: 94
#   konsert_biljettpris: 100
#   konserttyp_namn: 52
#   Producer: 100
#
# Row index in LLM data: 940
# Best match row index in human data: 58
# Best match score: 58.00000000000001
#   konsert_namn: 96
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 96
#   Producer: 0
#
# Row index in LLM data: 1030
# Best match row index in human data: 59
# Best match score: 97.0
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 70
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 938
# Best match row index in human data: 62
# Best match score: 63.900000000000006
#   konsert_namn: 24
#   lokal_namn: 79
#   konsert_biljettpris: 0
#   konserttyp_namn: 27
#   Producer: 100
#
# Row index in LLM data: 614
# Best match row index in human data: 65
# Best match score: 87.60000000000001
#   konsert_namn: 85
#   lokal_namn: 85
#   konsert_biljettpris: 52
#   konserttyp_namn: 30
#   Producer: 57
#
# Row index in LLM data: 616
# Best match row index in human data: 66
# Best match score: 42.10000000000001
#   konsert_namn: 47
#   lokal_namn: 24
#   konsert_biljettpris: 21
#   konserttyp_namn: 48
#   Producer: 34
#
# Row index in LLM data: 617
# Best match row index in human data: 66
# Best match score: 48.199999999999996
#   konsert_namn: 47
#   lokal_namn: 40
#   konsert_biljettpris: 0
#   konserttyp_namn: 74
#   Producer: 30
#
# Row index in LLM data: 650
# Best match row index in human data: 65
# Best match score: 40.900000000000006
#   konsert_namn: 32
#   lokal_namn: 38
#   konsert_biljettpris: 21
#   konserttyp_namn: 58
#   Producer: 25
#
# Row index in LLM data: 937
# Best match row index in human data: 65
# Best match score: 62.900000000000006
#   konsert_namn: 19
#   lokal_namn: 85
#   konsert_biljettpris: 76
#   konserttyp_namn: 57
#   Producer: 40
#
# Row index in LLM data: 6
# Best match row index in human data: 68
# Best match score: 69.8
#   konsert_namn: 100
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 42
# Best match row index in human data: 68
# Best match score: 67.9
#   konsert_namn: 87
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 57
#   Producer: 23
#
# Row index in LLM data: 54
# Best match row index in human data: 68
# Best match score: 64.9
#   konsert_namn: 94
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 53
#   Producer: 0
#
# Row index in LLM data: 58
# Best match row index in human data: 68
# Best match score: 68.2
#   konsert_namn: 100
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 62
#   Producer: 0
#
# Row index in LLM data: 81
# Best match row index in human data: 68
# Best match score: 39.0
#   konsert_namn: 27
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 62
#   Producer: 0
#
# Row index in LLM data: 405
# Best match row index in human data: 68
# Best match score: 89.8
#   konsert_namn: 100
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 427
# Best match row index in human data: 68
# Best match score: 88.60000000000001
#   konsert_namn: 97
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 460
# Best match row index in human data: 68
# Best match score: 89.8
#   konsert_namn: 100
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 482
# Best match row index in human data: 68
# Best match score: 88.60000000000001
#   konsert_namn: 97
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 945
# Best match row index in human data: 68
# Best match score: 69.8
#   konsert_namn: 100
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 1001
# Best match row index in human data: 68
# Best match score: 61.7
#   konsert_namn: 100
#   lokal_namn: 30
#   konsert_biljettpris: 57
#   konserttyp_namn: 40
#   Producer: 0
#
# Row index in LLM data: 71
# Best match row index in human data: 70
# Best match score: 55.4
#   konsert_namn: 50
#   lokal_namn: 42
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 43
#
# Row index in LLM data: 428
# Best match row index in human data: 71
# Best match score: 37.60000000000001
#   konsert_namn: 22
#   lokal_namn: 26
#   konsert_biljettpris: 100
#   konserttyp_namn: 52
#   Producer: 16
#
# Row index in LLM data: 483
# Best match row index in human data: 71
# Best match score: 37.60000000000001
#   konsert_namn: 22
#   lokal_namn: 26
#   konsert_biljettpris: 100
#   konserttyp_namn: 52
#   Producer: 16
#
# Row index in LLM data: 590
# Best match row index in human data: 70
# Best match score: 82.19999999999999
#   konsert_namn: 67
#   lokal_namn: 100
#   konsert_biljettpris: 16
#   konserttyp_namn: 100
#   Producer: 19
#
# Row index in LLM data: 926
# Best match row index in human data: 71
# Best match score: 28.0
#   konsert_namn: 70
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 927
# Best match row index in human data: 70
# Best match score: 78.8
#   konsert_namn: 47
#   lokal_namn: 100
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 930
# Best match row index in human data: 70
# Best match score: 55.6
#   konsert_namn: 100
#   lokal_namn: 39
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 702
# Best match row index in human data: 73
# Best match score: 40.5
#   konsert_namn: 52
#   lokal_namn: 22
#   konsert_biljettpris: 0
#   konserttyp_namn: 69
#   Producer: 20
#
# Row index in LLM data: 902
# Best match row index in human data: 73
# Best match score: 68.6
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 26
#   konserttyp_namn: 52
#   Producer: 0
#
# Row index in LLM data: 909
# Best match row index in human data: 73
# Best match score: 47.80000000000001
#   konsert_namn: 44
#   lokal_namn: 29
#   konsert_biljettpris: 46
#   konserttyp_namn: 78
#   Producer: 31
#
# Row index in LLM data: 928
# Best match row index in human data: 73
# Best match score: 72.9
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 30
#   konserttyp_namn: 27
#   Producer: 32
#
# Row index in LLM data: 59
# Best match row index in human data: 75
# Best match score: 10.0
#   konsert_namn: 0
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 62
# Best match row index in human data: 75
# Best match score: 55.0
#   konsert_namn: 61
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 63
# Best match row index in human data: 75
# Best match score: 56.099999999999994
#   konsert_namn: 62
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 69
#   Producer: 12
#
# Row index in LLM data: 64
# Best match row index in human data: 75
# Best match score: 39.400000000000006
#   konsert_namn: 32
#   lokal_namn: 26
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 42
#
# Row index in LLM data: 562
# Best match row index in human data: 74
# Best match score: 73.8
#   konsert_namn: 67
#   lokal_namn: 64
#   konsert_biljettpris: 29
#   konserttyp_namn: 33
#   Producer: 76
#
# Row index in LLM data: 700
# Best match row index in human data: 75
# Best match score: 58.400000000000006
#   konsert_namn: 96
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 903
# Best match row index in human data: 74
# Best match score: 62.39999999999999
#   konsert_namn: 31
#   lokal_namn: 79
#   konsert_biljettpris: 78
#   konserttyp_namn: 78
#   Producer: 14
#
# Row index in LLM data: 904
# Best match row index in human data: 76
# Best match score: 73.60000000000001
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 64
#   Producer: 0
#
# Row index in LLM data: 908
# Best match row index in human data: 75
# Best match score: 69.2
#   konsert_namn: 96
#   lokal_namn: 52
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 929
# Best match row index in human data: 76
# Best match score: 96.4
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 976
# Best match row index in human data: 74
# Best match score: 49.3
#   konsert_namn: 21
#   lokal_namn: 59
#   konsert_biljettpris: 67
#   konserttyp_namn: 78
#   Producer: 14
#
# Row index in LLM data: 980
# Best match row index in human data: 75
# Best match score: 10.0
#   konsert_namn: 0
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 981
# Best match row index in human data: 75
# Best match score: 55.0
#   konsert_namn: 61
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 982
# Best match row index in human data: 75
# Best match score: 58.80000000000001
#   konsert_namn: 46
#   lokal_namn: 48
#   konsert_biljettpris: 100
#   konserttyp_namn: 52
#   Producer: 30
#
# Row index in LLM data: 983
# Best match row index in human data: 75
# Best match score: 60.599999999999994
#   konsert_namn: 26
#   lokal_namn: 81
#   konsert_biljettpris: 100
#   konserttyp_namn: 30
#   Producer: 24
#
# Row index in LLM data: 74
# Best match row index in human data: 77
# Best match score: 42.400000000000006
#   konsert_namn: 24
#   lokal_namn: 39
#   konsert_biljettpris: 100
#   konserttyp_namn: 36
#   Producer: 18
#
# Row index in LLM data: 76
# Best match row index in human data: 77
# Best match score: 26.8
#   konsert_namn: 29
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 32
#   Producer: 10
#
# Row index in LLM data: 77
# Best match row index in human data: 77
# Best match score: 27.200000000000003
#   konsert_namn: 25
#   lokal_namn: 34
#   konsert_biljettpris: 0
#   konserttyp_namn: 36
#   Producer: 0
#
# Row index in LLM data: 581
# Best match row index in human data: 77
# Best match score: 50.8
#   konsert_namn: 29
#   lokal_namn: 45
#   konsert_biljettpris: 100
#   konserttyp_namn: 38
#   Producer: 37
#
# Row index in LLM data: 661
# Best match row index in human data: 77
# Best match score: 36.400000000000006
#   konsert_namn: 18
#   lokal_namn: 40
#   konsert_biljettpris: 100
#   konserttyp_namn: 32
#   Producer: 0
#
# Row index in LLM data: 662
# Best match row index in human data: 77
# Best match score: 38.800000000000004
#   konsert_namn: 23
#   lokal_namn: 41
#   konsert_biljettpris: 100
#   konserttyp_namn: 32
#   Producer: 0
#
# Row index in LLM data: 663
# Best match row index in human data: 77
# Best match score: 10.0
#   konsert_namn: 0
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 38
# Best match row index in human data: 78
# Best match score: 31.800000000000004
#   konsert_namn: 53
#   lokal_namn: 9
#   konsert_biljettpris: 0
#   konserttyp_namn: 70
#   Producer: 0
#
# Row index in LLM data: 39
# Best match row index in human data: 78
# Best match score: 38.6
#   konsert_namn: 44
#   lokal_namn: 28
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 17
#
# Row index in LLM data: 72
# Best match row index in human data: 78
# Best match score: 53.0
#   konsert_namn: 55
#   lokal_namn: 10
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 96
#
# Row index in LLM data: 429
# Best match row index in human data: 78
# Best match score: 84.2
#   konsert_namn: 57
#   lokal_namn: 84
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 484
# Best match row index in human data: 78
# Best match score: 84.2
#   konsert_namn: 57
#   lokal_namn: 84
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 582
# Best match row index in human data: 78
# Best match score: 32.0
#   konsert_namn: 30
#   lokal_namn: 14
#   konsert_biljettpris: 0
#   konserttyp_namn: 70
#   Producer: 37
#
# Row index in LLM data: 664
# Best match row index in human data: 78
# Best match score: 41.0
#   konsert_namn: 17
#   lokal_namn: 32
#   konsert_biljettpris: 74
#   konserttyp_namn: 78
#   Producer: 31
#
# Row index in LLM data: 704
# Best match row index in human data: 78
# Best match score: 61.199999999999996
#   konsert_namn: 43
#   lokal_namn: 79
#   konsert_biljettpris: 0
#   konserttyp_namn: 48
#   Producer: 38
#
# Row index in LLM data: 905
# Best match row index in human data: 78
# Best match score: 82.0
#   konsert_namn: 100
#   lokal_namn: 79
#   konsert_biljettpris: 0
#   konserttyp_namn: 42
#   Producer: 31
#
# Row index in LLM data: 924
# Best match row index in human data: 78
# Best match score: 36.6
#   konsert_namn: 30
#   lokal_namn: 43
#   konsert_biljettpris: 0
#   konserttyp_namn: 12
#   Producer: 31
#
# Row index in LLM data: 45
# Best match row index in human data: 79
# Best match score: 72.4
#   konsert_namn: 49
#   lokal_namn: 79
#   konsert_biljettpris: 72
#   konserttyp_namn: 78
#   Producer: 31
#
# Row index in LLM data: 436
# Best match row index in human data: 79
# Best match score: 67.30000000000001
#   konsert_namn: 47
#   lokal_namn: 79
#   konsert_biljettpris: 91
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 491
# Best match row index in human data: 79
# Best match score: 67.30000000000001
#   konsert_namn: 47
#   lokal_namn: 79
#   konsert_biljettpris: 91
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 684
# Best match row index in human data: 79
# Best match score: 35.6
#   konsert_namn: 47
#   lokal_namn: 17
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 919
# Best match row index in human data: 79
# Best match score: 41.6
#   konsert_namn: 78
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 58
#   Producer: 23
#
# Row index in LLM data: 977
# Best match row index in human data: 79
# Best match score: 68.8
#   konsert_namn: 56
#   lokal_namn: 79
#   konsert_biljettpris: 70
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 1
# Best match row index in human data: 81
# Best match score: 39.199999999999996
#   konsert_namn: 13
#   lokal_namn: 44
#   konsert_biljettpris: 100
#   konserttyp_namn: 64
#   Producer: 0
#
# Row index in LLM data: 2
# Best match row index in human data: 81
# Best match score: 49.2
#   konsert_namn: 25
#   lokal_namn: 48
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 35
# Best match row index in human data: 80
# Best match score: 58.00000000000001
#   konsert_namn: 58
#   lokal_namn: 41
#   konsert_biljettpris: 89
#   konserttyp_namn: 55
#   Producer: 20
#
# Row index in LLM data: 510
# Best match row index in human data: 81
# Best match score: 43.800000000000004
#   konsert_namn: 13
#   lokal_namn: 48
#   konsert_biljettpris: 100
#   konserttyp_namn: 64
#   Producer: 15
#
# Row index in LLM data: 543
# Best match row index in human data: 80
# Best match score: 67.7
#   konsert_namn: 67
#   lokal_namn: 64
#   konsert_biljettpris: 35
#   konserttyp_namn: 78
#   Producer: 20
#
# Row index in LLM data: 557
# Best match row index in human data: 80
# Best match score: 60.400000000000006
#   konsert_namn: 87
#   lokal_namn: 64
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 558
# Best match row index in human data: 80
# Best match score: 69.7
#   konsert_namn: 87
#   lokal_namn: 64
#   konsert_biljettpris: 0
#   konserttyp_namn: 55
#   Producer: 19
#
# Row index in LLM data: 563
# Best match row index in human data: 80
# Best match score: 62.0
#   konsert_namn: 59
#   lokal_namn: 64
#   konsert_biljettpris: 50
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 591
# Best match row index in human data: 81
# Best match score: 41.2
#   konsert_namn: 11
#   lokal_namn: 92
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 592
# Best match row index in human data: 81
# Best match score: 57.60000000000001
#   konsert_namn: 19
#   lokal_namn: 92
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 16
#
# Row index in LLM data: 612
# Best match row index in human data: 80
# Best match score: 64.8
#   konsert_namn: 54
#   lokal_namn: 64
#   konsert_biljettpris: 50
#   konserttyp_namn: 78
#   Producer: 24
#
# Row index in LLM data: 686
# Best match row index in human data: 80
# Best match score: 48.5
#   konsert_namn: 44
#   lokal_namn: 32
#   konsert_biljettpris: 81
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 687
# Best match row index in human data: 81
# Best match score: 46.20000000000001
#   konsert_namn: 29
#   lokal_namn: 33
#   konsert_biljettpris: 100
#   konserttyp_namn: 48
#   Producer: 33
#
# Row index in LLM data: 703
# Best match row index in human data: 80
# Best match score: 45.7
#   konsert_namn: 26
#   lokal_namn: 41
#   konsert_biljettpris: 89
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 906
# Best match row index in human data: 80
# Best match score: 52.4
#   konsert_namn: 57
#   lokal_namn: 37
#   konsert_biljettpris: 100
#   konserttyp_namn: 18
#   Producer: 15
#
# Row index in LLM data: 920
# Best match row index in human data: 80
# Best match score: 40.3
#   konsert_namn: 51
#   lokal_namn: 0
#   konsert_biljettpris: 81
#   konserttyp_namn: 78
#   Producer: 20
#
# Row index in LLM data: 978
# Best match row index in human data: 80
# Best match score: 40.1
#   konsert_namn: 45
#   lokal_namn: 0
#   konsert_biljettpris: 81
#   konserttyp_namn: 100
#   Producer: 20
#
# Row index in LLM data: 0
# Best match row index in human data: 82
# Best match score: 91.1
#   konsert_namn: 56
#   lokal_namn: 79
#   konsert_biljettpris: 71
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 36
# Best match row index in human data: 82
# Best match score: 75.6
#   konsert_namn: 60
#   lokal_namn: 79
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 48
# Best match row index in human data: 83
# Best match score: 35.800000000000004
#   konsert_namn: 29
#   lokal_namn: 40
#   konsert_biljettpris: 0
#   konserttyp_namn: 48
#   Producer: 17
#
# Row index in LLM data: 60
# Best match row index in human data: 82
# Best match score: 48.5
#   konsert_namn: 30
#   lokal_namn: 0
#   konsert_biljettpris: 65
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 61
# Best match row index in human data: 82
# Best match score: 65.0
#   konsert_namn: 43
#   lokal_namn: 79
#   konsert_biljettpris: 100
#   konserttyp_namn: 62
#   Producer: 0
#
# Row index in LLM data: 70
# Best match row index in human data: 82
# Best match score: 49.2
#   konsert_namn: 34
#   lokal_namn: 64
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 75
# Best match row index in human data: 82
# Best match score: 72.0
#   konsert_namn: 56
#   lokal_namn: 79
#   konsert_biljettpris: 80
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 395
# Best match row index in human data: 83
# Best match score: 63.9
#   konsert_namn: 65
#   lokal_namn: 20
#   konsert_biljettpris: 38
#   konserttyp_namn: 61
#   Producer: 100
#
# Row index in LLM data: 412
# Best match row index in human data: 82
# Best match score: 82.80000000000001
#   konsert_namn: 28
#   lokal_namn: 79
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 413
# Best match row index in human data: 83
# Best match score: 65.9
#   konsert_namn: 65
#   lokal_namn: 24
#   konsert_biljettpris: 42
#   konserttyp_namn: 61
#   Producer: 100
#
# Row index in LLM data: 417
# Best match row index in human data: 82
# Best match score: 85.2
#   konsert_namn: 34
#   lokal_namn: 79
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 418
# Best match row index in human data: 82
# Best match score: 98.2
#   konsert_namn: 51
#   lokal_namn: 100
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 421
# Best match row index in human data: 82
# Best match score: 53.0
#   konsert_namn: 31
#   lokal_namn: 21
#   konsert_biljettpris: 100
#   konserttyp_namn: 22
#   Producer: 100
#
# Row index in LLM data: 450
# Best match row index in human data: 83
# Best match score: 63.9
#   konsert_namn: 65
#   lokal_namn: 20
#   konsert_biljettpris: 38
#   konserttyp_namn: 61
#   Producer: 100
#
# Row index in LLM data: 467
# Best match row index in human data: 82
# Best match score: 82.80000000000001
#   konsert_namn: 28
#   lokal_namn: 79
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 468
# Best match row index in human data: 83
# Best match score: 65.9
#   konsert_namn: 65
#   lokal_namn: 24
#   konsert_biljettpris: 42
#   konserttyp_namn: 61
#   Producer: 100
#
# Row index in LLM data: 472
# Best match row index in human data: 82
# Best match score: 85.2
#   konsert_namn: 34
#   lokal_namn: 79
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 473
# Best match row index in human data: 82
# Best match score: 98.2
#   konsert_namn: 51
#   lokal_namn: 100
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 476
# Best match row index in human data: 82
# Best match score: 53.0
#   konsert_namn: 31
#   lokal_namn: 21
#   konsert_biljettpris: 100
#   konserttyp_namn: 22
#   Producer: 100
#
# Row index in LLM data: 508
# Best match row index in human data: 82
# ...
#   konsert_namn: 39
#   lokal_namn: 21
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 50
#
# Row index in LLM data: 356
# Best match row index in human data: 450
# Best match score: 32.4
#   konsert_namn: 28
#   lokal_namn: 35
#   konsert_biljettpris: 29
#   konserttyp_namn: 43
#   Producer: 0
#
# Row index in LLM data: 1346
# Best match row index in human data: 450
# Best match score: 32.4
#   konsert_namn: 28
#   lokal_namn: 35
#   konsert_biljettpris: 29
#   konserttyp_namn: 43
#   Producer: 0
#
# Row index in LLM data: 353
# Best match row index in human data: 452
# Best match score: 52.0
#   konsert_namn: 55
#   lokal_namn: 17
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 16
#
# Row index in LLM data: 879
# Best match row index in human data: 452
# Best match score: 30.400000000000002
#   konsert_namn: 17
#   lokal_namn: 37
#   konsert_biljettpris: 0
#   konserttyp_namn: 88
#   Producer: 0
#
# Row index in LLM data: 882
# Best match row index in human data: 453
# Best match score: 69.0
#   konsert_namn: 48
#   lokal_namn: 81
#   konsert_biljettpris: 100
#   konserttyp_namn: 74
#   Producer: 0
#
# Row index in LLM data: 1343
# Best match row index in human data: 452
# Best match score: 52.0
#   konsert_namn: 55
#   lokal_namn: 17
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 16
#
# Row index in LLM data: 336
# Best match row index in human data: 455
# Best match score: 50.10000000000001
#   konsert_namn: 49
#   lokal_namn: 32
#   konsert_biljettpris: 70
#   konserttyp_namn: 67
#   Producer: 20
#
# Row index in LLM data: 352
# Best match row index in human data: 455
# Best match score: 24.0
#   konsert_namn: 47
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 26
#
# Row index in LLM data: 856
# Best match row index in human data: 455
# Best match score: 62.2
#   konsert_namn: 45
#   lokal_namn: 79
#   konsert_biljettpris: 74
#   konserttyp_namn: 22
#   Producer: 15
#
# Row index in LLM data: 1326
# Best match row index in human data: 455
# Best match score: 50.10000000000001
#   konsert_namn: 49
#   lokal_namn: 32
#   konsert_biljettpris: 70
#   konserttyp_namn: 67
#   Producer: 20
#
# Row index in LLM data: 1342
# Best match row index in human data: 455
# Best match score: 24.0
#   konsert_namn: 47
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 26
#
# Row index in LLM data: 317
# Best match row index in human data: 459
# Best match score: 78.3
#   konsert_namn: 60
#   lokal_namn: 94
#   konsert_biljettpris: 100
#   konserttyp_namn: 67
#   Producer: 0
#
# Row index in LLM data: 323
# Best match row index in human data: 459
# Best match score: 59.2
#   konsert_namn: 75
#   lokal_namn: 43
#   konsert_biljettpris: 50
#   konserttyp_namn: 70
#   Producer: 0
#
# Row index in LLM data: 324
# Best match row index in human data: 458
# Best match score: 69.9
#   konsert_namn: 43
#   lokal_namn: 100
#   konsert_biljettpris: 60
#   konserttyp_namn: 67
#   Producer: 0
#
# Row index in LLM data: 325
# Best match row index in human data: 459
# Best match score: 90.3
#   konsert_namn: 56
#   lokal_namn: 94
#   konsert_biljettpris: 46
#   konserttyp_namn: 67
#   Producer: 95
#
# Row index in LLM data: 327
# Best match row index in human data: 460
# Best match score: 39.2
#   konsert_namn: 37
#   lokal_namn: 25
#   konsert_biljettpris: 22
#   konserttyp_namn: 64
#   Producer: 29
#
# Row index in LLM data: 328
# Best match row index in human data: 457
# Best match score: 46.400000000000006
#   konsert_namn: 33
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 62
#   Producer: 21
#
# Row index in LLM data: 1307
# Best match row index in human data: 459
# Best match score: 78.3
#   konsert_namn: 60
#   lokal_namn: 94
#   konsert_biljettpris: 100
#   konserttyp_namn: 67
#   Producer: 0
#
# Row index in LLM data: 1313
# Best match row index in human data: 459
# Best match score: 59.2
#   konsert_namn: 75
#   lokal_namn: 43
#   konsert_biljettpris: 50
#   konserttyp_namn: 70
#   Producer: 0
#
# Row index in LLM data: 1314
# Best match row index in human data: 458
# Best match score: 69.9
#   konsert_namn: 43
#   lokal_namn: 100
#   konsert_biljettpris: 60
#   konserttyp_namn: 67
#   Producer: 0
#
# Row index in LLM data: 1315
# Best match row index in human data: 459
# Best match score: 90.3
#   konsert_namn: 56
#   lokal_namn: 94
#   konsert_biljettpris: 46
#   konserttyp_namn: 67
#   Producer: 95
#
# Row index in LLM data: 1317
# Best match row index in human data: 460
# Best match score: 39.2
#   konsert_namn: 37
#   lokal_namn: 25
#   konsert_biljettpris: 22
#   konserttyp_namn: 64
#   Producer: 29
#
# Row index in LLM data: 1318
# Best match row index in human data: 457
# Best match score: 46.400000000000006
#   konsert_namn: 33
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 62
#   Producer: 21
#
# Row index in LLM data: 315
# Best match row index in human data: 462
# Best match score: 55.0
#   konsert_namn: 44
#   lokal_namn: 39
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 20
#
# Row index in LLM data: 876
# Best match row index in human data: 462
# Best match score: 56.0
#   konsert_namn: 26
#   lokal_namn: 64
#   konsert_biljettpris: 84
#   konserttyp_namn: 78
#   Producer: 19
#
# Row index in LLM data: 1305
# Best match row index in human data: 462
# Best match score: 55.0
#   konsert_namn: 44
#   lokal_namn: 39
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 20
#
# Row index in LLM data: 316
# Best match row index in human data: 467
# Best match score: 41.300000000000004
#   konsert_namn: 30
#   lokal_namn: 48
#   konsert_biljettpris: 49
#   konserttyp_namn: 52
#   Producer: 0
#
# Row index in LLM data: 326
# Best match row index in human data: 467
# Best match score: 50.3
#   konsert_namn: 50
#   lokal_namn: 48
#   konsert_biljettpris: 23
#   konserttyp_namn: 88
#   Producer: 0
#
# Row index in LLM data: 1306
# Best match row index in human data: 467
# Best match score: 41.300000000000004
#   konsert_namn: 30
#   lokal_namn: 48
#   konsert_biljettpris: 49
#   konserttyp_namn: 52
#   Producer: 0
#
# Row index in LLM data: 1316
# Best match row index in human data: 467
# Best match score: 50.3
#   konsert_namn: 50
#   lokal_namn: 48
#   konsert_biljettpris: 23
#   konserttyp_namn: 88
#   Producer: 0
#
# Row index in LLM data: 385
# Best match row index in human data: 470
# Best match score: 51.60000000000001
#   konsert_namn: 56
#   lokal_namn: 25
#   konsert_biljettpris: 100
#   konserttyp_namn: 56
#   Producer: 18
#
# Row index in LLM data: 386
# Best match row index in human data: 471
# Best match score: 62.800000000000004
#   konsert_namn: 44
#   lokal_namn: 24
#   konsert_biljettpris: 100
#   konserttyp_namn: 56
#   Producer: 100
#
# Row index in LLM data: 387
# Best match row index in human data: 470
# Best match score: 48.60000000000001
#   konsert_namn: 41
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 54
#   Producer: 24
#
# Row index in LLM data: 388
# Best match row index in human data: 471
# Best match score: 44.60000000000001
#   konsert_namn: 39
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 62
#   Producer: 0
#
# Row index in LLM data: 389
# Best match row index in human data: 471
# Best match score: 67.60000000000001
#   konsert_namn: 51
#   lokal_namn: 83
#   konsert_biljettpris: 100
#   konserttyp_namn: 40
#   Producer: 0
#
# Row index in LLM data: 1375
# Best match row index in human data: 470
# Best match score: 51.60000000000001
#   konsert_namn: 56
#   lokal_namn: 25
#   konsert_biljettpris: 100
#   konserttyp_namn: 56
#   Producer: 18
#
# Row index in LLM data: 1376
# Best match row index in human data: 471
# Best match score: 62.800000000000004
#   konsert_namn: 44
#   lokal_namn: 24
#   konsert_biljettpris: 100
#   konserttyp_namn: 56
#   Producer: 100
#
# Row index in LLM data: 1377
# Best match row index in human data: 470
# Best match score: 48.60000000000001
#   konsert_namn: 41
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 54
#   Producer: 24
#
# Row index in LLM data: 1378
# Best match row index in human data: 471
# Best match score: 44.60000000000001
#   konsert_namn: 39
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 62
#   Producer: 0
#
# Row index in LLM data: 1379
# Best match row index in human data: 471
# Best match score: 67.60000000000001
#   konsert_namn: 51
#   lokal_namn: 83
#   konsert_biljettpris: 100
#   konserttyp_namn: 40
#   Producer: 0
#
# Row index in LLM data: 372
# Best match row index in human data: 475
# Best match score: 49.3
#   konsert_namn: 27
#   lokal_namn: 52
#   konsert_biljettpris: 89
#   konserttyp_namn: 64
#   Producer: 12
#
# Row index in LLM data: 374
# Best match row index in human data: 477
# Best match score: 34.599999999999994
#   konsert_namn: 31
#   lokal_namn: 25
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 29
#
# Row index in LLM data: 375
# Best match row index in human data: 477
# Best match score: 50.800000000000004
#   konsert_namn: 49
#   lokal_namn: 39
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 46
#
# Row index in LLM data: 376
# Best match row index in human data: 477
# Best match score: 47.6
#   konsert_namn: 50
#   lokal_namn: 27
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 52
#
# Row index in LLM data: 377
# Best match row index in human data: 475
# Best match score: 26.700000000000003
#   konsert_namn: 15
#   lokal_namn: 19
#   konsert_biljettpris: 67
#   konserttyp_namn: 28
#   Producer: 18
#
# Row index in LLM data: 390
# Best match row index in human data: 475
# Best match score: 36.6
#   konsert_namn: 74
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 70
#   Producer: 0
#
# Row index in LLM data: 1362
# Best match row index in human data: 475
# Best match score: 49.3
#   konsert_namn: 27
#   lokal_namn: 52
#   konsert_biljettpris: 89
#   konserttyp_namn: 64
#   Producer: 12
#
# Row index in LLM data: 1364
# Best match row index in human data: 477
# Best match score: 34.599999999999994
#   konsert_namn: 31
#   lokal_namn: 25
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 29
#
# Row index in LLM data: 1365
# Best match row index in human data: 477
# Best match score: 50.800000000000004
#   konsert_namn: 49
#   lokal_namn: 39
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 46
#
# Row index in LLM data: 1366
# Best match row index in human data: 477
# Best match score: 47.6
#   konsert_namn: 50
#   lokal_namn: 27
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 52
#
# Row index in LLM data: 1367
# Best match row index in human data: 475
# Best match score: 26.700000000000003
#   konsert_namn: 15
#   lokal_namn: 19
#   konsert_biljettpris: 67
#   konserttyp_namn: 28
#   Producer: 18
#
# Row index in LLM data: 1380
# Best match row index in human data: 475
# Best match score: 36.6
#   konsert_namn: 74
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 70
#   Producer: 0
#
# Row index in LLM data: 383
# Best match row index in human data: 478
# Best match score: 74.8
#   konsert_namn: 21
#   lokal_namn: 91
#   konsert_biljettpris: 100
#   konserttyp_namn: 64
#   Producer: 68
#
# Row index in LLM data: 1373
# Best match row index in human data: 478
# Best match score: 74.8
#   konsert_namn: 21
#   lokal_namn: 91
#   konsert_biljettpris: 100
#   konserttyp_namn: 64
#   Producer: 68
#
# Row index in LLM data: 373
# Best match row index in human data: 483
# Best match score: 54.400000000000006
#   konsert_namn: 34
#   lokal_namn: 33
#   konsert_biljettpris: 0
#   konserttyp_namn: 76
#   Producer: 100
#
# Row index in LLM data: 384
# Best match row index in human data: 483
# Best match score: 55.2
#   konsert_namn: 34
#   lokal_namn: 29
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 1363
# Best match row index in human data: 483
# Best match score: 54.400000000000006
#   konsert_namn: 34
#   lokal_namn: 33
#   konsert_biljettpris: 0
#   konserttyp_namn: 76
#   Producer: 100
#
# Row index in LLM data: 1374
# Best match row index in human data: 483
# Best match score: 55.2
#   konsert_namn: 34
#   lokal_namn: 29
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 367
# Best match row index in human data: 505
# Best match score: 18.7
#   konsert_namn: 25
#   lokal_namn: 17
#   konsert_biljettpris: 0
#   konserttyp_namn: 19
#   Producer: 0
#
# Row index in LLM data: 368
# Best match row index in human data: 505
# Best match score: 18.0
#   konsert_namn: 17
#   lokal_namn: 25
#   konsert_biljettpris: 0
#   konserttyp_namn: 12
#   Producer: 0
#
# Row index in LLM data: 369
# Best match row index in human data: 505
# Best match score: 21.3
#   konsert_namn: 21
#   lokal_namn: 26
#   konsert_biljettpris: 0
#   konserttyp_namn: 25
#   Producer: 0
#
# Row index in LLM data: 370
# Best match row index in human data: 505
# Best match score: 17.8
#   konsert_namn: 25
#   lokal_namn: 14
#   konsert_biljettpris: 0
#   konserttyp_namn: 22
#   Producer: 0
#
# Row index in LLM data: 371
# Best match row index in human data: 505
# Best match score: 39.8
#   konsert_namn: 26
#   lokal_namn: 18
#   konsert_biljettpris: 0
#   konserttyp_namn: 22
#   Producer: 100
#
# Row index in LLM data: 1357
# Best match row index in human data: 505
# Best match score: 18.7
#   konsert_namn: 25
#   lokal_namn: 17
#   konsert_biljettpris: 0
#   konserttyp_namn: 19
#   Producer: 0
#
# Row index in LLM data: 1358
# Best match row index in human data: 505
# Best match score: 18.0
#   konsert_namn: 17
#   lokal_namn: 25
#   konsert_biljettpris: 0
#   konserttyp_namn: 12
#   Producer: 0
#
# Row index in LLM data: 1359
# Best match row index in human data: 505
# Best match score: 21.3
#   konsert_namn: 21
#   lokal_namn: 26
#   konsert_biljettpris: 0
#   konserttyp_namn: 25
#   Producer: 0
#
# Row index in LLM data: 1360
# Best match row index in human data: 505
# Best match score: 17.8
#   konsert_namn: 25
#   lokal_namn: 14
#   konsert_biljettpris: 0
#   konserttyp_namn: 22
#   Producer: 0
#
# Row index in LLM data: 1361
# Best match row index in human data: 505
# Best match score: 39.8
#   konsert_namn: 26
#   lokal_namn: 18
#   konsert_biljettpris: 0
#   konserttyp_namn: 22
#   Producer: 100
#
# Row index in LLM data: 835
# Best match row index in human data: 506
# Best match score: 46.8
#   konsert_namn: 43
#   lokal_namn: 24
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 836
# Best match row index in human data: 506
# Best match score: 46.800000000000004
#   konsert_namn: 45
#   lokal_namn: 29
#   konsert_biljettpris: 100
#   konserttyp_namn: 22
#   Producer: 25
#
# Row index in LLM data: 850
# Best match row index in human data: 508
# Best match score: 33.4
#   konsert_namn: 20
#   lokal_namn: 25
#   konsert_biljettpris: 85
#   konserttyp_namn: 69
#   Producer: 0
#
# Row index in LLM data: 849
# Best match row index in human data: 511
# Best match score: 27.500000000000004
#   konsert_namn: 12
#   lokal_namn: 32
#   konsert_biljettpris: 0
#   konserttyp_namn: 33
#   Producer: 33
#
# Row index in LLM data: 828
# Best match row index in human data: 513
# Best match score: 27.000000000000004
#   konsert_namn: 33
#   lokal_namn: 29
#   konsert_biljettpris: 0
#   konserttyp_namn: 22
#   Producer: 0
#
# Row index in LLM data: 829
# Best match row index in human data: 513
# Best match score: 23.2
#   konsert_namn: 25
#   lokal_namn: 31
#   konsert_biljettpris: 0
#   konserttyp_namn: 8
#   Producer: 0
#
# Row index in LLM data: 832
# Best match row index in human data: 512
# Best match score: 79.6
#   konsert_namn: 24
#   lokal_namn: 100
#   konsert_biljettpris: 100
#   konserttyp_namn: 0
#   Producer: 100
#
#    json_row_index  xls_row_index  overall_match_score  konsert_namn  \
# 0             666              0                 31.6            23
# 1             668              0                 37.2            38
# 2             671              0                 52.7            30
# 3             433              1                 75.3            53
# 4             434              1                 88.3            66
#
#    lokal_namn  konsert_biljettpris  konserttyp_namn  Producer
# 0          17                  100               56         0
# 1          17                  100               52         0
# 2          79                    0               55        18
# 3         100                   55               22        32
# 4         100                   55              100        32
# Best Match Details:
#      json_row_index  xls_row_index  overall_match_score  konsert_namn  \
# 136             432             59                116.4           100
# 138             487             59                116.4           100
#
#      lokal_namn  konsert_biljettpris  konserttyp_namn  Producer
# 136         100                   64              100       100
# 138         100                   64              100       100

# %%
# Extract JSON matching info from the report and turn it into a table

# Create a DataFrame to store detailed matching information
detailed_matching_info = []

# Correct variable names and keys in printing and CSV output
for result in all_comparison_results:
    print(f"Row index in LLM data: {result['json_row_index']}")
    print(f"Best match row index in human data: {result['xls_row_index']}")
    print(f"Best match score: {result['overall_match_score']}")
    for col, score in result.items():
        if col in ['json_row_index', 'xls_row_index', 'overall_match_score', 'original_date']:
            continue
        print(f"  {col}: {score}")
    print()

# Convert the list to a DataFrame
detailed_matching_df = pd.DataFrame(detailed_matching_info)

# Display the first few rows of the detailed matching DataFrame
print(detailed_matching_df.head())

# Optionally, save the detailed matching info to a CSV file for further analysis
detailed_matching_file_name = f'detailed_matching_info_{report_date}.csv'
detailed_matching_df.to_csv(detailed_matching_file_name, index=False)

# Display the table in the notebook
detailed_matching_df
# Out:
# Row index in LLM data: 666
# Best match row index in human data: 0
# Best match score: 31.6
#   konsert_namn: 23
#   lokal_namn: 17
#   konsert_biljettpris: 100
#   konserttyp_namn: 56
#   Producer: 0
#
# Row index in LLM data: 668
# Best match row index in human data: 0
# Best match score: 37.2
#   konsert_namn: 38
#   lokal_namn: 17
#   konsert_biljettpris: 100
#   konserttyp_namn: 52
#   Producer: 0
#
# Row index in LLM data: 671
# Best match row index in human data: 0
# Best match score: 52.7
#   konsert_namn: 30
#   lokal_namn: 79
#   konsert_biljettpris: 0
#   konserttyp_namn: 55
#   Producer: 18
#
# Row index in LLM data: 433
# Best match row index in human data: 1
# Best match score: 75.30000000000001
#   konsert_namn: 53
#   lokal_namn: 100
#   konsert_biljettpris: 55
#   konserttyp_namn: 22
#   Producer: 32
#
# Row index in LLM data: 434
# Best match row index in human data: 1
# Best match score: 88.30000000000001
#   konsert_namn: 66
#   lokal_namn: 100
#   konsert_biljettpris: 55
#   konserttyp_namn: 100
#   Producer: 32
#
# Row index in LLM data: 488
# Best match row index in human data: 1
# Best match score: 75.30000000000001
#   konsert_namn: 53
#   lokal_namn: 100
#   konsert_biljettpris: 55
#   konserttyp_namn: 22
#   Producer: 32
#
# Row index in LLM data: 489
# Best match row index in human data: 1
# Best match score: 88.30000000000001
#   konsert_namn: 66
#   lokal_namn: 100
#   konsert_biljettpris: 55
#   konserttyp_namn: 100
#   Producer: 32
#
# Row index in LLM data: 667
# Best match row index in human data: 1
# Best match score: 96.30000000000001
#   konsert_namn: 61
#   lokal_namn: 98
#   konsert_biljettpris: 53
#   konserttyp_namn: 74
#   Producer: 100
#
# Row index in LLM data: 1022
# Best match row index in human data: 1
# Best match score: 47.0
#   konsert_namn: 33
#   lokal_namn: 24
#   konsert_biljettpris: 0
#   konserttyp_namn: 42
#   Producer: 100
#
# Row index in LLM data: 1023
# Best match row index in human data: 1
# Best match score: 66.2
#   konsert_namn: 53
#   lokal_namn: 79
#   konsert_biljettpris: 0
#   konserttyp_namn: 70
#   Producer: 32
#
# Row index in LLM data: 1024
# Best match row index in human data: 4
# Best match score: 70.39999999999999
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 0
#   konserttyp_namn: 48
#   Producer: 24
#
# Row index in LLM data: 1027
# Best match row index in human data: 3
# Best match score: 66.30000000000001
#   konsert_namn: 54
#   lokal_namn: 20
#   konsert_biljettpris: 100
#   konserttyp_namn: 67
#   Producer: 100
#
# Row index in LLM data: 1025
# Best match row index in human data: 8
# Best match score: 82.3
#   konsert_namn: 100
#   lokal_namn: 59
#   konsert_biljettpris: 81
#   konserttyp_namn: 48
#   Producer: 29
#
# Row index in LLM data: 87
# Best match row index in human data: 9
# Best match score: 68.6
#   konsert_namn: 49
#   lokal_namn: 90
#   konsert_biljettpris: 33
#   konserttyp_namn: 97
#   Producer: 0
#
# Row index in LLM data: 435
# Best match row index in human data: 9
# Best match score: 86.9
#   konsert_namn: 49
#   lokal_namn: 100
#   konsert_biljettpris: 39
#   konserttyp_namn: 100
#   Producer: 67
#
# Row index in LLM data: 490
# Best match row index in human data: 9
# Best match score: 86.9
#   konsert_namn: 49
#   lokal_namn: 100
#   konsert_biljettpris: 39
#   konserttyp_namn: 100
#   Producer: 67
#
# Row index in LLM data: 1026
# Best match row index in human data: 9
# Best match score: 75.5
#   konsert_namn: 35
#   lokal_namn: 85
#   konsert_biljettpris: 44
#   konserttyp_namn: 97
#   Producer: 67
#
# Row index in LLM data: 1011
# Best match row index in human data: 11
# Best match score: 35.400000000000006
#   konsert_namn: 23
#   lokal_namn: 46
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 657
# Best match row index in human data: 12
# Best match score: 43.2
#   konsert_namn: 69
#   lokal_namn: 29
#   konsert_biljettpris: 0
#   konserttyp_namn: 40
#   Producer: 0
#
# Row index in LLM data: 658
# Best match row index in human data: 12
# Best match score: 40.2
#   konsert_namn: 61
#   lokal_namn: 22
#   konsert_biljettpris: 0
#   konserttyp_namn: 70
#   Producer: 0
#
# Row index in LLM data: 659
# Best match row index in human data: 12
# Best match score: 37.2
#   konsert_namn: 37
#   lokal_namn: 25
#   konsert_biljettpris: 0
#   konserttyp_namn: 56
#   Producer: 34
#
# Row index in LLM data: 961
# Best match row index in human data: 12
# Best match score: 94.2
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 963
# Best match row index in human data: 12
# Best match score: 46.2
#   konsert_namn: 71
#   lokal_namn: 25
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 964
# Best match row index in human data: 12
# Best match score: 45.7
#   konsert_namn: 60
#   lokal_namn: 39
#   konsert_biljettpris: 0
#   konserttyp_namn: 61
#   Producer: 0
#
# Row index in LLM data: 965
# Best match row index in human data: 12
# Best match score: 38.2
#   konsert_namn: 55
#   lokal_namn: 30
#   konsert_biljettpris: 0
#   konserttyp_namn: 42
#   Producer: 0
#
# Row index in LLM data: 656
# Best match row index in human data: 13
# Best match score: 63.2
#   konsert_namn: 100
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 16
#
# Row index in LLM data: 26
# Best match row index in human data: 16
# Best match score: 35.2
#   konsert_namn: 49
#   lokal_namn: 39
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 27
# Best match row index in human data: 16
# Best match score: 37.0
#   konsert_namn: 43
#   lokal_namn: 19
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 29
#
# Row index in LLM data: 28
# Best match row index in human data: 17
# Best match score: 40.6
#   konsert_namn: 43
#   lokal_namn: 27
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 13
#
# Row index in LLM data: 415
# Best match row index in human data: 16
# Best match score: 50.80000000000001
#   konsert_namn: 42
#   lokal_namn: 29
#   konsert_biljettpris: 100
#   konserttyp_namn: 52
#   Producer: 36
#
# Row index in LLM data: 416
# Best match row index in human data: 16
# Best match score: 48.60000000000001
#   konsert_namn: 52
#   lokal_namn: 39
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 29
#
# Row index in LLM data: 470
# Best match row index in human data: 16
# Best match score: 50.80000000000001
#   konsert_namn: 42
#   lokal_namn: 29
#   konsert_biljettpris: 100
#   konserttyp_namn: 52
#   Producer: 36
#
# Row index in LLM data: 471
# Best match row index in human data: 16
# Best match score: 48.60000000000001
#   konsert_namn: 52
#   lokal_namn: 39
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 29
#
# Row index in LLM data: 941
# Best match row index in human data: 16
# Best match score: 90.00000000000001
#   konsert_namn: 82
#   lokal_namn: 85
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 27
#
# Row index in LLM data: 942
# Best match row index in human data: 16
# Best match score: 17.400000000000002
#   konsert_namn: 24
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 946
# Best match row index in human data: 16
# Best match score: 38.50000000000001
#   konsert_namn: 41
#   lokal_namn: 26
#   konsert_biljettpris: 65
#   konserttyp_namn: 52
#   Producer: 0
#
# Row index in LLM data: 947
# Best match row index in human data: 16
# Best match score: 32.6
#   konsert_namn: 35
#   lokal_namn: 17
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 27
#
# Row index in LLM data: 962
# Best match row index in human data: 16
# Best match score: 62.800000000000004
#   konsert_namn: 36
#   lokal_namn: 60
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 33
#
# Row index in LLM data: 1012
# Best match row index in human data: 16
# Best match score: 51.1
#   konsert_namn: 40
#   lokal_namn: 60
#   konsert_biljettpris: 100
#   konserttyp_namn: 11
#   Producer: 0
#
# Row index in LLM data: 40
# Best match row index in human data: 18
# Best match score: 36.00000000000001
#   konsert_namn: 26
#   lokal_namn: 22
#   konsert_biljettpris: 26
#   konserttyp_namn: 76
#   Producer: 33
#
# Row index in LLM data: 44
# Best match row index in human data: 18
# Best match score: 27.8
#   konsert_namn: 14
#   lokal_namn: 36
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 414
# Best match row index in human data: 18
# Best match score: 57.199999999999996
#   konsert_namn: 35
#   lokal_namn: 67
#   konsert_biljettpris: 18
#   konserttyp_namn: 80
#   Producer: 33
#
# Row index in LLM data: 469
# Best match row index in human data: 18
# Best match score: 57.199999999999996
#   konsert_namn: 35
#   lokal_namn: 67
#   konsert_biljettpris: 18
#   konserttyp_namn: 80
#   Producer: 33
#
# Row index in LLM data: 4
# Best match row index in human data: 19
# Best match score: 61.800000000000004
#   konsert_namn: 33
#   lokal_namn: 60
#   konsert_biljettpris: 100
#   konserttyp_namn: 22
#   Producer: 62
#
# Row index in LLM data: 7
# Best match row index in human data: 19
# Best match score: 38.8
#   konsert_namn: 35
#   lokal_namn: 29
#   konsert_biljettpris: 0
#   konserttyp_namn: 74
#   Producer: 29
#
# Row index in LLM data: 23
# Best match row index in human data: 20
# Best match score: 49.699999999999996
#   konsert_namn: 62
#   lokal_namn: 20
#   konsert_biljettpris: 43
#   konserttyp_namn: 72
#   Producer: 27
#
# Row index in LLM data: 41
# Best match row index in human data: 19
# Best match score: 72.39999999999999
#   konsert_namn: 42
#   lokal_namn: 100
#   konsert_biljettpris: 100
#   konserttyp_namn: 56
#   Producer: 0
#
# Row index in LLM data: 402
# Best match row index in human data: 19
# Best match score: 56.1
#   konsert_namn: 11
#   lokal_namn: 100
#   konsert_biljettpris: 71
#   konserttyp_namn: 46
#   Producer: 0
#
# Row index in LLM data: 457
# Best match row index in human data: 19
# Best match score: 56.1
#   konsert_namn: 11
#   lokal_namn: 100
#   konsert_biljettpris: 71
#   konserttyp_namn: 46
#   Producer: 0
#
# Row index in LLM data: 660
# Best match row index in human data: 19
# Best match score: 76.00000000000001
#   konsert_namn: 48
#   lokal_namn: 100
#   konsert_biljettpris: 94
#   konserttyp_namn: 24
#   Producer: 25
#
# Row index in LLM data: 998
# Best match row index in human data: 19
# Best match score: 41.0
#   konsert_namn: 27
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 74
#   Producer: 0
#
# Row index in LLM data: 1003
# Best match row index in human data: 19
# Best match score: 40.0
#   konsert_namn: 33
#   lokal_namn: 25
#   konsert_biljettpris: 10
#   konserttyp_namn: 100
#   Producer: 29
#
# Row index in LLM data: 3
# Best match row index in human data: 21
# Best match score: 89.4
#   konsert_namn: 99
#   lokal_namn: 54
#   konsert_biljettpris: 100
#   konserttyp_namn: 58
#   Producer: 62
#
# Row index in LLM data: 43
# Best match row index in human data: 21
# Best match score: 85.60000000000001
#   konsert_namn: 95
#   lokal_namn: 71
#   konsert_biljettpris: 100
#   konserttyp_namn: 58
#   Producer: 17
#
# Row index in LLM data: 401
# Best match row index in human data: 21
# Best match score: 60.400000000000006
#   konsert_namn: 87
#   lokal_namn: 32
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 14
#
# Row index in LLM data: 456
# Best match row index in human data: 21
# Best match score: 60.400000000000006
#   konsert_namn: 87
#   lokal_namn: 32
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 14
#
# Row index in LLM data: 641
# Best match row index in human data: 21
# Best match score: 90.4
#   konsert_namn: 99
#   lokal_namn: 71
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 62
#
# Row index in LLM data: 652
# Best match row index in human data: 23
# Best match score: 75.4
#   konsert_namn: 30
#   lokal_namn: 88
#   konsert_biljettpris: 0
#   konserttyp_namn: 82
#   Producer: 100
#
# Row index in LLM data: 952
# Best match row index in human data: 23
# Best match score: 97.00000000000001
#   konsert_namn: 71
#   lokal_namn: 100
#   konsert_biljettpris: 44
#   konserttyp_namn: 42
#   Producer: 100
#
# Row index in LLM data: 959
# Best match row index in human data: 22
# Best match score: 53.599999999999994
#   konsert_namn: 81
#   lokal_namn: 16
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 24
#
# Row index in LLM data: 968
# Best match row index in human data: 22
# Best match score: 50.5
#   konsert_namn: 64
#   lokal_namn: 26
#   konsert_biljettpris: 25
#   konserttyp_namn: 56
#   Producer: 32
#
# Row index in LLM data: 5
# Best match row index in human data: 28
# Best match score: 75.60000000000001
#   konsert_namn: 42
#   lokal_namn: 89
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 16
#
# Row index in LLM data: 25
# Best match row index in human data: 28
# Best match score: 73.4
#   konsert_namn: 40
#   lokal_namn: 89
#   konsert_biljettpris: 100
#   konserttyp_namn: 86
#   Producer: 16
#
# Row index in LLM data: 78
# Best match row index in human data: 28
# Best match score: 71.0
#   konsert_namn: 42
#   lokal_namn: 89
#   konsert_biljettpris: 86
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 404
# Best match row index in human data: 28
# Best match score: 64.0
#   konsert_namn: 46
#   lokal_namn: 89
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 439
# Best match row index in human data: 28
# Best match score: 62.8
#   konsert_namn: 43
#   lokal_namn: 89
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 459
# Best match row index in human data: 28
# Best match score: 64.0
#   konsert_namn: 46
#   lokal_namn: 89
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 494
# Best match row index in human data: 28
# Best match score: 62.8
#   konsert_namn: 43
#   lokal_namn: 89
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 943
# Best match row index in human data: 28
# Best match score: 77.60000000000001
#   konsert_namn: 42
#   lokal_namn: 89
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 26
#
# Row index in LLM data: 948
# Best match row index in human data: 28
# Best match score: 42.7
#   konsert_namn: 45
#   lokal_namn: 48
#   konsert_biljettpris: 0
#   konserttyp_namn: 55
#   Producer: 0
#
# Row index in LLM data: 949
# Best match row index in human data: 28
# Best match score: 47.00000000000001
#   konsert_namn: 41
#   lokal_namn: 55
#   konsert_biljettpris: 0
#   konserttyp_namn: 56
#   Producer: 15
#
# Row index in LLM data: 950
# Best match row index in human data: 25
# Best match score: 82.4
#   konsert_namn: 65
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 951
# Best match row index in human data: 28
# Best match score: 78.0
#   konsert_namn: 51
#   lokal_namn: 94
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 955
# Best match row index in human data: 27
# Best match score: 70.6
#   konsert_namn: 39
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 36
#   Producer: 25
#
# Row index in LLM data: 960
# Best match row index in human data: 24
# Best match score: 81.19999999999999
#   konsert_namn: 100
#   lokal_namn: 44
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 18
#
# Row index in LLM data: 966
# Best match row index in human data: 27
# Best match score: 70.6
#   konsert_namn: 39
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 36
#   Producer: 25
#
# Row index in LLM data: 1002
# Best match row index in human data: 27
# Best match score: 67.0
#   konsert_namn: 44
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 30
#   Producer: 0
#
# Row index in LLM data: 1013
# Best match row index in human data: 27
# Best match score: 90.4
#   konsert_namn: 81
#   lokal_namn: 100
#   konsert_biljettpris: 0
#   konserttyp_namn: 30
#   Producer: 75
#
# Row index in LLM data: 24
# Best match row index in human data: 29
# Best match score: 65.6
#   konsert_namn: 60
#   lokal_namn: 60
#   konsert_biljettpris: 76
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 79
# Best match row index in human data: 29
# Best match score: 87.9
#   konsert_namn: 87
#   lokal_namn: 60
#   konsert_biljettpris: 76
#   konserttyp_namn: 53
#   Producer: 81
#
# Row index in LLM data: 953
# Best match row index in human data: 29
# Best match score: 57.2
#   konsert_namn: 42
#   lokal_namn: 57
#   konsert_biljettpris: 76
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 1000
# Best match row index in human data: 29
# Best match score: 61.6
#   konsert_namn: 42
#   lokal_namn: 52
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 20
#
# Row index in LLM data: 669
# Best match row index in human data: 33
# Best match score: 41.2
#   konsert_namn: 19
#   lokal_namn: 62
#   konsert_biljettpris: 0
#   konserttyp_namn: 88
#   Producer: 0
#
# Row index in LLM data: 670
# Best match row index in human data: 32
# Best match score: 26.6
#   konsert_namn: 32
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 62
#   Producer: 38
#
# Row index in LLM data: 673
# Best match row index in human data: 32
# Best match score: 31.800000000000004
#   konsert_namn: 30
#   lokal_namn: 24
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 12
#
# Row index in LLM data: 53
# Best match row index in human data: 34
# Best match score: 38.800000000000004
#   konsert_namn: 21
#   lokal_namn: 27
#   konsert_biljettpris: 100
#   konserttyp_namn: 18
#   Producer: 39
#
# Row index in LLM data: 975
# Best match row index in human data: 34
# Best match score: 30.8
#   konsert_namn: 22
#   lokal_namn: 25
#   konsert_biljettpris: 100
#   konserttyp_namn: 20
#   Producer: 0
#
# Row index in LLM data: 51
# Best match row index in human data: 39
# Best match score: 49.400000000000006
#   konsert_namn: 42
#   lokal_namn: 47
#   konsert_biljettpris: 83
#   konserttyp_namn: 55
#   Producer: 0
#
# Row index in LLM data: 642
# Best match row index in human data: 39
# Best match score: 45.6
#   konsert_namn: 40
#   lokal_namn: 47
#   konsert_biljettpris: 0
#   konserttyp_namn: 56
#   Producer: 26
#
# Row index in LLM data: 643
# Best match row index in human data: 39
# Best match score: 30.7
#   konsert_namn: 26
#   lokal_namn: 23
#   konsert_biljettpris: 0
#   konserttyp_namn: 69
#   Producer: 21
#
# Row index in LLM data: 644
# Best match row index in human data: 39
# Best match score: 50.2
#   konsert_namn: 44
#   lokal_namn: 62
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 647
# Best match row index in human data: 39
# Best match score: 42.300000000000004
#   konsert_namn: 47
#   lokal_namn: 25
#   konsert_biljettpris: 0
#   konserttyp_namn: 69
#   Producer: 33
#
# Row index in LLM data: 648
# Best match row index in human data: 38
# Best match score: 29.900000000000002
#   konsert_namn: 46
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 55
#   Producer: 30
#
# Row index in LLM data: 911
# Best match row index in human data: 39
# Best match score: 51.10000000000001
#   konsert_namn: 42
#   lokal_namn: 59
#   konsert_biljettpris: 40
#   konserttyp_namn: 67
#   Producer: 0
#
# Row index in LLM data: 913
# Best match row index in human data: 38
# Best match score: 69.4
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 22
#   Producer: 0
#
# Row index in LLM data: 916
# Best match row index in human data: 38
# Best match score: 41.900000000000006
#   konsert_namn: 44
#   lokal_namn: 32
#   konsert_biljettpris: 0
#   konserttyp_namn: 53
#   Producer: 31
#
# Row index in LLM data: 917
# Best match row index in human data: 38
# Best match score: 31.4
#   konsert_namn: 23
#   lokal_namn: 32
#   konsert_biljettpris: 0
#   konserttyp_namn: 30
#   Producer: 32
#
# Row index in LLM data: 967
# Best match row index in human data: 38
# Best match score: 74.39999999999999
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 26
#   konserttyp_namn: 62
#   Producer: 24
#
# Row index in LLM data: 83
# Best match row index in human data: 40
# Best match score: 57.9
#   konsert_namn: 58
#   lokal_namn: 31
#   konsert_biljettpris: 100
#   konserttyp_namn: 69
#   Producer: 27
#
# Row index in LLM data: 84
# Best match row index in human data: 41
# Best match score: 58.4
#   konsert_namn: 23
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 64
#   Producer: 100
#
# Row index in LLM data: 912
# Best match row index in human data: 41
# Best match score: 70.0
#   konsert_namn: 56
#   lokal_namn: 94
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 918
# Best match row index in human data: 41
# Best match score: 63.8
#   konsert_namn: 67
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 70
#   Producer: 100
#
# Row index in LLM data: 944
# Best match row index in human data: 41
# Best match score: 70.0
#   konsert_namn: 56
#   lokal_namn: 94
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 954
# Best match row index in human data: 41
# Best match score: 78.6
#   konsert_namn: 56
#   lokal_namn: 69
#   konsert_biljettpris: 0
#   konserttyp_namn: 86
#   Producer: 100
#
# Row index in LLM data: 969
# Best match row index in human data: 42
# Best match score: 111.60000000000001
#   konsert_namn: 88
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 52
# Best match row index in human data: 44
# Best match score: 60.6
#   konsert_namn: 40
#   lokal_namn: 60
#   konsert_biljettpris: 76
#   konserttyp_namn: 100
#   Producer: 15
#
# Row index in LLM data: 438
# Best match row index in human data: 44
# Best match score: 75.8
#   konsert_namn: 79
#   lokal_namn: 60
#   konsert_biljettpris: 50
#   konserttyp_namn: 100
#   Producer: 26
#
# Row index in LLM data: 493
# Best match row index in human data: 44
# Best match score: 75.8
#   konsert_namn: 79
#   lokal_namn: 60
#   konsert_biljettpris: 50
#   konserttyp_namn: 100
#   Producer: 26
#
# Row index in LLM data: 914
# Best match row index in human data: 44
# Best match score: 74.8
#   konsert_namn: 26
#   lokal_namn: 85
#   konsert_biljettpris: 76
#   konserttyp_namn: 100
#   Producer: 64
#
# Row index in LLM data: 970
# Best match row index in human data: 44
# Best match score: 64.0
#   konsert_namn: 47
#   lokal_namn: 32
#   konsert_biljettpris: 76
#   konserttyp_namn: 100
#   Producer: 74
#
# Row index in LLM data: 50
# Best match row index in human data: 47
# Best match score: 43.7
#   konsert_namn: 44
#   lokal_namn: 32
#   konsert_biljettpris: 42
#   konserttyp_namn: 61
#   Producer: 15
#
# Row index in LLM data: 80
# Best match row index in human data: 46
# Best match score: 49.30000000000001
#   konsert_namn: 79
#   lokal_namn: 0
#   konsert_biljettpris: 68
#   konserttyp_namn: 61
#   Producer: 24
#
# Row index in LLM data: 85
# Best match row index in human data: 46
# Best match score: 52.7
#   konsert_namn: 68
#   lokal_namn: 37
#   konsert_biljettpris: 26
#   konserttyp_namn: 61
#   Producer: 10
#
# Row index in LLM data: 956
# Best match row index in human data: 46
# Best match score: 31.900000000000002
#   konsert_namn: 38
#   lokal_namn: 0
#   konsert_biljettpris: 63
#   konserttyp_namn: 56
#   Producer: 24
#
# Row index in LLM data: 971
# Best match row index in human data: 46
# Best match score: 68.10000000000001
#   konsert_namn: 38
#   lokal_namn: 100
#   konsert_biljettpris: 26
#   konserttyp_namn: 55
#   Producer: 24
#
# Row index in LLM data: 957
# Best match row index in human data: 50
# Best match score: 31.900000000000002
#   konsert_namn: 38
#   lokal_namn: 0
#   konsert_biljettpris: 63
#   konserttyp_namn: 56
#   Producer: 24
#
# Row index in LLM data: 972
# Best match row index in human data: 50
# Best match score: 68.10000000000001
#   konsert_namn: 38
#   lokal_namn: 100
#   konsert_biljettpris: 26
#   konserttyp_namn: 55
#   Producer: 24
#
# Row index in LLM data: 1028
# Best match row index in human data: 52
# Best match score: 66.6
#   konsert_namn: 100
#   lokal_namn: 36
#   konsert_biljettpris: 0
#   konserttyp_namn: 82
#   Producer: 20
#
# Row index in LLM data: 1032
# Best match row index in human data: 53
# Best match score: 34.900000000000006
#   konsert_namn: 30
#   lokal_namn: 32
#   konsert_biljettpris: 0
#   konserttyp_namn: 21
#   Producer: 40
#
# Row index in LLM data: 1033
# Best match row index in human data: 52
# Best match score: 23.7
#   konsert_namn: 15
#   lokal_namn: 21
#   konsert_biljettpris: 0
#   konserttyp_namn: 33
#   Producer: 30
#
# Row index in LLM data: 55
# Best match row index in human data: 55
# Best match score: 73.4
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 0
#   konserttyp_namn: 62
#   Producer: 32
#
# Row index in LLM data: 57
# Best match row index in human data: 56
# Best match score: 38.0
#   konsert_namn: 45
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 100
#
# Row index in LLM data: 568
# Best match row index in human data: 55
# Best match score: 46.800000000000004
#   konsert_namn: 56
#   lokal_namn: 33
#   konsert_biljettpris: 0
#   konserttyp_namn: 62
#   Producer: 25
#
# Row index in LLM data: 676
# Best match row index in human data: 55
# Best match score: 44.400000000000006
#   konsert_namn: 64
#   lokal_namn: 22
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 910
# Best match row index in human data: 56
# Best match score: 40.400000000000006
#   konsert_namn: 26
#   lokal_namn: 42
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 34
#
# Row index in LLM data: 931
# Best match row index in human data: 55
# Best match score: 38.7
#   konsert_namn: 49
#   lokal_namn: 33
#   konsert_biljettpris: 0
#   konserttyp_namn: 59
#   Producer: 0
#
# Row index in LLM data: 933
# Best match row index in human data: 55
# Best match score: 73.6
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 25
#
# Row index in LLM data: 934
# Best match row index in human data: 56
# Best match score: 50.4
#   konsert_namn: 38
#   lokal_namn: 43
#   konsert_biljettpris: 54
#   konserttyp_namn: 62
#   Producer: 32
#
# Row index in LLM data: 939
# Best match row index in human data: 56
# Best match score: 46.5
#   konsert_namn: 55
#   lokal_namn: 42
#   konsert_biljettpris: 0
#   konserttyp_namn: 47
#   Producer: 15
#
# Row index in LLM data: 958
# Best match row index in human data: 56
# Best match score: 42.0
#   konsert_namn: 28
#   lokal_namn: 0
#   konsert_biljettpris: 38
#   konserttyp_namn: 70
#   Producer: 100
#
# Row index in LLM data: 973
# Best match row index in human data: 54
# Best match score: 68.10000000000001
#   konsert_namn: 38
#   lokal_namn: 100
#   konsert_biljettpris: 26
#   konserttyp_namn: 55
#   Producer: 24
#
# Row index in LLM data: 1029
# Best match row index in human data: 56
# Best match score: 66.69999999999999
#   konsert_namn: 37
#   lokal_namn: 43
#   konsert_biljettpris: 83
#   konserttyp_namn: 64
#   Producer: 100
#
# Row index in LLM data: 1031
# Best match row index in human data: 55
# Best match score: 74.5
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 70
#   konserttyp_namn: 67
#   Producer: 0
#
# Row index in LLM data: 56
# Best match row index in human data: 57
# Best match score: 67.4
#   konsert_namn: 59
#   lokal_namn: 64
#   konsert_biljettpris: 100
#   konserttyp_namn: 82
#   Producer: 0
#
# Row index in LLM data: 86
# Best match row index in human data: 60
# Best match score: 73.80000000000001
#   konsert_namn: 22
#   lokal_namn: 94
#   konsert_biljettpris: 0
#   konserttyp_namn: 74
#   Producer: 100
#
# Row index in LLM data: 431
# Best match row index in human data: 59
# Best match score: 111.60000000000001
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 52
#   Producer: 100
#
# Row index in LLM data: 432
# Best match row index in human data: 59
# Best match score: 116.4
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 486
# Best match row index in human data: 59
# Best match score: 111.60000000000001
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 52
#   Producer: 100
#
# Row index in LLM data: 487
# Best match row index in human data: 59
# Best match score: 116.4
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 584
# Best match row index in human data: 57
# Best match score: 55.400000000000006
#   konsert_namn: 41
#   lokal_namn: 53
#   konsert_biljettpris: 44
#   konserttyp_namn: 100
#   Producer: 17
#
# Row index in LLM data: 915
# Best match row index in human data: 58
# Best match score: 50.00000000000001
#   konsert_namn: 31
#   lokal_namn: 41
#   konsert_biljettpris: 100
#   konserttyp_namn: 58
#   Producer: 27
#
# Row index in LLM data: 935
# Best match row index in human data: 59
# Best match score: 96.4
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 936
# Best match row index in human data: 60
# Best match score: 97.2
#   konsert_namn: 61
#   lokal_namn: 94
#   konsert_biljettpris: 100
#   konserttyp_namn: 52
#   Producer: 100
#
# Row index in LLM data: 940
# Best match row index in human data: 58
# Best match score: 58.00000000000001
#   konsert_namn: 96
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 96
#   Producer: 0
#
# Row index in LLM data: 1030
# Best match row index in human data: 59
# Best match score: 97.0
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 70
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 938
# Best match row index in human data: 62
# Best match score: 63.900000000000006
#   konsert_namn: 24
#   lokal_namn: 79
#   konsert_biljettpris: 0
#   konserttyp_namn: 27
#   Producer: 100
#
# Row index in LLM data: 614
# Best match row index in human data: 65
# Best match score: 87.60000000000001
#   konsert_namn: 85
#   lokal_namn: 85
#   konsert_biljettpris: 52
#   konserttyp_namn: 30
#   Producer: 57
#
# Row index in LLM data: 616
# Best match row index in human data: 66
# Best match score: 42.10000000000001
#   konsert_namn: 47
#   lokal_namn: 24
#   konsert_biljettpris: 21
#   konserttyp_namn: 48
#   Producer: 34
#
# Row index in LLM data: 617
# Best match row index in human data: 66
# Best match score: 48.199999999999996
#   konsert_namn: 47
#   lokal_namn: 40
#   konsert_biljettpris: 0
#   konserttyp_namn: 74
#   Producer: 30
#
# Row index in LLM data: 650
# Best match row index in human data: 65
# Best match score: 40.900000000000006
#   konsert_namn: 32
#   lokal_namn: 38
#   konsert_biljettpris: 21
#   konserttyp_namn: 58
#   Producer: 25
#
# Row index in LLM data: 937
# Best match row index in human data: 65
# Best match score: 62.900000000000006
#   konsert_namn: 19
#   lokal_namn: 85
#   konsert_biljettpris: 76
#   konserttyp_namn: 57
#   Producer: 40
#
# Row index in LLM data: 6
# Best match row index in human data: 68
# Best match score: 69.8
#   konsert_namn: 100
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 42
# Best match row index in human data: 68
# Best match score: 67.9
#   konsert_namn: 87
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 57
#   Producer: 23
#
# Row index in LLM data: 54
# Best match row index in human data: 68
# Best match score: 64.9
#   konsert_namn: 94
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 53
#   Producer: 0
#
# Row index in LLM data: 58
# Best match row index in human data: 68
# Best match score: 68.2
#   konsert_namn: 100
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 62
#   Producer: 0
#
# Row index in LLM data: 81
# Best match row index in human data: 68
# Best match score: 39.0
#   konsert_namn: 27
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 62
#   Producer: 0
#
# Row index in LLM data: 405
# Best match row index in human data: 68
# Best match score: 89.8
#   konsert_namn: 100
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 427
# Best match row index in human data: 68
# Best match score: 88.60000000000001
#   konsert_namn: 97
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 460
# Best match row index in human data: 68
# Best match score: 89.8
#   konsert_namn: 100
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 482
# Best match row index in human data: 68
# Best match score: 88.60000000000001
#   konsert_namn: 97
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 945
# Best match row index in human data: 68
# Best match score: 69.8
#   konsert_namn: 100
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 1001
# Best match row index in human data: 68
# Best match score: 61.7
#   konsert_namn: 100
#   lokal_namn: 30
#   konsert_biljettpris: 57
#   konserttyp_namn: 40
#   Producer: 0
#
# Row index in LLM data: 71
# Best match row index in human data: 70
# Best match score: 55.4
#   konsert_namn: 50
#   lokal_namn: 42
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 43
#
# Row index in LLM data: 428
# Best match row index in human data: 71
# Best match score: 37.60000000000001
#   konsert_namn: 22
#   lokal_namn: 26
#   konsert_biljettpris: 100
#   konserttyp_namn: 52
#   Producer: 16
#
# Row index in LLM data: 483
# Best match row index in human data: 71
# Best match score: 37.60000000000001
#   konsert_namn: 22
#   lokal_namn: 26
#   konsert_biljettpris: 100
#   konserttyp_namn: 52
#   Producer: 16
#
# Row index in LLM data: 590
# Best match row index in human data: 70
# Best match score: 82.19999999999999
#   konsert_namn: 67
#   lokal_namn: 100
#   konsert_biljettpris: 16
#   konserttyp_namn: 100
#   Producer: 19
#
# Row index in LLM data: 926
# Best match row index in human data: 71
# Best match score: 28.0
#   konsert_namn: 70
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 927
# Best match row index in human data: 70
# Best match score: 78.8
#   konsert_namn: 47
#   lokal_namn: 100
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 930
# Best match row index in human data: 70
# Best match score: 55.6
#   konsert_namn: 100
#   lokal_namn: 39
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 702
# Best match row index in human data: 73
# Best match score: 40.5
#   konsert_namn: 52
#   lokal_namn: 22
#   konsert_biljettpris: 0
#   konserttyp_namn: 69
#   Producer: 20
#
# Row index in LLM data: 902
# Best match row index in human data: 73
# Best match score: 68.6
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 26
#   konserttyp_namn: 52
#   Producer: 0
#
# Row index in LLM data: 909
# Best match row index in human data: 73
# Best match score: 47.80000000000001
#   konsert_namn: 44
#   lokal_namn: 29
#   konsert_biljettpris: 46
#   konserttyp_namn: 78
#   Producer: 31
#
# Row index in LLM data: 928
# Best match row index in human data: 73
# Best match score: 72.9
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 30
#   konserttyp_namn: 27
#   Producer: 32
#
# Row index in LLM data: 59
# Best match row index in human data: 75
# Best match score: 10.0
#   konsert_namn: 0
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 62
# Best match row index in human data: 75
# Best match score: 55.0
#   konsert_namn: 61
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 63
# Best match row index in human data: 75
# Best match score: 56.099999999999994
#   konsert_namn: 62
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 69
#   Producer: 12
#
# Row index in LLM data: 64
# Best match row index in human data: 75
# Best match score: 39.400000000000006
#   konsert_namn: 32
#   lokal_namn: 26
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 42
#
# Row index in LLM data: 562
# Best match row index in human data: 74
# Best match score: 73.8
#   konsert_namn: 67
#   lokal_namn: 64
#   konsert_biljettpris: 29
#   konserttyp_namn: 33
#   Producer: 76
#
# Row index in LLM data: 700
# Best match row index in human data: 75
# Best match score: 58.400000000000006
#   konsert_namn: 96
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 903
# Best match row index in human data: 74
# Best match score: 62.39999999999999
#   konsert_namn: 31
#   lokal_namn: 79
#   konsert_biljettpris: 78
#   konserttyp_namn: 78
#   Producer: 14
#
# Row index in LLM data: 904
# Best match row index in human data: 76
# Best match score: 73.60000000000001
#   konsert_namn: 52
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 64
#   Producer: 0
#
# Row index in LLM data: 908
# Best match row index in human data: 75
# Best match score: 69.2
#   konsert_namn: 96
#   lokal_namn: 52
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 929
# Best match row index in human data: 76
# Best match score: 96.4
#   konsert_namn: 100
#   lokal_namn: 100
#   konsert_biljettpris: 64
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 976
# Best match row index in human data: 74
# Best match score: 49.3
#   konsert_namn: 21
#   lokal_namn: 59
#   konsert_biljettpris: 67
#   konserttyp_namn: 78
#   Producer: 14
#
# Row index in LLM data: 980
# Best match row index in human data: 75
# Best match score: 10.0
#   konsert_namn: 0
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 981
# Best match row index in human data: 75
# Best match score: 55.0
#   konsert_namn: 61
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 982
# Best match row index in human data: 75
# Best match score: 58.80000000000001
#   konsert_namn: 46
#   lokal_namn: 48
#   konsert_biljettpris: 100
#   konserttyp_namn: 52
#   Producer: 30
#
# Row index in LLM data: 983
# Best match row index in human data: 75
# Best match score: 60.599999999999994
#   konsert_namn: 26
#   lokal_namn: 81
#   konsert_biljettpris: 100
#   konserttyp_namn: 30
#   Producer: 24
#
# Row index in LLM data: 74
# Best match row index in human data: 77
# Best match score: 42.400000000000006
#   konsert_namn: 24
#   lokal_namn: 39
#   konsert_biljettpris: 100
#   konserttyp_namn: 36
#   Producer: 18
#
# Row index in LLM data: 76
# Best match row index in human data: 77
# Best match score: 26.8
#   konsert_namn: 29
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 32
#   Producer: 10
#
# Row index in LLM data: 77
# Best match row index in human data: 77
# Best match score: 27.200000000000003
#   konsert_namn: 25
#   lokal_namn: 34
#   konsert_biljettpris: 0
#   konserttyp_namn: 36
#   Producer: 0
#
# Row index in LLM data: 581
# Best match row index in human data: 77
# Best match score: 50.8
#   konsert_namn: 29
#   lokal_namn: 45
#   konsert_biljettpris: 100
#   konserttyp_namn: 38
#   Producer: 37
#
# Row index in LLM data: 661
# Best match row index in human data: 77
# Best match score: 36.400000000000006
#   konsert_namn: 18
#   lokal_namn: 40
#   konsert_biljettpris: 100
#   konserttyp_namn: 32
#   Producer: 0
#
# Row index in LLM data: 662
# Best match row index in human data: 77
# Best match score: 38.800000000000004
#   konsert_namn: 23
#   lokal_namn: 41
#   konsert_biljettpris: 100
#   konserttyp_namn: 32
#   Producer: 0
#
# Row index in LLM data: 663
# Best match row index in human data: 77
# Best match score: 10.0
#   konsert_namn: 0
#   lokal_namn: 0
#   konsert_biljettpris: 100
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 38
# Best match row index in human data: 78
# Best match score: 31.800000000000004
#   konsert_namn: 53
#   lokal_namn: 9
#   konsert_biljettpris: 0
#   konserttyp_namn: 70
#   Producer: 0
#
# Row index in LLM data: 39
# Best match row index in human data: 78
# Best match score: 38.6
#   konsert_namn: 44
#   lokal_namn: 28
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 17
#
# Row index in LLM data: 72
# Best match row index in human data: 78
# Best match score: 53.0
#   konsert_namn: 55
#   lokal_namn: 10
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 96
#
# Row index in LLM data: 429
# Best match row index in human data: 78
# Best match score: 84.2
#   konsert_namn: 57
#   lokal_namn: 84
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 484
# Best match row index in human data: 78
# Best match score: 84.2
#   konsert_namn: 57
#   lokal_namn: 84
#   konsert_biljettpris: 0
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 582
# Best match row index in human data: 78
# Best match score: 32.0
#   konsert_namn: 30
#   lokal_namn: 14
#   konsert_biljettpris: 0
#   konserttyp_namn: 70
#   Producer: 37
#
# Row index in LLM data: 664
# Best match row index in human data: 78
# Best match score: 41.0
#   konsert_namn: 17
#   lokal_namn: 32
#   konsert_biljettpris: 74
#   konserttyp_namn: 78
#   Producer: 31
#
# Row index in LLM data: 704
# Best match row index in human data: 78
# Best match score: 61.199999999999996
#   konsert_namn: 43
#   lokal_namn: 79
#   konsert_biljettpris: 0
#   konserttyp_namn: 48
#   Producer: 38
#
# Row index in LLM data: 905
# Best match row index in human data: 78
# Best match score: 82.0
#   konsert_namn: 100
#   lokal_namn: 79
#   konsert_biljettpris: 0
#   konserttyp_namn: 42
#   Producer: 31
#
# Row index in LLM data: 924
# Best match row index in human data: 78
# Best match score: 36.6
#   konsert_namn: 30
#   lokal_namn: 43
#   konsert_biljettpris: 0
#   konserttyp_namn: 12
#   Producer: 31
#
# Row index in LLM data: 45
# Best match row index in human data: 79
# Best match score: 72.4
#   konsert_namn: 49
#   lokal_namn: 79
#   konsert_biljettpris: 72
#   konserttyp_namn: 78
#   Producer: 31
#
# Row index in LLM data: 436
# Best match row index in human data: 79
# Best match score: 67.30000000000001
#   konsert_namn: 47
#   lokal_namn: 79
#   konsert_biljettpris: 91
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 491
# Best match row index in human data: 79
# Best match score: 67.30000000000001
#   konsert_namn: 47
#   lokal_namn: 79
#   konsert_biljettpris: 91
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 684
# Best match row index in human data: 79
# Best match score: 35.6
#   konsert_namn: 47
#   lokal_namn: 17
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 919
# Best match row index in human data: 79
# Best match score: 41.6
#   konsert_namn: 78
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 58
#   Producer: 23
#
# Row index in LLM data: 977
# Best match row index in human data: 79
# Best match score: 68.8
#   konsert_namn: 56
#   lokal_namn: 79
#   konsert_biljettpris: 70
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 1
# Best match row index in human data: 81
# Best match score: 39.199999999999996
#   konsert_namn: 13
#   lokal_namn: 44
#   konsert_biljettpris: 100
#   konserttyp_namn: 64
#   Producer: 0
#
# Row index in LLM data: 2
# Best match row index in human data: 81
# Best match score: 49.2
#   konsert_namn: 25
#   lokal_namn: 48
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 35
# Best match row index in human data: 80
# Best match score: 58.00000000000001
#   konsert_namn: 58
#   lokal_namn: 41
#   konsert_biljettpris: 89
#   konserttyp_namn: 55
#   Producer: 20
#
# Row index in LLM data: 510
# Best match row index in human data: 81
# Best match score: 43.800000000000004
#   konsert_namn: 13
#   lokal_namn: 48
#   konsert_biljettpris: 100
#   konserttyp_namn: 64
#   Producer: 15
#
# Row index in LLM data: 543
# Best match row index in human data: 80
# Best match score: 67.7
#   konsert_namn: 67
#   lokal_namn: 64
#   konsert_biljettpris: 35
#   konserttyp_namn: 78
#   Producer: 20
#
# Row index in LLM data: 557
# Best match row index in human data: 80
# Best match score: 60.400000000000006
#   konsert_namn: 87
#   lokal_namn: 64
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 558
# Best match row index in human data: 80
# Best match score: 69.7
#   konsert_namn: 87
#   lokal_namn: 64
#   konsert_biljettpris: 0
#   konserttyp_namn: 55
#   Producer: 19
#
# Row index in LLM data: 563
# Best match row index in human data: 80
# Best match score: 62.0
#   konsert_namn: 59
#   lokal_namn: 64
#   konsert_biljettpris: 50
#   konserttyp_namn: 78
#   Producer: 0
#
# Row index in LLM data: 591
# Best match row index in human data: 81
# Best match score: 41.2
#   konsert_namn: 11
#   lokal_namn: 92
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 0
#
# Row index in LLM data: 592
# Best match row index in human data: 81
# Best match score: 57.60000000000001
#   konsert_namn: 19
#   lokal_namn: 92
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 16
#
# Row index in LLM data: 612
# Best match row index in human data: 80
# Best match score: 64.8
#   konsert_namn: 54
#   lokal_namn: 64
#   konsert_biljettpris: 50
#   konserttyp_namn: 78
#   Producer: 24
#
# Row index in LLM data: 686
# Best match row index in human data: 80
# Best match score: 48.5
#   konsert_namn: 44
#   lokal_namn: 32
#   konsert_biljettpris: 81
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 687
# Best match row index in human data: 81
# Best match score: 46.20000000000001
#   konsert_namn: 29
#   lokal_namn: 33
#   konsert_biljettpris: 100
#   konserttyp_namn: 48
#   Producer: 33
#
# Row index in LLM data: 703
# Best match row index in human data: 80
# Best match score: 45.7
#   konsert_namn: 26
#   lokal_namn: 41
#   konsert_biljettpris: 89
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 906
# Best match row index in human data: 80
# Best match score: 52.4
#   konsert_namn: 57
#   lokal_namn: 37
#   konsert_biljettpris: 100
#   konserttyp_namn: 18
#   Producer: 15
#
# Row index in LLM data: 920
# Best match row index in human data: 80
# Best match score: 40.3
#   konsert_namn: 51
#   lokal_namn: 0
#   konsert_biljettpris: 81
#   konserttyp_namn: 78
#   Producer: 20
#
# Row index in LLM data: 978
# Best match row index in human data: 80
# Best match score: 40.1
#   konsert_namn: 45
#   lokal_namn: 0
#   konsert_biljettpris: 81
#   konserttyp_namn: 100
#   Producer: 20
#
# Row index in LLM data: 0
# Best match row index in human data: 82
# Best match score: 91.1
#   konsert_namn: 56
#   lokal_namn: 79
#   konsert_biljettpris: 71
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 36
# Best match row index in human data: 82
# Best match score: 75.6
#   konsert_namn: 60
#   lokal_namn: 79
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 48
# Best match row index in human data: 83
# Best match score: 35.800000000000004
#   konsert_namn: 29
#   lokal_namn: 40
#   konsert_biljettpris: 0
#   konserttyp_namn: 48
#   Producer: 17
#
# Row index in LLM data: 60
# Best match row index in human data: 82
# Best match score: 48.5
#   konsert_namn: 30
#   lokal_namn: 0
#   konsert_biljettpris: 65
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 61
# Best match row index in human data: 82
# Best match score: 65.0
#   konsert_namn: 43
#   lokal_namn: 79
#   konsert_biljettpris: 100
#   konserttyp_namn: 62
#   Producer: 0
#
# Row index in LLM data: 70
# Best match row index in human data: 82
# Best match score: 49.2
#   konsert_namn: 34
#   lokal_namn: 64
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 75
# Best match row index in human data: 82
# Best match score: 72.0
#   konsert_namn: 56
#   lokal_namn: 79
#   konsert_biljettpris: 80
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 395
# Best match row index in human data: 83
# Best match score: 63.9
#   konsert_namn: 65
#   lokal_namn: 20
#   konsert_biljettpris: 38
#   konserttyp_namn: 61
#   Producer: 100
#
# Row index in LLM data: 412
# Best match row index in human data: 82
# Best match score: 82.80000000000001
#   konsert_namn: 28
#   lokal_namn: 79
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 413
# Best match row index in human data: 83
# Best match score: 65.9
#   konsert_namn: 65
#   lokal_namn: 24
#   konsert_biljettpris: 42
#   konserttyp_namn: 61
#   Producer: 100
#
# Row index in LLM data: 417
# Best match row index in human data: 82
# Best match score: 85.2
#   konsert_namn: 34
#   lokal_namn: 79
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 418
# Best match row index in human data: 82
# Best match score: 98.2
#   konsert_namn: 51
#   lokal_namn: 100
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 421
# Best match row index in human data: 82
# Best match score: 53.0
#   konsert_namn: 31
#   lokal_namn: 21
#   konsert_biljettpris: 100
#   konserttyp_namn: 22
#   Producer: 100
#
# Row index in LLM data: 450
# Best match row index in human data: 83
# Best match score: 63.9
#   konsert_namn: 65
#   lokal_namn: 20
#   konsert_biljettpris: 38
#   konserttyp_namn: 61
#   Producer: 100
#
# Row index in LLM data: 467
# Best match row index in human data: 82
# Best match score: 82.80000000000001
#   konsert_namn: 28
#   lokal_namn: 79
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 468
# Best match row index in human data: 83
# Best match score: 65.9
#   konsert_namn: 65
#   lokal_namn: 24
#   konsert_biljettpris: 42
#   konserttyp_namn: 61
#   Producer: 100
#
# Row index in LLM data: 472
# Best match row index in human data: 82
# Best match score: 85.2
#   konsert_namn: 34
#   lokal_namn: 79
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 473
# Best match row index in human data: 82
# Best match score: 98.2
#   konsert_namn: 51
#   lokal_namn: 100
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 100
#
# Row index in LLM data: 476
# Best match row index in human data: 82
# Best match score: 53.0
#   konsert_namn: 31
#   lokal_namn: 21
#   konsert_biljettpris: 100
#   konserttyp_namn: 22
#   Producer: 100
#
# Row index in LLM data: 508
# Best match row index in human data: 82
# ...
# Best match score: 48.4
#   konsert_namn: 51
#   lokal_namn: 24
#   konsert_biljettpris: 60
#   konserttyp_namn: 74
#   Producer: 25
#
# Row index in LLM data: 883
# Best match row index in human data: 448
# Best match score: 43.2
#   konsert_namn: 54
#   lokal_namn: 17
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 24
#
# Row index in LLM data: 1325
# Best match row index in human data: 448
# Best match score: 107.20000000000002
#   konsert_namn: 98
#   lokal_namn: 79
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 93
#
# Row index in LLM data: 1341
# Best match row index in human data: 448
# Best match score: 29.9
#   konsert_namn: 18
#   lokal_namn: 27
#   konsert_biljettpris: 94
#   konserttyp_namn: 25
#   Producer: 0
#
# Row index in LLM data: 1344
# Best match row index in human data: 448
# Best match score: 39.0
#   konsert_namn: 44
#   lokal_namn: 21
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 15
#
# Row index in LLM data: 1345
# Best match row index in human data: 448
# Best match score: 35.0
#   konsert_namn: 43
#   lokal_namn: 27
#   konsert_biljettpris: 0
#   konserttyp_namn: 70
#   Producer: 0
#
# Row index in LLM data: 1347
# Best match row index in human data: 448
# Best match score: 40.4
#   konsert_namn: 39
#   lokal_namn: 21
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 50
#
# Row index in LLM data: 356
# Best match row index in human data: 450
# Best match score: 32.4
#   konsert_namn: 28
#   lokal_namn: 35
#   konsert_biljettpris: 29
#   konserttyp_namn: 43
#   Producer: 0
#
# Row index in LLM data: 1346
# Best match row index in human data: 450
# Best match score: 32.4
#   konsert_namn: 28
#   lokal_namn: 35
#   konsert_biljettpris: 29
#   konserttyp_namn: 43
#   Producer: 0
#
# Row index in LLM data: 353
# Best match row index in human data: 452
# Best match score: 52.0
#   konsert_namn: 55
#   lokal_namn: 17
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 16
#
# Row index in LLM data: 879
# Best match row index in human data: 452
# Best match score: 30.400000000000002
#   konsert_namn: 17
#   lokal_namn: 37
#   konsert_biljettpris: 0
#   konserttyp_namn: 88
#   Producer: 0
#
# Row index in LLM data: 882
# Best match row index in human data: 453
# Best match score: 69.0
#   konsert_namn: 48
#   lokal_namn: 81
#   konsert_biljettpris: 100
#   konserttyp_namn: 74
#   Producer: 0
#
# Row index in LLM data: 1343
# Best match row index in human data: 452
# Best match score: 52.0
#   konsert_namn: 55
#   lokal_namn: 17
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 16
#
# Row index in LLM data: 336
# Best match row index in human data: 455
# Best match score: 50.10000000000001
#   konsert_namn: 49
#   lokal_namn: 32
#   konsert_biljettpris: 70
#   konserttyp_namn: 67
#   Producer: 20
#
# Row index in LLM data: 352
# Best match row index in human data: 455
# Best match score: 24.0
#   konsert_namn: 47
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 26
#
# Row index in LLM data: 856
# Best match row index in human data: 455
# Best match score: 62.2
#   konsert_namn: 45
#   lokal_namn: 79
#   konsert_biljettpris: 74
#   konserttyp_namn: 22
#   Producer: 15
#
# Row index in LLM data: 1326
# Best match row index in human data: 455
# Best match score: 50.10000000000001
#   konsert_namn: 49
#   lokal_namn: 32
#   konsert_biljettpris: 70
#   konserttyp_namn: 67
#   Producer: 20
#
# Row index in LLM data: 1342
# Best match row index in human data: 455
# Best match score: 24.0
#   konsert_namn: 47
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 0
#   Producer: 26
#
# Row index in LLM data: 317
# Best match row index in human data: 459
# Best match score: 78.3
#   konsert_namn: 60
#   lokal_namn: 94
#   konsert_biljettpris: 100
#   konserttyp_namn: 67
#   Producer: 0
#
# Row index in LLM data: 323
# Best match row index in human data: 459
# Best match score: 59.2
#   konsert_namn: 75
#   lokal_namn: 43
#   konsert_biljettpris: 50
#   konserttyp_namn: 70
#   Producer: 0
#
# Row index in LLM data: 324
# Best match row index in human data: 458
# Best match score: 69.9
#   konsert_namn: 43
#   lokal_namn: 100
#   konsert_biljettpris: 60
#   konserttyp_namn: 67
#   Producer: 0
#
# Row index in LLM data: 325
# Best match row index in human data: 459
# Best match score: 90.3
#   konsert_namn: 56
#   lokal_namn: 94
#   konsert_biljettpris: 46
#   konserttyp_namn: 67
#   Producer: 95
#
# Row index in LLM data: 327
# Best match row index in human data: 460
# Best match score: 39.2
#   konsert_namn: 37
#   lokal_namn: 25
#   konsert_biljettpris: 22
#   konserttyp_namn: 64
#   Producer: 29
#
# Row index in LLM data: 328
# Best match row index in human data: 457
# Best match score: 46.400000000000006
#   konsert_namn: 33
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 62
#   Producer: 21
#
# Row index in LLM data: 1307
# Best match row index in human data: 459
# Best match score: 78.3
#   konsert_namn: 60
#   lokal_namn: 94
#   konsert_biljettpris: 100
#   konserttyp_namn: 67
#   Producer: 0
#
# Row index in LLM data: 1313
# Best match row index in human data: 459
# Best match score: 59.2
#   konsert_namn: 75
#   lokal_namn: 43
#   konsert_biljettpris: 50
#   konserttyp_namn: 70
#   Producer: 0
#
# Row index in LLM data: 1314
# Best match row index in human data: 458
# Best match score: 69.9
#   konsert_namn: 43
#   lokal_namn: 100
#   konsert_biljettpris: 60
#   konserttyp_namn: 67
#   Producer: 0
#
# Row index in LLM data: 1315
# Best match row index in human data: 459
# Best match score: 90.3
#   konsert_namn: 56
#   lokal_namn: 94
#   konsert_biljettpris: 46
#   konserttyp_namn: 67
#   Producer: 95
#
# Row index in LLM data: 1317
# Best match row index in human data: 460
# Best match score: 39.2
#   konsert_namn: 37
#   lokal_namn: 25
#   konsert_biljettpris: 22
#   konserttyp_namn: 64
#   Producer: 29
#
# Row index in LLM data: 1318
# Best match row index in human data: 457
# Best match score: 46.400000000000006
#   konsert_namn: 33
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 62
#   Producer: 21
#
# Row index in LLM data: 315
# Best match row index in human data: 462
# Best match score: 55.0
#   konsert_namn: 44
#   lokal_namn: 39
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 20
#
# Row index in LLM data: 876
# Best match row index in human data: 462
# Best match score: 56.0
#   konsert_namn: 26
#   lokal_namn: 64
#   konsert_biljettpris: 84
#   konserttyp_namn: 78
#   Producer: 19
#
# Row index in LLM data: 1305
# Best match row index in human data: 462
# Best match score: 55.0
#   konsert_namn: 44
#   lokal_namn: 39
#   konsert_biljettpris: 100
#   konserttyp_namn: 78
#   Producer: 20
#
# Row index in LLM data: 316
# Best match row index in human data: 467
# Best match score: 41.300000000000004
#   konsert_namn: 30
#   lokal_namn: 48
#   konsert_biljettpris: 49
#   konserttyp_namn: 52
#   Producer: 0
#
# Row index in LLM data: 326
# Best match row index in human data: 467
# Best match score: 50.3
#   konsert_namn: 50
#   lokal_namn: 48
#   konsert_biljettpris: 23
#   konserttyp_namn: 88
#   Producer: 0
#
# Row index in LLM data: 1306
# Best match row index in human data: 467
# Best match score: 41.300000000000004
#   konsert_namn: 30
#   lokal_namn: 48
#   konsert_biljettpris: 49
#   konserttyp_namn: 52
#   Producer: 0
#
# Row index in LLM data: 1316
# Best match row index in human data: 467
# Best match score: 50.3
#   konsert_namn: 50
#   lokal_namn: 48
#   konsert_biljettpris: 23
#   konserttyp_namn: 88
#   Producer: 0
#
# Row index in LLM data: 385
# Best match row index in human data: 470
# Best match score: 51.60000000000001
#   konsert_namn: 56
#   lokal_namn: 25
#   konsert_biljettpris: 100
#   konserttyp_namn: 56
#   Producer: 18
#
# Row index in LLM data: 386
# Best match row index in human data: 471
# Best match score: 62.800000000000004
#   konsert_namn: 44
#   lokal_namn: 24
#   konsert_biljettpris: 100
#   konserttyp_namn: 56
#   Producer: 100
#
# Row index in LLM data: 387
# Best match row index in human data: 470
# Best match score: 48.60000000000001
#   konsert_namn: 41
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 54
#   Producer: 24
#
# Row index in LLM data: 388
# Best match row index in human data: 471
# Best match score: 44.60000000000001
#   konsert_namn: 39
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 62
#   Producer: 0
#
# Row index in LLM data: 389
# Best match row index in human data: 471
# Best match score: 67.60000000000001
#   konsert_namn: 51
#   lokal_namn: 83
#   konsert_biljettpris: 100
#   konserttyp_namn: 40
#   Producer: 0
#
# Row index in LLM data: 1375
# Best match row index in human data: 470
# Best match score: 51.60000000000001
#   konsert_namn: 56
#   lokal_namn: 25
#   konsert_biljettpris: 100
#   konserttyp_namn: 56
#   Producer: 18
#
# Row index in LLM data: 1376
# Best match row index in human data: 471
# Best match score: 62.800000000000004
#   konsert_namn: 44
#   lokal_namn: 24
#   konsert_biljettpris: 100
#   konserttyp_namn: 56
#   Producer: 100
#
# Row index in LLM data: 1377
# Best match row index in human data: 470
# Best match score: 48.60000000000001
#   konsert_namn: 41
#   lokal_namn: 30
#   konsert_biljettpris: 100
#   konserttyp_namn: 54
#   Producer: 24
#
# Row index in LLM data: 1378
# Best match row index in human data: 471
# Best match score: 44.60000000000001
#   konsert_namn: 39
#   lokal_namn: 32
#   konsert_biljettpris: 100
#   konserttyp_namn: 62
#   Producer: 0
#
# Row index in LLM data: 1379
# Best match row index in human data: 471
# Best match score: 67.60000000000001
#   konsert_namn: 51
#   lokal_namn: 83
#   konsert_biljettpris: 100
#   konserttyp_namn: 40
#   Producer: 0
#
# Row index in LLM data: 372
# Best match row index in human data: 475
# Best match score: 49.3
#   konsert_namn: 27
#   lokal_namn: 52
#   konsert_biljettpris: 89
#   konserttyp_namn: 64
#   Producer: 12
#
# Row index in LLM data: 374
# Best match row index in human data: 477
# Best match score: 34.599999999999994
#   konsert_namn: 31
#   lokal_namn: 25
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 29
#
# Row index in LLM data: 375
# Best match row index in human data: 477
# Best match score: 50.800000000000004
#   konsert_namn: 49
#   lokal_namn: 39
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 46
#
# Row index in LLM data: 376
# Best match row index in human data: 477
# Best match score: 47.6
#   konsert_namn: 50
#   lokal_namn: 27
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 52
#
# Row index in LLM data: 377
# Best match row index in human data: 475
# Best match score: 26.700000000000003
#   konsert_namn: 15
#   lokal_namn: 19
#   konsert_biljettpris: 67
#   konserttyp_namn: 28
#   Producer: 18
#
# Row index in LLM data: 390
# Best match row index in human data: 475
# Best match score: 36.6
#   konsert_namn: 74
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 70
#   Producer: 0
#
# Row index in LLM data: 1362
# Best match row index in human data: 475
# Best match score: 49.3
#   konsert_namn: 27
#   lokal_namn: 52
#   konsert_biljettpris: 89
#   konserttyp_namn: 64
#   Producer: 12
#
# Row index in LLM data: 1364
# Best match row index in human data: 477
# Best match score: 34.599999999999994
#   konsert_namn: 31
#   lokal_namn: 25
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 29
#
# Row index in LLM data: 1365
# Best match row index in human data: 477
# Best match score: 50.800000000000004
#   konsert_namn: 49
#   lokal_namn: 39
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 46
#
# Row index in LLM data: 1366
# Best match row index in human data: 477
# Best match score: 47.6
#   konsert_namn: 50
#   lokal_namn: 27
#   konsert_biljettpris: 0
#   konserttyp_namn: 64
#   Producer: 52
#
# Row index in LLM data: 1367
# Best match row index in human data: 475
# Best match score: 26.700000000000003
#   konsert_namn: 15
#   lokal_namn: 19
#   konsert_biljettpris: 67
#   konserttyp_namn: 28
#   Producer: 18
#
# Row index in LLM data: 1380
# Best match row index in human data: 475
# Best match score: 36.6
#   konsert_namn: 74
#   lokal_namn: 0
#   konsert_biljettpris: 0
#   konserttyp_namn: 70
#   Producer: 0
#
# Row index in LLM data: 383
# Best match row index in human data: 478
# Best match score: 74.8
#   konsert_namn: 21
#   lokal_namn: 91
#   konsert_biljettpris: 100
#   konserttyp_namn: 64
#   Producer: 68
#
# Row index in LLM data: 1373
# Best match row index in human data: 478
# Best match score: 74.8
#   konsert_namn: 21
#   lokal_namn: 91
#   konsert_biljettpris: 100
#   konserttyp_namn: 64
#   Producer: 68
#
# Row index in LLM data: 373
# Best match row index in human data: 483
# Best match score: 54.400000000000006
#   konsert_namn: 34
#   lokal_namn: 33
#   konsert_biljettpris: 0
#   konserttyp_namn: 76
#   Producer: 100
#
# Row index in LLM data: 384
# Best match row index in human data: 483
# Best match score: 55.2
#   konsert_namn: 34
#   lokal_namn: 29
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 1363
# Best match row index in human data: 483
# Best match score: 54.400000000000006
#   konsert_namn: 34
#   lokal_namn: 33
#   konsert_biljettpris: 0
#   konserttyp_namn: 76
#   Producer: 100
#
# Row index in LLM data: 1374
# Best match row index in human data: 483
# Best match score: 55.2
#   konsert_namn: 34
#   lokal_namn: 29
#   konsert_biljettpris: 0
#   konserttyp_namn: 100
#   Producer: 100
#
# Row index in LLM data: 367
# Best match row index in human data: 505
# Best match score: 18.7
#   konsert_namn: 25
#   lokal_namn: 17
#   konsert_biljettpris: 0
#   konserttyp_namn: 19
#   Producer: 0
#
# Row index in LLM data: 368
# Best match row index in human data: 505
# Best match score: 18.0
#   konsert_namn: 17
#   lokal_namn: 25
#   konsert_biljettpris: 0
#   konserttyp_namn: 12
#   Producer: 0
#
# Row index in LLM data: 369
# Best match row index in human data: 505
# Best match score: 21.3
#   konsert_namn: 21
#   lokal_namn: 26
#   konsert_biljettpris: 0
#   konserttyp_namn: 25
#   Producer: 0
#
# Row index in LLM data: 370
# Best match row index in human data: 505
# Best match score: 17.8
#   konsert_namn: 25
#   lokal_namn: 14
#   konsert_biljettpris: 0
#   konserttyp_namn: 22
#   Producer: 0
#
# Row index in LLM data: 371
# Best match row index in human data: 505
# Best match score: 39.8
#   konsert_namn: 26
#   lokal_namn: 18
#   konsert_biljettpris: 0
#   konserttyp_namn: 22
#   Producer: 100
#
# Row index in LLM data: 1357
# Best match row index in human data: 505
# Best match score: 18.7
#   konsert_namn: 25
#   lokal_namn: 17
#   konsert_biljettpris: 0
#   konserttyp_namn: 19
#   Producer: 0
#
# Row index in LLM data: 1358
# Best match row index in human data: 505
# Best match score: 18.0
#   konsert_namn: 17
#   lokal_namn: 25
#   konsert_biljettpris: 0
#   konserttyp_namn: 12
#   Producer: 0
#
# Row index in LLM data: 1359
# Best match row index in human data: 505
# Best match score: 21.3
#   konsert_namn: 21
#   lokal_namn: 26
#   konsert_biljettpris: 0
#   konserttyp_namn: 25
#   Producer: 0
#
# Row index in LLM data: 1360
# Best match row index in human data: 505
# Best match score: 17.8
#   konsert_namn: 25
#   lokal_namn: 14
#   konsert_biljettpris: 0
#   konserttyp_namn: 22
#   Producer: 0
#
# Row index in LLM data: 1361
# Best match row index in human data: 505
# Best match score: 39.8
#   konsert_namn: 26
#   lokal_namn: 18
#   konsert_biljettpris: 0
#   konserttyp_namn: 22
#   Producer: 100
#
# Row index in LLM data: 835
# Best match row index in human data: 506
# Best match score: 46.8
#   konsert_namn: 43
#   lokal_namn: 24
#   konsert_biljettpris: 100
#   konserttyp_namn: 100
#   Producer: 0
#
# Row index in LLM data: 836
# Best match row index in human data: 506
# Best match score: 46.800000000000004
#   konsert_namn: 45
#   lokal_namn: 29
#   konsert_biljettpris: 100
#   konserttyp_namn: 22
#   Producer: 25
#
# Row index in LLM data: 850
# Best match row index in human data: 508
# Best match score: 33.4
#   konsert_namn: 20
#   lokal_namn: 25
#   konsert_biljettpris: 85
#   konserttyp_namn: 69
#   Producer: 0
#
# Row index in LLM data: 849
# Best match row index in human data: 511
# Best match score: 27.500000000000004
#   konsert_namn: 12
#   lokal_namn: 32
#   konsert_biljettpris: 0
#   konserttyp_namn: 33
#   Producer: 33
#
# Row index in LLM data: 828
# Best match row index in human data: 513
# Best match score: 27.000000000000004
#   konsert_namn: 33
#   lokal_namn: 29
#   konsert_biljettpris: 0
#   konserttyp_namn: 22
#   Producer: 0
#
# Row index in LLM data: 829
# Best match row index in human data: 513
# Best match score: 23.2
#   konsert_namn: 25
#   lokal_namn: 31
#   konsert_biljettpris: 0
#   konserttyp_namn: 8
#   Producer: 0
#
# Row index in LLM data: 832
# Best match row index in human data: 512
# Best match score: 79.6
#   konsert_namn: 24
#   lokal_namn: 100
#   konsert_biljettpris: 100
#   konserttyp_namn: 0
#   Producer: 100
#
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Trying a heatmap recommended by gpt4
