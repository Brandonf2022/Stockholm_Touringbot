# %% [markdown]
# # Fuzzy Comparison between human-made and AI-made data

# %%
import pandas as pd

# Load XLS file with the date column explicitly set to string type
xls_path = 'All_Concerts_1908_filtered.xlsx'

# Load the Excel file, skipping the specified number of rows
xls_df = pd.read_excel(xls_path)

# Display the first few rows of the loaded DataFrame to verify
print(xls_df.head(10))

# Display the DataFrame to ensure dates are read as strings. Basically if you see dates here and not NaT, we're good.
#start_row_xls = 2090
#num_rows_to_display = 3  # Adjust as needed
#print("Excel DataFrame from row 2090:") # reason: the beginning of the data doesn't have dates in the date column.
#print(xls_df.iloc[start_row_xls:start_row_xls + num_rows_to_display])
# Out:
#    konsert_ID konsert_datum                         konsert_namn  \
# 0        2528    1908-01-02    Brüssel-kvartetten Beethovenafton
# 1        2509    1908-01-05  1:sta säsångskonsert: Nordisk afton
# 2        2521    1908-01-05                       Afskedskonsert
# 3        2516    1908-01-05                         Folk-konsert
# 4        2515    1908-01-05                       Populärkonsert
# 5        2510    1908-01-06        2:a populära Symfoni-matinéen
# 6        2511    1908-01-06                     Jul-fest med Bal
# 7        2517    1908-01-06                        Populär soaré
# 8        2519    1908-01-06                        Populär soaré
# 9        2512    1908-01-07  2:a kammarmusikkonsert: Brahmsafton
#
#                                      lokal_namn  \
# 0         Kungliga musikaliska akademiens lokal
# 1                    Hotel Continentals festsal
# 2                               Immanuelskyrkan
# 3  Arbetare-institutet, Klara Norra Kyrkogata 8
# 4                   Vetenskapsakademiens hörsal
# 5                                  Berns salong
# 6       Grand Restaurant Nationals stora salong
# 7                   Vetenskapsakademiens hörsal
# 8  Arbetare-institutet, Klara Norra Kyrkogata 8
# 9                   Vetenskapsakademiens hörsal
#
#                           konsert_biljettpris  SummaförAnnons/program  \
# 0                                         NaN                     NaN
# 1    2kr (numrerade platser), 1:50kre och 1kr                     2.0
# 2                                         NaN                     NaN
# 3                                         NaN                     2.0
# 4                                         NaN                     NaN
# 5     1kr till salongen, 1:50kr till läktaren                     NaN
# 6            1:25kr herre, 1kr da, 50öre barn                     NaN
# 7  1kr reserverad plats, 75öre övriga platser                     1.0
# 8          1kr reserverad plats, 75öre, 50öre                     NaN
# 9            3kr numrerade, 2:50kr onumrerade                     3.0
#
#    SummaförRecension  SummaförAntalförkonsert_verk_ID  \
# 0                NaN                              NaN
# 1                NaN                             14.0
# 2                2.0                              NaN
# 3                NaN                              5.0
# 4                NaN                              NaN
# 5                2.0                              NaN
# 6                NaN                              NaN
# 7                NaN                              9.0
# 8                NaN                              NaN
# 9                2.0                              3.0
#
#                   Arrangör     konserttyp_namn    Månad    År       Dag  \
# 0  Brüssel-stråkkvartetten  Kammarmusikkonsert  JANUARY  1908  Thursday
# 1           Gellin, Eduard             Konsert  JANUARY  1908    Sunday
# 2   Bohlin, Carl. Direktör        Kyrkokonsert  JANUARY  1908    Sunday
# 3                      NaN         Folkkonsert  JANUARY  1908    Sunday
# 4            Hansson, Axel      Populärkonsert  JANUARY  1908    Sunday
# 5                    Berns             Konsert  JANUARY  1908    Monday
# 6                   Lj. B.                 Bal  JANUARY  1908    Monday
# 7           Dahlberg, Erik      Populärkonsert  JANUARY  1908    Monday
# 8       Arbetareinstitutet      Populärkonsert  JANUARY  1908    Monday
# 9          Aulinkvartetten  Kammarmusikkonsert  JANUARY  1908   Tuesday
#
#    Månadnr  lokal_namn_eng    konserttyp_namn_eng  \
# 0        1             NaN  Chamber music concert
# 1        1             NaN                Concert
# 2        1             NaN         Church concert
# 3        1             NaN           Folk concert
# 4        1             NaN        Popular concert
# 5        1             NaN                Concert
# 6        1             NaN                   Ball
# 7        1             NaN        Popular concert
# 8        1             NaN        Popular concert
# 9        1             NaN  Chamber music concert
#
#                                             Producer
# 0  Brüssel-stråkkvartetten - Brussels String Quartet
# 1                                     Gellin, Eduard
# 2                             Bohlin, Carl. Director
# 3                                                NaN
# 4                                      Hansson, Axel
# 5                                              Berns
# 6                                             Lj. B.
# 7                                     Dahlberg, Erik
# 8            Arbetareinstitutet - Workers' Institute
# 9                    Aulinkvartetten - Aulin Quartet

# %%
# Load JSON file
json_path = 'Datasets/18.05.24_oldtimey_Touringbot_SvD_1908-01-01-1908-02-29_search_konsert_gpt3.5_turbo_batch_cpkGJ53jIRLdMmZGbhlkL7cT_output.json'
json_df = pd.read_json(json_path)

#Did this load right? If there's dates and whatever in here, we're good.
print(json_df.head(3))
# Out:
#   konsert_datum                     konsert_namn  \
# 0      15.02.08                 Symfonikonserten
# 1      14.02.08               Populär Sång-Afton
# 2      21.02.08  Vivien Cliartrcs afskedskonsert
#
#                                   lokal_namn  konsert_biljettpris  \
# 0                           Kungliga Teatern              UNKNOWN
# 1       F.U.M:s hörsal, Birger Jarlsgatan 35      1kr 50 öre, 1kr
# 2  Kungliga musikaliska akademiens stora sal  2:50kr, 2kr, 1:50kr
#
#   SummaförAnnons/program SummaförRecension SummaförAntalförkonsert_verk_ID  \
# 0                      0                 0                               4
# 1                      1                 0                               0
# 2                      1                 0                               7
#
#          Arrangör konserttyp_namn     Månad    År       Dag Månadnr  \
# 0   Järnefelt, A.  Symfonikonsert  FEBRUARY  1908  Saturday       2
# 1  Lundberg, Anna     Sångkonsert  FEBRUARY  1908    Friday       2
# 2  Gellin, Eduard     Solokonsert  FEBRUARY  1908    Friday       2
#
#   konserttyp_namn_eng        Producer
# 0    Symphony concert  Gellin, Eduard
# 1       Vocal concert  Lundberg, Anna
# 2        Solo concert  Gellin, Eduard

# %% [markdown]
# # Now we normalise the text so that they can be compared

# %% [markdown]
# ## Removing Columns that are irrelevant

# %%
# Identify relevant columns (adjust based on your specific dataset)
relevant_columns = ['konsert_datum','konsert_namn','lokal_namn','konsert_biljettpris','Arrangör','konserttyp_namn','Producer']

# Remove irrelevant columns from both DataFrames
xls_df = xls_df[relevant_columns]
json_df = json_df[relevant_columns]

# %%
import pandas as pd
from fuzzywuzzy import process, fuzz
import re
from datetime import datetime

# Function to normalize text
def normalize(text):
    if pd.isna(text) or text.strip().lower() == "unknown":  # Handle NaN values and "UNKNOWN"
        return ""
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'[-,]', ' ', text)  # Replace hyphens and commas with spaces
    text = re.sub(r'\s+', ' ', text)  # Replace multiple spaces with a single space
    text = text.strip()  # Remove leading and trailing spaces
    return text

# Function to normalize dates
def normalize_date(date):
    try:
        # Try to parse the date from different formats
        if isinstance(date, str):
            if re.match(r'\d{2}\.\d{2}\.\d{2}', date):  # Format: DD.MM.YY
                date_obj = datetime.strptime(date, '%d.%m.%y')
                # Adjust for century
                if date_obj.year >= 2000:
                    date_obj = date_obj.replace(year=date_obj.year - 100)
            elif re.match(r'\d{4}\.\d{2}\.\d{2}', date):  # Format: YYYY.MM.DD
                date_obj = datetime.strptime(date, '%Y.%m.%d')
            elif re.match(r'\d{2}\.\d{2}\.\d{4}', date):  # Format: DD.MM.YYYY
                date_obj = datetime.strptime(date, '%d.%m.%Y')
            else:
                return ""
        elif isinstance(date, datetime):
            # If already a datetime object, just format it
            date_obj = date
        else:
            return ""
        return date_obj.strftime('%Y-%m-%d')  # Convert to "YYYY-MM-DD"
    except ValueError:
        return ""

# Normalize the date columns in both dataframes
xls_df['normalized_konsert_datum'] = xls_df['konsert_datum'].apply(normalize_date)
json_df['normalized_konsert_datum'] = json_df['konsert_datum'].apply(normalize_date)

# Normalize all text columns in both dataframes
for col in xls_df.columns:
    if xls_df[col].dtype == 'object':  # Apply only to text columns
        xls_df[col] = xls_df[col].apply(normalize)

for col in json_df.columns:
    if json_df[col].dtype == 'object':  # Apply only to text columns
        json_df[col] = json_df[col].apply(normalize)

# Function to identify potential duplicates based on date and other criteria
def identify_potential_duplicates(df, date_col, other_cols, threshold=90):
    duplicates = []
    for i, row in df.iterrows():
        for j, other_row in df.iterrows():
            if i != j:
                # Check date similarity
                date_similarity = fuzz.token_sort_ratio(row[date_col], other_row[date_col])
                # Check other columns similarity
                other_similarity = all(fuzz.token_sort_ratio(row[col], other_row[col]) > threshold for col in other_cols)
                if date_similarity > threshold and other_similarity:
                    duplicates.append(i)
                    break  # Once a duplicate is found, move to the next row
    return list(set(duplicates))

# Columns to compare (excluding date)
other_columns_to_compare = ['konsert_namn', 'lokal_namn', 'konsert_biljettpris', 'Arrangör', 'konserttyp_namn', 'Producer']

# Identify potential duplicates in LLM data
duplicate_indices = identify_potential_duplicates(json_df, 'normalized_konsert_datum', other_columns_to_compare)

# Extract duplicates and export to CSV
today = datetime.today().strftime('%Y-%m-%d')
excluded_concerts = json_df.loc[duplicate_indices]
excluded_concerts.to_csv(f'{today}_excluded_concerts_fuzzy_comparison.csv', index=False)

# Remove duplicates from json_df
json_df = json_df.drop(duplicate_indices)

# %% [markdown]
# # This version has a toggle between exact and fuzzy matches

# %%
# Toggle variable for match type
match_type = "exact"  # Set to "exact" for exact match, "fuzzy" for fuzzy match

# Exact Match Function
def exact_match(df1, df2):
    # Merge on normalized date
    merged_df = pd.merge(df1, df2, on='normalized_konsert_datum', suffixes=('_human', '_llm'))
    
    # Calculate similarities for other columns
    for col in other_columns_to_compare:
        merged_df[f'score_{col}'] = merged_df.apply(lambda row: fuzz.token_sort_ratio(row[f'{col}_human'], row[f'{col}_llm']), axis=1)
    
    # Print analytics
    for col in other_columns_to_compare:
        avg_score = merged_df[f'score_{col}'].mean()
        print(f"Average match score for {col}: {avg_score:.2f}")
    
    return merged_df

# Fuzzy Match Function
def fuzzy_match(df1, df2):
    # Function to find best matches for the 'normalized_konsert_datum' column
    def find_best_matches_for_dates(df1, df2, column_name='normalized_konsert_datum', threshold=80):
        matches = df2[column_name].apply(lambda x: process.extractOne(x, df1[column_name].dropna(), scorer=fuzz.token_sort_ratio) if x else ('No match', 0))
        df2[f'best_match_{column_name}'] = matches.apply(lambda x: x[0] if x else 'No match')
        df2[f'score_{column_name}'] = matches.apply(lambda x: x[1] if x else 0)
    
    # Apply fuzzy matching for 'normalized_konsert_datum'
    find_best_matches_for_dates(df1, df2)

    # Analyze results for 'normalized_konsert_datum'
    score_col = 'score_normalized_konsert_datum'
    avg_score = df2[score_col].mean()
    print(f"Average match score for konsert_datum: {avg_score:.2f}")

    # Identify rows with low match scores (below threshold)
    low_match_rows = df2[df2[score_col] < 80]
    print(f"Rows with low match scores for konsert_datum (total {len(low_match_rows)}):")
    print(low_match_rows[['konsert_datum', 'best_match_normalized_konsert_datum', score_col]])

# Toggle between exact and fuzzy match
if match_type == "exact":
    result_df = exact_match(xls_df, json_df)
elif match_type == "fuzzy":
    fuzzy_match(xls_df, json_df)
# Out:
# Average match score for konsert_namn: 36.31
# Average match score for lokal_namn: 44.60
# Average match score for konsert_biljettpris: 32.63
# Average match score for Arrangör: 28.93
# Average match score for konserttyp_namn: 61.05
# Average match score for Producer: 26.04

# %%
# Print to verify that normalisation went ok
start_row_xls = 2090
num_rows_to_display = 3  # Adjust as needed
#print("Excel DataFrame from row 2090:") # reason: the beginning of the data doesn't have dates in the date column.
#print(xls_df.iloc[start_row_xls:start_row_xls + num_rows_to_display])
print(json_df.head(3))
# Out:
#   konsert_datum                      konsert_namn  \
# 0      15.02.08                  symfonikonserten
# 1      14.02.08                populär sång afton
# 3    21.02.1908  vivien cliartrcs afskeds konsert
#
#                                   lokal_namn konsert_biljettpris  \
# 0                           kungliga teatern
# 1        f.u.m:s hörsal birger jarlsgatan 35      1kr 50 öre 1kr
# 3  kungliga musikaliska akademiens stora sal   2:50kr 2kr 1:50kr
#
#         Arrangör konserttyp_namn       Producer normalized_konsert_datum
# 0   järnefelt a.  symfonikonsert  gellin eduard               1908 02 15
# 1  lundberg anna     sångkonsert  lundberg anna               1908 02 14
# 3  gellin eduard     solokonsert  gellin eduard

# %% [markdown]
# # Fuzzywuzzy comparison

# %%
from fuzzywuzzy import process, fuzz

# Assume the DataFrames xls_df and json_df are already loaded and normalized
# Columns to compare
columns_to_compare = [
    'normalized_konsert_datum', 'konsert_namn', 'lokal_namn', 
    'konsert_biljettpris', 'Arrangör', 'konserttyp_namn', 'Producer'
]

# Normalize all text columns in both dataframes
for col in columns_to_compare:
    if xls_df[col].dtype == 'object':  # Apply only to text columns
        xls_df[col] = xls_df[col].apply(normalize)

for col in columns_to_compare:
    if json_df[col].dtype == 'object':  # Apply only to text columns
        json_df[col] = json_df[col].apply(normalize)

# Function to find best matches for a single column, with handling for empty strings
def find_best_matches(df1, df2, column_name, threshold=80):
    matches = df2[column_name].apply(lambda x: process.extractOne(x, df1[column_name].dropna(), scorer=fuzz.token_sort_ratio) if x else ('No match', 0))
    df2[f'best_match_{column_name}'] = matches.apply(lambda x: x[0] if x else 'No match')
    df2[f'score_{column_name}'] = matches.apply(lambda x: x[1] if x else 0)

# Apply fuzzy matching for each column
for col in columns_to_compare:
    if col in xls_df.columns and col in json_df.columns:
        find_best_matches(xls_df, json_df, col)

# Analyze results
for col in columns_to_compare:
    score_col = f'score_{col}'
    avg_score = json_df[score_col].mean()
    print(f"Average match score for {col}: {avg_score:.2f}")
    
    # Identifying low match scores
    low_match_rows = json_df[json_df[score_col] < 80]
    print(f"Rows with low match scores for {col}:")
    print(low_match_rows[[col, f'best_match_{col}', score_col]])

# Optionally, you can save the results to a CSV for further analysis
json_df.to_csv('comparison_results.csv', index=False)
# Out:
# Average match score for normalized_konsert_datum: 84.31
# Rows with low match scores for normalized_konsert_datum:
#    normalized_konsert_datum best_match_normalized_konsert_datum  \
# 3                                                      No match
# 6                                                      No match
# 9                                                      No match
# 25                                                     No match
# 36                                                     No match
# 43                                                     No match
# 46                                                     No match
# 54                                                     No match
#
#     score_normalized_konsert_datum
# 3                                0
# 6                                0
# 9                                0
# 25                               0
# 36                               0
# 43                               0
# 46                               0
# 54                               0
# Average match score for konsert_namn: 69.47
# Rows with low match scores for konsert_namn:
#                                          konsert_namn  \
# 3                    vivien cliartrcs afskeds konsert
# 5                                        behioz faust
# 8   minnesord af docenten kuben g. son berg ii kantat
# 9         pianistkonsert av fru h peizodd från london
# 10                              kyrko konsert gtf wkk
# 13             hans burmes ters orkester aftonkonsert
# 14          populär sång afton med det nya programmet
# 16     anlinska kvartettens tredje kammarmusikkonsert
# 17                                        stopkonsert
# 18                                      jones konsert
# 20  typografiska föreningens sångkör under ledning...
# 21              hans burmesters orkester stoppkonsert
# 22                   hans burmesters orkester konsert
# 23                            anrora molander concert
# 24                           viyien cliartres konsert
# 25    hans burmesters orkester kaffe och aftonkonsert
# 26  leo nora sista gästuppträdandet av fru matilda...
# 27           gästuppträdande av fru matilda jungstedt
# 28                     ebba sjögren vis och sångafton
# 31              berlioz faust (la damnation de faust)
# 32                                kallo afton konsert
# 34                                   bazarins döttrar
# 35                          henri marteau solokonsert
# 36
# 39                                 1:a säsong konsert
# 40                  eduard gellins 1:a säsongskonsert
# 42            2:a och sista konsert med märtha ohlson
# 43                   templet frälsningsarméns konsert
# 45                 kyrko konsert i gustaf wasa kyrkan
# 46  ungerska dam kapellet egressy sandor stop konsert
# 47            auktion av oljemålningar och akvareller
# 48                                    beethoven afton
# 51              berlioz faust (la damnation de faust)
# 54                                       stop konsert
#
#                               best_match_konsert_namn  score_konsert_namn
# 3                       vivian chartres andra konsert                  75
# 5                                               faust                  59
# 8   medborgarfesten på skansen: vid talarstolen på...                  42
# 9                                 carlo erici konsert                  49
# 10                                 stor kyrko konsert                  72
# 13                      populär konsert: svensk afton                  58
# 14                    populär sång afton nytt program                  79
# 16  aulinska kvartettens 3e kammarmusikkonsert: sc...                  78
# 17                                            konsert                  78
# 18                                       folk konsert                  72
# 20  illuminering och konsert av typografiska fören...                  57
# 21                       artistringens första konsert                  56
# 22                      s.s.u.h körens första konsert                  58
# 23                              henri marteau konsert                  55
# 24                      vivian chartres andra konsert                  75
# 25                      populär konsert: svensk afton                  51
# 26                            fjärde symfonikonserten                  43
# 27  stor extra konsert till förmån för de nödlidan...                  46
# 28                                vis och romansafton                  60
# 31                 dramatisk musikalisk soaré med bal                  47
# 32                                       folk konsert                  71
# 34               litteratur afton: björnson drachmann                  45
# 35                              henri marteau konsert                  57
# 36                                           No match                   0
# 39                                       o.d. konsert                  71
# 40                1:sta säsångskonsert: nordisk afton                  66
# 42                 årets sista folkdag: två konserter                  55
# 43                            teresa carrenos konsert                  60
# 45                      s.s.u.h körens första konsert                  62
# 46  illuminering och konsert av typografiska fören...                  55
# 47             litteraturafton: fröding och karlfeldt                  46
# 48                        musik afton: beethovenafton                  73
# 51                 dramatisk musikalisk soaré med bal                  47
# 54                                       o.d. konsert                  78
# Average match score for lokal_namn: 70.51
# Rows with low match scores for lokal_namn:
#                                            lokal_namn  \
# 0                                    kungliga teatern
# 1                 f.u.m:s hörsal birger jarlsgatan 35
# 3           kungliga musikaliska akademiens stora sal
# 5           kungliga musikaliska akademiens stora sal
# 6                                          svea salen
# 7                              stockholms borgarskola
# 13                                              hotel
# 16                       vetenskaps akademiens hörsal
# 17                               hotel hamburger börs
# 18          kungliga musikaliska akademiens stora sal
# 19  föreningen för ungdomens musikaliska fostran h...
# 20                                             salong
# 21                                          sveasalen
# 22                                         svea salen
# 23          kungliga musikaliska akademiens stora sal
# 25                                        hotel fenix
# 26                                   kungliga teatern
# 27                                       ambassadören
# 29          kungliga musikaliska akademiens stora sal
# 30          kungliga musikaliska akademiens stora sal
# 31          kungliga musikaliska akademiens stora sal
# 32                                          sveasalen
# 34                                  östermalmsteatern
# 36
# 42          kungliga musikaliska akademiens stora sal
# 43             templet frälsningsarméns konsertsalong
# 44                       vetenskaps akademiens hörsal
# 46                                         svea salen
# 47  stockholms bokauktionskammare theodor blanch's...
# 48          kungliga musikaliska akademiens stora sal
# 49                                         svea salen
# 50                                         svea salen
# 51           hotell rydberg gustaf adolfs torg n:o 16
# 52                       vetenskaps akademiens hörsal
# 53                       vetenskaps akademiens hörsal
# 54                                         svea salen
#
#                                best_match_lokal_namn  score_lokal_namn
# 0                   kungliga operan/kungliga teatern                67
# 1                 brummerska skolan johannesgatan 18                53
# 3              kungliga musikaliska akademiens lokal                79
# 5              kungliga musikaliska akademiens lokal                79
# 6                                e. w:s stora salong                50
# 7                                     waxholms kyrka                50
# 13                                vaxhlms nya hotell                43
# 16                       vetenskapsakademiens hörsal                60
# 17                        hotel continentals festsal                40
# 18             kungliga musikaliska akademiens lokal                79
# 19                brummerska skolan johannesgatan 18                41
# 20                                      berns salong                67
# 21                                     viktoriasalen                64
# 22                               e. w:s stora salong                50
# 23             kungliga musikaliska akademiens lokal                79
# 25                             grand hotel festsalen                56
# 26                  kungliga operan/kungliga teatern                67
# 27                                      hasselbacken                52
# 29             kungliga musikaliska akademiens lokal                79
# 30             kungliga musikaliska akademiens lokal                79
# 31             kungliga musikaliska akademiens lokal                79
# 32                                     viktoriasalen                64
# 34                                     oscarsteatern                69
# 36                                          No match                 0
# 42             kungliga musikaliska akademiens lokal                79
# 43  kåren templet östemalmstorg 26 [frälsningsarmén]                77
# 44                       vetenskapsakademiens hörsal                60
# 46                               e. w:s stora salong                50
# 47           grand restaurant nationals stora salong                49
# 48             kungliga musikaliska akademiens lokal                79
# 49                               e. w:s stora salong                50
# 50                               e. w:s stora salong                50
# 51           grand restaurant nationals stora salong                43
# 52                       vetenskapsakademiens hörsal                60
# 53                       vetenskapsakademiens hörsal                60
# 54                               e. w:s stora salong                50
# Average match score for konsert_biljettpris: 54.65
# Rows with low match scores for konsert_biljettpris:
#    konsert_biljettpris best_match_konsert_biljettpris  \
# 0                                            No match
# 1       1kr 50 öre 1kr               1:50kr 1kr 50öre
# 7                                            No match
# 10                                           No match
# 13                                           No match
# 17                                           No match
# 22                                           No match
# 25                                           No match
# 26                                           No match
# 28       0:50kr 0:75kr               75öre 1kr 1:50kr
# 30                                           No match
# 34                                           No match
# 35                                           No match
# 36                                           No match
# 37       0.50kr 0.75kr               75öre 1kr 1:50kr
# 38       0:50kr 0:75kr               75öre 1kr 1:50kr
# 41          5kr 2:50kr                  3kr 2:50kr kr
# 43                                           No match
# 44       2kr 2kr 50öre                 2kr 1:50kr 1kr
# 45                                           No match
# 46                                           No match
# 47                                           No match
# 49                                           No match
# 50                                           No match
# 51                                           No match
# 52          3kr 2:60kr                  3kr 2:50kr kr
# 53          3kr 2.60kr                  3kr 2:50kr kr
# 54                                           No match
#
#     score_konsert_biljettpris
# 0                           0
# 1                          79
# 7                           0
# 10                          0
# 13                          0
# 17                          0
# 22                          0
# 25                          0
# 26                          0
# 28                         71
# 30                          0
# 34                          0
# 35                          0
# 36                          0
# 37                         71
# 38                         71
# 41                         78
# 43                          0
# 44                         77
# 45                          0
# 46                          0
# 47                          0
# 49                          0
# 50                          0
# 51                          0
# 52                         78
# 53                         78
# 54                          0
# Average match score for Arrangör: 62.04
# Rows with low match scores for Arrangör:
#                                   Arrangör            best_match_Arrangör  \
# 0                             järnefelt a.                  grünert dagny
# 5                         tärnefelt arinas                  grünert dagny
# 7                hertigen af västergötland     sundbaum strömberg kerstin
# 8                                                                No match
# 9                           peizodd h mrs.              petzold hanka fru
# 10                                                               No match
# 12                                                               No match
# 13                                                               No match
# 15                                                               No match
# 16  ödnianu arvid forssell john stiebel k.          gillberg carin fröken
# 17                          rochstroh paul      erici [fürstenberg] carlo
# 20             olsson otto gentzel carl a.                     olson otto
# 21                          egressy sandor                   ysaye eugène
# 22                          burmester hans                          berns
# 25                          burmester hans                          berns
# 26                         styrelsen nöjen           folkets hus styrelse
# 28                        hammarén fredric  zetterman k.f. [karl fredrik]
# 31                         armas järnefelt                  grünert dagny
# 32                           hennberg rich                  dahlberg erik
# 34                          ranft direktör                  orfei drängar
# 41              aulinkvartetten neruda fr.                aulinkvartetten
# 42                                                               No match
# 43                          vickberg major                 wahlberg anton
# 44                      nord automobil a&b                     ackté aino
# 45                                                               No match
# 46                          egressy sandor                   ysaye eugène
# 47                          blanch theodor                 nyrén thorvald
# 48                                                               No match
# 49               hotel hamburger börs prhf             stenhammar wilhelm
# 50                          egressy sandor                   ysaye eugène
# 54                           halldén björn                 nyrén thorvald
#
#     score_Arrangör
# 0               55
# 5               52
# 7               54
# 8                0
# 9               47
# 10               0
# 12               0
# 13               0
# 15               0
# 16              43
# 17              44
# 20              56
# 21              48
# 22              53
# 25              53
# 26              59
# 28              54
# 31              46
# 32              62
# 34              48
# 41              75
# 42               0
# 43              50
# 44              44
# 45               0
# 46              48
# 47              44
# 48               0
# 49              43
# 50              48
# 54              58
# Average match score for konserttyp_namn: 81.12
# Rows with low match scores for konserttyp_namn:
#            konserttyp_namn best_match_konserttyp_namn  score_konserttyp_namn
# 5             stor konsert                    konsert                     74
# 6          orkesterkonsert             arbetarkonsert                     76
# 8                   kantat                    konsert                     46
# 9             pianokonsert                barnkonsert                     78
# 13  kaffe och aftonkonsert             symfonikonsert                     56
# 17      kaffe aftonkonsert                folkkonsert                     62
# 21    kaffe o aftonkonsert             symfonikonsert                     59
# 22         orkesterkonsert             arbetarkonsert                     76
# 25  kaffe och aftonkonsert             symfonikonsert                     56
# 27                gästspel                       fest                     36
# 28       vis och sångafton             symfonikonsert                     40
# 30      abonnemangskonsert             arbetarkonsert                     69
# 31         orkesterkonsert             arbetarkonsert                     76
# 32           stråkorkester               kyrkokonsert                     58
# 34             studentspex       instrumental konsert                     52
# 36                                           No match                      0
# 37         populär konsert                    konsert                     67
# 39             kammarmusik         kammarmusikkonsert                     76
# 47                 auktion                barnkonsert                     44
# 49         orkesterkonsert             arbetarkonsert                     76
# 50         orkesterkonsert             arbetarkonsert                     76
# 53             kammarmusik         kammarmusikkonsert                     76
# 54      kaffe aftonkonsert                folkkonsert                     62
# Average match score for Producer: 63.94
# Rows with low match scores for Producer:
#                                   Producer  \
# 5                         tärnefelt arinas
# 6                            hofkapellet k
# 7                hertigen af västergötland
# 8
# 9                           peizodd h mrs.
# 10
# 12
# 13
# 15
# 16  ödnianu arvid forssell john stiebel k.
# 17                          rochstroh paul
# 21                          egressy sandor
# 22                          burmester hans
# 25                          burmester hans
# 26                         styrelsen nöjen
# 28                        hammarén fredric
# 30            nya filharmoniska sällskapet
# 31                         järnefelt armas
# 32                           hennberg rich
# 34                          ranft direktör
# 41              aulinkvartetten neruda fr.
# 42
# 43                          vickberg major
# 44                      nord automobil a&b
# 45
# 46                          egressy sandor
# 47                          blanch theodor
# 49               hotel hamburger börs prhf
# 50                          egressy sandor
# 51            nya filharmoniska sällskapet
# 54                           halldén björn
#
#                                   best_match_Producer  score_Producer
# 5                                       grünert dagny              52
# 6            kungl. hovkapellet royal court orchestra              46
# 7                          sundbaum strömberg kerstin              54
# 8                                            No match               0
# 9                                   petzold hanka mrs              73
# 10                                           No match               0
# 12                                           No match               0
# 13                                           No match               0
# 15                                           No match               0
# 16          folkets hus styrelse people's house board              42
# 17                          erici [fürstenberg] carlo              44
# 21                                       ysaye eugène              48
# 22                                              berns              53
# 25                                              berns              53
# 26                                       ysaye eugène              48
# 28                      zetterman k.f. [karl fredrik]              54
# 30  nya filharmoniska sällskapet new philharmonic ...              68
# 31                                   sjögren ebba mrs              48
# 32                                      dahlberg erik              62
# 34                             wennerberg reuter sara              46
# 41                      aulinkvartetten aulin quartet              67
# 42                                           No match               0
# 43                                     wahlberg anton              50
# 44                                         ackté aino              44
# 45                                           No match               0
# 46                                       ysaye eugène              48
# 47                                     nyrén thorvald              44
# 49                                 stenhammar wilhelm              43
# 50                                       ysaye eugène              48
# 51  nya filharmoniska sällskapet new philharmonic ...              68
# 54                                     nyrén thorvald              58

# %% [markdown]
# ## Find unique concerts for LLM

# %%
# Function to find unique concerts based on dates
def find_unique_dates(df1, df2, column_name='normalized_konsert_datum', threshold=80):
    # Concerts found by LLM but not by human
    unique_to_llm = df2[df2[f'score_{column_name}'] < threshold]
    # Concerts found by human but not matched by LLM
    matched_indices = df2[df2[f'score_{column_name}'] >= threshold][f'best_match_{column_name}'].index
    matched_entries = df1.loc[matched_indices]
    unique_to_human = df1[~df1.index.isin(matched_entries.index)]
    return unique_to_llm, unique_to_human

# Find unique concerts based on dates
unique_llm_dates, unique_human_dates = find_unique_dates(xls_df, json_df)

print(f"\nUnique concerts found by LLM but not by human (total {len(unique_llm_dates)}):")
print(unique_llm_dates[['konsert_datum', 'best_match_normalized_konsert_datum', score_col]])

print(f"\nUnique concerts found by human but not by LLM (total {len(unique_human_dates)}):")
print(unique_human_dates[['konsert_datum']])

# Optionally, save the unique concert results to separate CSV files for further analysis
unique_llm_dates.to_csv('unique_to_llm_konsert_datum.csv', index=False)
unique_human_dates.to_csv('unique_to_human_konsert_datum.csv', index=False)
# Out:
# Unique concerts found by LLM but not by human (total 8):
#         konsert_datum best_match_normalized_konsert_datum  score_Producer
# 3          21.02.1908                            No match             100
# 6                                                No match              46
# 9                                                No match              73
# 25                                               No match              53
# 36                                               No match             100
# 43  11.02.08 15.02.08                            No match              50
# 46                                               No match              48
# 54                                               No match              58
#
# Unique concerts found by human but not by LLM (total 471):
#     konsert_datum
# 2      1908-01-05
# 3      1908-01-05
# 4      1908-01-05
# 6      1908-01-06
# 9      1908-01-07
# ..            ...
# 509    1908-12-26
# 510    1908-12-26
# 511    1908-12-27
# 512    1908-12-31
# 513    1908-12-31
#
# [471 rows x 1 columns]
